# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/mois1-mois2/blob/main/FeatureSelection/corr2_cx_pipiens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
def corr(x,y):
    moyenne_x = np.mean(x)
    classes = []
    for classe in y.unique():
        xi_classe = x[y==classe]
        classes.append({'ni': len(xi_classe),
                        'moyenne_classe': np.mean(xi_classe)})
    SCT = np.sum([(xj-moyenne_x)**2 for xj in x])
    SCE = np.sum([c['ni']*(c['moyenne_classe']-moyenne_x)**2 for c in classes])
    return SCE/SCT

# %% [markdown]
# # cs_longia

# %%
Cl1 = '/content/cx_pipiens.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data["Source"] 
del data["CodeSite"] 
data
# Out:
#         X_long      Y_lat  Cx_pipiens     Bovins    Volaille   Caprins  \
# 0   -15.911420  23.794740           0   0.000000    0.000000  0.000000
# 1   -13.188370  27.132950           0   0.000214    0.000000  0.063449
# 2   -13.188370  27.132950           0   0.000214    0.000000  0.063449
# 3   -13.167180  27.157730           1   0.000000    0.000000  0.000000
# 4   -13.207000  27.165000           1   0.000000    0.000000  0.000000
# ..         ...        ...         ...        ...         ...       ...
# 205  -5.333333  35.266667           1  11.136305  139.052841  8.974447
# 206  -5.218206  35.348765           1  24.167864  101.951973  6.131610
# 207  -6.033333  35.466667           1   2.164068  117.797806  0.460241
# 208  -5.366667  35.566667           1   0.000000    0.000000  0.000000
# 209  -5.833954  35.759465           1   0.000000    0.000000  0.000000
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.379107          0        100  ...        5.0         5.2
# 4     0.000000  0.299265          0         74  ...        5.1         5.6
# ..         ...       ...        ...        ...  ...        ...         ...
# 205  27.155428  0.614620          0          0  ...        3.6         3.8
# 206  13.230689  0.796660          0          0  ...        5.0         4.6
# 207   4.490880  0.897535          0          6  ...        3.7         3.7
# 208   0.000000  1.145192          0          0  ...        3.9         3.9
# 209   0.000000  1.795786          0          0  ...        4.2         3.9
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.4        5.7         6.2        5.8        5.6       4.2
# 4         5.8        6.2         6.6        6.3        5.7       4.6
# ..        ...        ...         ...        ...        ...       ...
# 205       3.4        3.5         3.3        3.0        3.1       3.3
# 206       4.2        3.5         3.5        3.6        4.0       4.3
# 207       3.9        3.6         3.6        3.7        3.3       3.1
# 208       3.9        4.0         3.5        3.6        3.6       3.7
# 209       3.7        3.7         3.6        3.3        3.4       3.5
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.6       3.8
# 4         3.8       3.9
# ..        ...       ...
# 205       3.2       3.1
# 206       3.9       3.8
# 207       3.4       3.4
# 208       3.5       3.5
# 209       3.8       3.9
#
# [210 rows x 226 columns]

# %%
data["Cx_pipiens"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 205    1
# 206    1
# 207    1
# 208    1
# 209    1
# Name: Cx_pipiens, Length: 210, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cx_pipiens']
y = data.Cx_pipiens

# %%
X
# Out:
#         X_long      Y_lat     Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740   0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950   0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950   0.000214    0.000000  0.063449   0.034352
# 3   -13.167180  27.157730   0.000000    0.000000  0.000000   0.000000
# 4   -13.207000  27.165000   0.000000    0.000000  0.000000   0.000000
# ..         ...        ...        ...         ...       ...        ...
# 205  -5.333333  35.266667  11.136305  139.052841  8.974447  27.155428
# 206  -5.218206  35.348765  24.167864  101.951973  6.131610  13.230689
# 207  -6.033333  35.466667   2.164068  117.797806  0.460241   4.490880
# 208  -5.366667  35.566667   0.000000    0.000000  0.000000   0.000000
# 209  -5.833954  35.759465   0.000000    0.000000  0.000000   0.000000
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.379107          0        100        0  ...        5.0         5.2
# 4    0.299265          0         74        0  ...        5.1         5.6
# ..        ...        ...        ...      ...  ...        ...         ...
# 205  0.614620          0          0        0  ...        3.6         3.8
# 206  0.796660          0          0        0  ...        5.0         4.6
# 207  0.897535          0          6       30  ...        3.7         3.7
# 208  1.145192          0          0        0  ...        3.9         3.9
# 209  1.795786          0          0        0  ...        4.2         3.9
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.4        5.7         6.2        5.8        5.6       4.2
# 4         5.8        6.2         6.6        6.3        5.7       4.6
# ..        ...        ...         ...        ...        ...       ...
# 205       3.4        3.5         3.3        3.0        3.1       3.3
# 206       4.2        3.5         3.5        3.6        4.0       4.3
# 207       3.9        3.6         3.6        3.7        3.3       3.1
# 208       3.9        4.0         3.5        3.6        3.6       3.7
# 209       3.7        3.7         3.6        3.3        3.4       3.5
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.6       3.8
# 4         3.8       3.9
# ..        ...       ...
# 205       3.2       3.1
# 206       3.9       3.8
# 207       3.4       3.4
# 208       3.5       3.5
# 209       3.8       3.9
#
# [210 rows x 225 columns]

# %%
F=X.columns

# %%
F
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
lst=[]

# %%
for variable in F :
  x=X[variable]
  print("variable : ",variable,"/corrélation:",corr(x,y))
  lst.append([variable,corr(x,y)])
# Out:
# variable :  X_long /corrélation: 0.007123024838628962
# variable :  Y_lat /corrélation: 0.007604908220227153
# variable :  Bovins /corrélation: 0.0011370319950690202
# variable :  Volaille /corrélation: 0.0016877561593661597
# variable :  Caprins /corrélation: 0.006701259155605291
# variable :  Ovins /corrélation: 6.019469349421955e-07
# variable :  Equides /corrélation: 0.012981336643631724
# variable :  Coniferes /corrélation: 0.006446838253433108
# variable :  ZoneAride /corrélation: 0.012989706153456038
# variable :  ZonePel /corrélation: 7.769672378814701e-05
# variable :  Lesfeuillus /corrélation: 0.006771275568538855
# variable :  Caduc /corrélation: 0.0012896335627134695
# variable :  Autres /corrélation: 0.0004180746795173086
# variable :  Arbrisseau /corrélation: 0.010084381737737987
# variable :  Pl_herb /corrélation: 0.005773170494275068
# variable :  VegCul /corrélation: 0.001608396293241264
# variable :  VegInond /corrélation: nan
# variable :  ZoneUrbaine /corrélation: 0.00025331532014406804
# variable :  Moy_IRM /corrélation: 0.010087681609529971
# variable :  Amp1_IRM /corrélation: 0.0026471098473502914
# variable :  Amp2_IRM /corrélation: 2.675659737421517e-05
# variable :  Amp3_IRM /corrélation: 0.006749815403383741
# variable :  VarT_ann_IRM /corrélation: 0.0021246828084642896
# variable :  VarT_bi_IRM /corrélation: 0.004504560711745545
# variable :  VarT_tri_IRM /corrélation: 0.0007914523149980203
# variable :  VarT_Cy_IRM /corrélation: 0.00254849178430838
# variable :  Min_IRM /corrélation: 0.011818720007363512
# variable :  Max_IRM /corrélation: 0.006984348305868838
# variable :  Ph1_IRM /corrélation: 0.005626872274954191
# variable :  Ph2_IRM /corrélation: 2.5033600702251164e-05
# variable :  Ph3_IRM /corrélation: 6.525928379380352e-06
# variable :  Var_IRM /corrélation: 0.004505316273202378
# variable :  Moy_TempJ /corrélation: 0.00010340640090301188
# variable :  Amp1_TempJ /corrélation: 0.0027716305129108546
# variable :  Amp2_TempJ /corrélation: 0.00014871042793313785
# variable :  Amp3_TempJ /corrélation: 0.04508491003478243
# variable :  VarT_ann_TempJ /corrélation: 0.0011774765556007147
# variable :  VarT_bi_TempJ /corrélation: 0.0
# variable :  VarT_tri_TempJ /corrélation: 0.0022675736961451248
# variable :  VarT_cy_TempJ /corrélation: 0.0014426752621761623
# variable :  Min_TempJ /corrélation: 0.00018587345579854547
# variable :  Max_TempJ /corrélation: 5.10357694621021e-06
# variable :  Ph1_TempJ /corrélation: 7.437290458988519e-05
# variable :  Ph2_TempJ /corrélation: 0.012682833156048947
# variable :  Ph3_TempJ /corrélation: 8.619187956048456e-06
# variable :  Var_TempJ /corrélation: 0.0020621727706753466
# variable :  Moy_TempN /corrélation: 5.6103456486728945e-05
# variable :  Amp1_TempN /corrélation: 6.319390877247106e-08
# variable :  Amp2_TempN /corrélation: 0.0043561123699191046
# variable :  Amp3_TempN /corrélation: 0.00030857260408610857
# variable :  VarT_ann_TempN /corrélation: 0.0024872651107671396
# variable :  VarT_bi_TempN /corrélation: 0.0028895106178048885
# variable :  VarT_tri_TempN /corrélation: 0.00785854616895874
# variable :  VarT_cy_TempN /corrélation: 0.0017512708929314873
# variable :  Min_TempN /corrélation: 2.2125906800236377e-05
# variable :  Max_TempN /corrélation: 2.1182376715055433e-05
# variable :  Ph1_TempN /corrélation: 0.000989633398333003
# variable :  Ph2_TempN /corrélation: 0.0193373288610182
# variable :  Ph3_TempN /corrélation: 0.002085488960742583
# variable :  Var_TempN /corrélation: 1.3092194506369626e-06
# variable :  Moy_NDVI /corrélation: 0.01692326574066365
# variable :  Amp1_NDVI /corrélation: 0.004435585029989494
# variable :  Amp2_NDVI /corrélation: 0.002167879288960119
# variable :  Amp3_NDVI /corrélation: 0.0022693604816087258
# variable :  VarT_ann_NDVI /corrélation: 0.00022489084362029122
# variable :  VarT_bi_NDVI /corrélation: 3.8788442983412805e-05
# variable :  VarT_tri_NDVI /corrélation: 0.00015162427504643476
# variable :
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# VarT_cy_NDVI /corrélation: 0.00020752713652507547
# variable :  Min_NDVI /corrélation: 0.015082505318512084
# variable :  Max_NDVI /corrélation: 0.014698545816185075
# variable :  Ph1_NDVI /corrélation: 0.0070890575167221435
# variable :  Ph2_NDVI /corrélation: 0.008805942602771264
# variable :  Ph3_NDVI /corrélation: 0.000556581266773959
# variable :  Var_NDVI /corrélation: 0.004564957270873328
# variable :  Moy_EVI /corrélation: 0.014222271821386722
# variable :  Amp1_EVI /corrélation: 0.001408731708487349
# variable :  Amp2_EVI /corrélation: 1.5601655616973066e-05
# variable :  Amp3_EVI /corrélation: 3.2642895626473948e-06
# variable :  VarT_ann_EVI /corrélation: 0.00010064512476588142
# variable :  VarT_bi_EVI /corrélation: 0.0027463375395090717
# variable :  VarT_tri_EVI /corrélation: 0.0001927510196528935
# variable :  VarT_cy_EVI /corrélation: 0.0004091524717355432
# variable :  Min_EVI /corrélation: 0.018523020677977085
# variable :  Max_EVI /corrélation: 0.007947359239035492
# variable :  Ph1_EVI /corrélation: 0.009915830762949284
# variable :  Ph2_EVI /corrélation: 0.0019601287636493107
# variable :  Ph3_EVI /corrélation: 0.008072025549498015
# variable :  Var_EVI /corrélation: 0.0005795657592090129
# variable :  Ret_eau /corrélation: 0.0013516113138546668
# variable :  Sol_teneur /corrélation: 0.022050785877649196
# variable :  Substratum /corrélation: 0.01034821048319442
# variable :  Prob_R /corrélation: 0.014309390941085168
# variable :  ProfAbs_Sub /corrélation: 0.019559270864840186
# variable :  CEC /corrélation: 0.0005435102297882226
# variable :  Sol_Argile /corrélation: 0.0014586083768578855
# variable :  Sol_Carbone /corrélation: 0.00033496438402548723
# variable :  Sol_Carbone_stock /corrélation: 0.0012502311133099448
# variable :  Sol_Carbone_terreFine /corrélation: 0.00398906502627915
# variable :  Sol_pH_KCL /corrélation: 0.012411448428132613
# variable :  Sol_Limon /corrélation: 0.0009111267144239823
# variable :  Sol_Sable /corrélation: 0.008841672170784002
# variable :  Elev_Max /corrélation: 0.011573933470517602
# variable :  Elev_Moyenne /corrélation: 0.009070181736358476
# variable :  Elev_Min /corrélation: 0.005999144333566324
# variable :  Elev_Moy /corrélation: 0.008920073951700915
# variable :  Elev_sd /corrélation: 0.02123076217443756
# variable :  Geom_maj /corrélation: 0.0032458499489937806
# variable :  Geom_Shan /corrélation: 0.004125933760220891
# variable :  Geom_unif /corrélation: 0.011241926209612523
# variable :  Rugosite_Max /corrélation: 0.02227499985976456
# variable :  Rugosite_Moyenne /corrélation: 0.02491301046122466
# variable :  Rugosite_Min /corrélation: 0.02693405573330188
# variable :  Rugosite_Moy /corrélation: 0.024457664781804882
# variable :  Rugosite_sd /corrélation: 0.015341693667588252
# variable :  Pente_Max /corrélation: 0.025106549610429643
# variable :  Pente_Moyenne /corrélation: 0.02273301661912954
# variable :  Pente_Min /corrélation: 0.06097179637889289
# variable :  Pente_Moy /corrélation: 0.029256443296827257
# variable :  Pente_sd /corrélation: 0.007741575168523198
# variable :  IPT_Max /corrélation: 0.016342717750848775
# variable :  IPT_Med /corrélation: 0.025434488368561724
# variable :  IPT_Min /corrélation: 0.0010939221322242584
# variable :  IPT_Moy /corrélation: 0.033252821099255044
# variable :  IPT_sd /corrélation: 0.006250086616432428
# variable :  IR_Max /corrélation: 0.019924234986915302
# variable :  IR_Med /corrélation: 0.020348722423423195
# variable :  IR_Min /corrélation: 0.022234542614495794
# variable :  IR_Moy /corrélation: 0.021273484010621204
# variable :  IR_sd /corrélation: 0.013647697835358779
# variable :  RV_Max /corrélation: 0.003764752469977219
# variable :  RV_Med /corrélation: 9.85061202845402e-05
# variable :  RV_Min /corrélation: 9.54695576575781e-05
# variable :  RV_Moy /corrélation: 0.0007438572669844677
# variable :  RV_sd /corrélation: 0.0021774308627638965
# variable :  Bio_Ta_moy /corrélation: 0.021967447862778777
# variable :  Bio_Tj_Moy /corrélation: 0.022815244442231878
# variable :  Isoth /corrélation: 0.008172828249842681
# variable :  Bio_Saison /corrélation: 8.798813975038611e-06
# variable :  Bio_Tmax /corrélation: 0.03102469120658799
# variable :  Bio_Tmin /corrélation: 0.0028536799057928015
# variable :  Bio_Tint /corrélation: 0.0041760851302311535
# variable :  Bio_Thum_Moy /corrélation: 0.01942136515953537
# variable :  Bio_Tsec_Moy /corrélation: 0.02368243139774749
# variable :  Bio_Tch_Moy /corrélation: 0.02259526986331635
# variable :  Bio_Tfr_Moy /corrélation: 0.01039719484720076
# variable :  Bio_Pre_Ann /corrélation: 0.008475967564651106
# variable :  Bio_Pre_hum /corrélation: 0.0030073595211131277
# variable :  Bio_Pre_sec /corrélation: 0.016106315093562258
# variable :  Bio_Pre_Saison /corrélation: 0.010057927953635552
# variable :  Bio_Pre_Qhum /corrélation: 0.00750830213162861
# variable :  Bio_Pre_Qsec /corrélation: 0.014362328021022577
# variable :  Bio_Pre_Qch /corrélation: 0.012901086501451015
# variable :  Bio_Pre_Qfr /corrélation: 0.005661520083396631
# variable :  Prec_Janv /corrélation: 0.011715440930238071
# variable :  Prec_Fev /corrélation: 0.011226053664446655
# variable :  Prec_Mars /corrélation: 0.014184805229434199
# variable :  Prec_Avril /corrélation: 0.0031624170199316347
# variable :  Prec_Mai /corrélation: 0.009813975966862575
# variable :  Prec_Juin /corrélation: 0.005793407863795797
# variable :  Prec_Juill /corrélation: 0.013416704625450339
# variable :  Prec_Aout /corrélation: 0.02067849522418411
# variable :  Prec_Sept /corrélation: 0.02083962863781768
# variable :  Prec_Oct /corrélation: 0.002201368022163982
# variable :  Prec_Nov /corrélation: 0.00896599317027181
# variable :  Prec_Dec /corrélation: 7.330534895466616e-05
# variable :  Rad_Janv /corrélation: 0.009650177212710529
# variable :  Rad_Fev /corrélation: 0.008525964281100527
# variable :  Rad_Mars /corrélation: 0.012118161570132211
# variable :  Rad_Avril /corrélation: 0.01705072328942222
# variable :  Rad_Mai /corrélation: 0.002185662076795602
# variable :  Rad_Juin /corrélation: 0.0009755233581733684
# variable :  Rad_Juill /corrélation: 0.0039850413899877824
# variable :  Rad_Aout /corrélation: 0.01427326141096547
# variable :  Rad_Sept /corrélation: 0.0014314921567857696
# variable :  Rad_Oct /corrélation: 0.009244570541902749
# variable :  Rad_Nov /corrélation: 0.015084592909100154
# variable :  Rad_Dec /corrélation: 0.010799228663996567
# variable :  Tmax_Janv /corrélation: 0.016731501342946733
# variable :  Tmax_Fev /corrélation: 0.024380447318143927
# variable :  Tmax_Mars /corrélation: 0.02637537573691639
# variable :  Tmax_Avril /corrélation: 0.02394647185631821
# variable :  Tmax_Mai /corrélation: 0.021477416373845832
# variable :  Tmax_Juin /corrélation: 0.01600401997062824
# variable :  Tmax_Juill /corrélation: 0.029772010777067964
# variable :  Tmax_Aout /corrélation: 0.03269593798159143
# variable :  Tmax_Sept /corrélation: 0.04043049396512836
# variable :  Tmax_Oct /corrélation: 0.037896726401627445
# variable :  Tmax_Nov /corrélation: 0.02924067060630779
# variable :  Tmax_Dec /corrélation: 0.017577150922887832
# variable :  Tmin_Janv /corrélation: 0.003721501104679902
# variable :  Tmin_Fev /corrélation: 0.007187081648138918
# variable :  Tmin_Mars /corrélation: 0.009023323962127586
# variable :  Tmin_Avril /corrélation: 0.008570206589610125
# variable :  Tmin_Mai /corrélation: 0.010599358791711566
# variable :  Tmin_Juin /corrélation: 0.010842108878371715
# variable :  Tmin_Juill /corrélation: 0.006242993854663393
# variable :  Tmin_Aout /corrélation: 0.00816703054433279
# variable :  Tmin_Sept /corrélation: 0.009639757477709248
# variable :  Tmin_Oct /corrélation: 0.011158144046183866
# variable :  Tmin_Nov /corrélation: 0.006080494738662461
# variable :  Tmin_Dec /corrélation: 0.0012887700509589886
# variable :  Vap_Janv /corrélation: 0.0003709537821050886
# variable :  Vap_Fev /corrélation: 0.0006906801317477237
# variable :  Vap_Mars /corrélation: 0.0008499744163933966
# variable :  Vap_Avril /corrélation: 0.0012239966038433217
# variable :  Vap_Mai /corrélation: 0.0009373113071949026
# variable :  Vap_Juin /corrélation: 0.000629991621444252
# variable :  Vap_Juill /corrélation: 5.528744458203711e-05
# variable :  Vap_Aout /corrélation: 8.061948833983386e-06
# variable :  Vap_Sept /corrélation: 4.518292573391878e-05
# variable :  Vap_Oct /corrélation: 2.023077995404867e-05
# variable :  Vap_Nov /corrélation: 2.042390637258196e-05
# variable :  Vap_Dec /corrélation: 1.4418588867034668e-05
# variable :  Vent_Janv /corrélation: 0.03391273957445586
# variable :  Vent_Fev /corrélation: 0.048213825493191864
# variable :  Vent_Mars /corrélation: 0.034674688200768654
# variable :  Vent_Avril /corrélation: 0.025639151172401654
# variable :  Vent_Mai /corrélation: 0.013873385001225952
# variable :  Vent_Juin /corrélation: 0.008301280464058673
# variable :  Vent_Juill /corrélation: 0.0013371366405948565
# variable :  Vent_Aout /corrélation: 0.0014285221859750047
# variable :  Vent_Sept /corrélation: 0.039924034735939966
# variable :  Vent_Oct /corrélation: 0.05506998551098996
# variable :  Vent_Nov /corrélation: 0.027257921415708892
# variable :  Vent_Dec /corrélation: 0.055531332872018016

# %%
lst
# Out:
# [['X_long', 0.007123024838628962],
#  ['Y_lat', 0.007604908220227153],
#  ['Bovins', 0.0011370319950690202],
#  ['Volaille', 0.0016877561593661597],
#  ['Caprins', 0.006701259155605291],
#  ['Ovins', 6.019469349421955e-07],
#  ['Equides', 0.012981336643631724],
#  ['Coniferes', 0.006446838253433108],
#  ['ZoneAride', 0.012989706153456038],
#  ['ZonePel', 7.769672378814701e-05],
#  ['Lesfeuillus', 0.006771275568538855],
#  ['Caduc', 0.0012896335627134695],
#  ['Autres', 0.0004180746795173086],
#  ['Arbrisseau', 0.010084381737737987],
#  ['Pl_herb', 0.005773170494275068],
#  ['VegCul', 0.001608396293241264],
#  ['VegInond', nan],
#  ['ZoneUrbaine', 0.00025331532014406804],
#  ['Moy_IRM', 0.010087681609529971],
#  ['Amp1_IRM', 0.0026471098473502914],
#  ['Amp2_IRM', 2.675659737421517e-05],
#  ['Amp3_IRM', 0.006749815403383741],
#  ['VarT_ann_IRM', 0.0021246828084642896],
#  ['VarT_bi_IRM', 0.004504560711745545],
#  ['VarT_tri_IRM', 0.0007914523149980203],
#  ['VarT_Cy_IRM', 0.00254849178430838],
#  ['Min_IRM', 0.011818720007363512],
#  ['Max_IRM', 0.006984348305868838],
#  ['Ph1_IRM', 0.005626872274954191],
#  ['Ph2_IRM', 2.5033600702251164e-05],
#  ['Ph3_IRM', 6.525928379380352e-06],
#  ['Var_IRM', 0.004505316273202378],
#  ['Moy_TempJ', 0.00010340640090301188],
#  ['Amp1_TempJ', 0.0027716305129108546],
#  ['Amp2_TempJ', 0.00014871042793313785],
#  ['Amp3_TempJ', 0.04508491003478243],
#  ['VarT_ann_TempJ', 0.0011774765556007147],
#  ['VarT_bi_TempJ', 0.0],
#  ['VarT_tri_TempJ', 0.0022675736961451248],
#  ['VarT_cy_TempJ', 0.0014426752621761623],
#  ['Min_TempJ', 0.00018587345579854547],
#  ['Max_TempJ', 5.10357694621021e-06],
#  ['Ph1_TempJ', 7.437290458988519e-05],
#  ['Ph2_TempJ', 0.012682833156048947],
#  ['Ph3_TempJ', 8.619187956048456e-06],
#  ['Var_TempJ', 0.0020621727706753466],
#  ['Moy_TempN', 5.6103456486728945e-05],
#  ['Amp1_TempN', 6.319390877247106e-08],
#  ['Amp2_TempN', 0.0043561123699191046],
#  ['Amp3_TempN', 0.00030857260408610857],
#  ['VarT_ann_TempN', 0.0024872651107671396],
#  ['VarT_bi_TempN', 0.0028895106178048885],
#  ['VarT_tri_TempN', 0.00785854616895874],
#  ['VarT_cy_TempN', 0.0017512708929314873],
#  ['Min_TempN', 2.2125906800236377e-05],
#  ['Max_TempN', 2.1182376715055433e-05],
#  ['Ph1_TempN', 0.000989633398333003],
#  ['Ph2_TempN', 0.0193373288610182],
#  ['Ph3_TempN', 0.002085488960742583],
#  ['Var_TempN', 1.3092194506369626e-06],
#  ['Moy_NDVI', 0.01692326574066365],
#  ['Amp1_NDVI', 0.004435585029989494],
#  ['Amp2_NDVI', 0.002167879288960119],
#  ['Amp3_NDVI', 0.0022693604816087258],
#  ['VarT_ann_NDVI', 0.00022489084362029122],
#  ['VarT_bi_NDVI', 3.8788442983412805e-05],
#  ['VarT_tri_NDVI', 0.00015162427504643476],
#  ['VarT_cy_NDVI', 0.00020752713652507547],
#  ['Min_NDVI', 0.015082505318512084],
#  ['Max_NDVI', 0.014698545816185075],
#  ['Ph1_NDVI', 0.0070890575167221435],
#  ['Ph2_NDVI', 0.008805942602771264],
#  ['Ph3_NDVI', 0.000556581266773959],
#  ['Var_NDVI', 0.004564957270873328],
#  ['Moy_EVI', 0.014222271821386722],
#  ['Amp1_EVI', 0.001408731708487349],
#  ['Amp2_EVI', 1.5601655616973066e-05],
#  ['Amp3_EVI', 3.2642895626473948e-06],
#  ['VarT_ann_EVI', 0.00010064512476588142],
#  ['VarT_bi_EVI', 0.0027463375395090717],
#  ['VarT_tri_EVI', 0.0001927510196528935],
#  ['VarT_cy_EVI', 0.0004091524717355432],
#  ['Min_EVI', 0.018523020677977085],
#  ['Max_EVI', 0.007947359239035492],
#  ['Ph1_EVI', 0.009915830762949284],
#  ['Ph2_EVI', 0.0019601287636493107],
#  ['Ph3_EVI', 0.008072025549498015],
#  ['Var_EVI', 0.0005795657592090129],
#  ['Ret_eau', 0.0013516113138546668],
#  ['Sol_teneur', 0.022050785877649196],
#  ['Substratum', 0.01034821048319442],
#  ['Prob_R', 0.014309390941085168],
#  ['ProfAbs_Sub', 0.019559270864840186],
#  ['CEC', 0.0005435102297882226],
#  ['Sol_Argile', 0.0014586083768578855],
#  ['Sol_Carbone', 0.00033496438402548723],
#  ['Sol_Carbone_stock', 0.0012502311133099448],
#  ['Sol_Carbone_terreFine', 0.00398906502627915],
#  ['Sol_pH_KCL', 0.012411448428132613],
#  ['Sol_Limon', 0.0009111267144239823],
#  ['Sol_Sable', 0.008841672170784002],
#  ['Elev_Max', 0.011573933470517602],
#  ['Elev_Moyenne', 0.009070181736358476],
#  ['Elev_Min', 0.005999144333566324],
#  ['Elev_Moy', 0.008920073951700915],
#  ['Elev_sd', 0.02123076217443756],
#  ['Geom_maj', 0.0032458499489937806],
#  ['Geom_Shan', 0.004125933760220891],
#  ['Geom_unif', 0.011241926209612523],
#  ['Rugosite_Max', 0.02227499985976456],
#  ['Rugosite_Moyenne', 0.02491301046122466],
#  ['Rugosite_Min', 0.02693405573330188],
#  ['Rugosite_Moy', 0.024457664781804882],
#  ['Rugosite_sd', 0.015341693667588252],
#  ['Pente_Max', 0.025106549610429643],
#  ['Pente_Moyenne', 0.02273301661912954],
#  ['Pente_Min', 0.06097179637889289],
#  ['Pente_Moy', 0.029256443296827257],
#  ['Pente_sd', 0.007741575168523198],
#  ['IPT_Max', 0.016342717750848775],
#  ['IPT_Med', 0.025434488368561724],
#  ['IPT_Min', 0.0010939221322242584],
#  ['IPT_Moy', 0.033252821099255044],
#  ['IPT_sd', 0.006250086616432428],
#  ['IR_Max', 0.019924234986915302],
#  ['IR_Med', 0.020348722423423195],
#  ['IR_Min', 0.022234542614495794],
#  ['IR_Moy', 0.021273484010621204],
#  ['IR_sd', 0.013647697835358779],
#  ['RV_Max', 0.003764752469977219],
#  ['RV_Med', 9.85061202845402e-05],
#  ['RV_Min', 9.54695576575781e-05],
#  ['RV_Moy', 0.0007438572669844677],
#  ['RV_sd', 0.0021774308627638965],
#  ['Bio_Ta_moy', 0.021967447862778777],
#  ['Bio_Tj_Moy', 0.022815244442231878],
#  ['Isoth', 0.008172828249842681],
#  ['Bio_Saison', 8.798813975038611e-06],
#  ['Bio_Tmax', 0.03102469120658799],
#  ['Bio_Tmin', 0.0028536799057928015],
#  ['Bio_Tint', 0.0041760851302311535],
#  ['Bio_Thum_Moy', 0.01942136515953537],
#  ['Bio_Tsec_Moy', 0.02368243139774749],
#  ['Bio_Tch_Moy', 0.02259526986331635],
#  ['Bio_Tfr_Moy', 0.01039719484720076],
#  ['Bio_Pre_Ann', 0.008475967564651106],
#  ['Bio_Pre_hum', 0.0030073595211131277],
#  ['Bio_Pre_sec', 0.016106315093562258],
#  ['Bio_Pre_Saison', 0.010057927953635552],
#  ['Bio_Pre_Qhum', 0.00750830213162861],
#  ['Bio_Pre_Qsec', 0.014362328021022577],
#  ['Bio_Pre_Qch', 0.012901086501451015],
#  ['Bio_Pre_Qfr', 0.005661520083396631],
#  ['Prec_Janv', 0.011715440930238071],
#  ['Prec_Fev', 0.011226053664446655],
#  ['Prec_Mars', 0.014184805229434199],
#  ['Prec_Avril', 0.0031624170199316347],
#  ['Prec_Mai', 0.009813975966862575],
#  ['Prec_Juin', 0.005793407863795797],
#  ['Prec_Juill', 0.013416704625450339],
#  ['Prec_Aout', 0.02067849522418411],
#  ['Prec_Sept', 0.02083962863781768],
#  ['Prec_Oct', 0.002201368022163982],
#  ['Prec_Nov', 0.00896599317027181],
#  ['Prec_Dec', 7.330534895466616e-05],
#  ['Rad_Janv', 0.009650177212710529],
#  ['Rad_Fev', 0.008525964281100527],
#  ['Rad_Mars', 0.012118161570132211],
#  ['Rad_Avril', 0.01705072328942222],
#  ['Rad_Mai', 0.002185662076795602],
#  ['Rad_Juin', 0.0009755233581733684],
#  ['Rad_Juill', 0.0039850413899877824],
#  ['Rad_Aout', 0.01427326141096547],
#  ['Rad_Sept', 0.0014314921567857696],
#  ['Rad_Oct', 0.009244570541902749],
#  ['Rad_Nov', 0.015084592909100154],
#  ['Rad_Dec', 0.010799228663996567],
#  ['Tmax_Janv', 0.016731501342946733],
#  ['Tmax_Fev', 0.024380447318143927],
#  ['Tmax_Mars', 0.02637537573691639],
#  ['Tmax_Avril', 0.02394647185631821],
#  ['Tmax_Mai', 0.021477416373845832],
#  ['Tmax_Juin', 0.01600401997062824],
#  ['Tmax_Juill', 0.029772010777067964],
#  ['Tmax_Aout', 0.03269593798159143],
#  ['Tmax_Sept', 0.04043049396512836],
#  ['Tmax_Oct', 0.037896726401627445],
#  ['Tmax_Nov', 0.02924067060630779],
#  ['Tmax_Dec', 0.017577150922887832],
#  ['Tmin_Janv', 0.003721501104679902],
#  ['Tmin_Fev', 0.007187081648138918],
#  ['Tmin_Mars', 0.009023323962127586],
#  ['Tmin_Avril', 0.008570206589610125],
#  ['Tmin_Mai', 0.010599358791711566],
#  ['Tmin_Juin', 0.010842108878371715],
#  ['Tmin_Juill', 0.006242993854663393],
#  ['Tmin_Aout', 0.00816703054433279],
#  ['Tmin_Sept', 0.009639757477709248],
#  ['Tmin_Oct', 0.011158144046183866],
#  ['Tmin_Nov', 0.006080494738662461],
#  ['Tmin_Dec', 0.0012887700509589886],
#  ['Vap_Janv', 0.0003709537821050886],
#  ['Vap_Fev', 0.0006906801317477237],
#  ['Vap_Mars', 0.0008499744163933966],
#  ['Vap_Avril', 0.0012239966038433217],
#  ['Vap_Mai', 0.0009373113071949026],
#  ['Vap_Juin', 0.000629991621444252],
#  ['Vap_Juill', 5.528744458203711e-05],
#  ['Vap_Aout', 8.061948833983386e-06],
#  ['Vap_Sept', 4.518292573391878e-05],
#  ['Vap_Oct', 2.023077995404867e-05],
#  ['Vap_Nov', 2.042390637258196e-05],
#  ['Vap_Dec', 1.4418588867034668e-05],
#  ['Vent_Janv', 0.03391273957445586],
#  ['Vent_Fev', 0.048213825493191864],
#  ['Vent_Mars', 0.034674688200768654],
#  ['Vent_Avril', 0.025639151172401654],
#  ['Vent_Mai', 0.013873385001225952],
#  ['Vent_Juin', 0.008301280464058673],
#  ['Vent_Juill', 0.0013371366405948565],
#  ['Vent_Aout', 0.0014285221859750047],
#  ['Vent_Sept', 0.039924034735939966],
#  ['Vent_Oct', 0.05506998551098996],
#  ['Vent_Nov', 0.027257921415708892],
#  ['Vent_Dec', 0.055531332872018016]]

# %%
df1 = pd.DataFrame(lst, columns = ['variable','corrélation'])
print(df1)
# Out:
#       variable  corrélation
# 0       X_long     0.007123
# 1        Y_lat     0.007605
# 2       Bovins     0.001137
# 3     Volaille     0.001688
# 4      Caprins     0.006701
# ..         ...          ...
# 220  Vent_Aout     0.001429
# 221  Vent_Sept     0.039924
# 222   Vent_Oct     0.055070
# 223   Vent_Nov     0.027258
# 224   Vent_Dec     0.055531
#
# [225 rows x 2 columns]

# %%
df1.to_excel("cx_pipiens_corrélation.xlsx")

# %%
A=df1.sort_values(by=["corrélation"],ascending=False)

# %%
A
# Out:
#           variable   corrélation
# 116      Pente_Min  6.097180e-02
# 224       Vent_Dec  5.553133e-02
# 222       Vent_Oct  5.506999e-02
# 214       Vent_Fev  4.821383e-02
# 35      Amp3_TempJ  4.508491e-02
# ..             ...           ...
# 59       Var_TempN  1.309219e-06
# 5            Ovins  6.019469e-07
# 47      Amp1_TempN  6.319391e-08
# 37   VarT_bi_TempJ  0.000000e+00
# 16        VegInond           NaN
#
# [225 rows x 2 columns]

# %%
type(A)
# Out:
# pandas.core.frame.DataFrame

# %%
A["variable"][0:10]
# Out:
# 116     Pente_Min
# 224      Vent_Dec
# 222      Vent_Oct
# 214      Vent_Fev
# 35     Amp3_TempJ
# 185     Tmax_Sept
# 221     Vent_Sept
# 186      Tmax_Oct
# 215     Vent_Mars
# 213     Vent_Janv
# Name: variable, dtype: object

# %% [markdown]
# # Modélisation

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_neg =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_neg
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %% [markdown]
# # three-shold 10 %  (23 variables)

# %%
A["variable"][0:23]
# Out:
# 116           Pente_Min
# 224            Vent_Dec
# 222            Vent_Oct
# 214            Vent_Fev
# 35           Amp3_TempJ
# 185           Tmax_Sept
# 221           Vent_Sept
# 186            Tmax_Oct
# 215           Vent_Mars
# 213           Vent_Janv
# 122             IPT_Moy
# 184           Tmax_Aout
# 138            Bio_Tmax
# 183          Tmax_Juill
# 117           Pente_Moy
# 187            Tmax_Nov
# 223            Vent_Nov
# 111        Rugosite_Min
# 179           Tmax_Mars
# 216          Vent_Avril
# 120             IPT_Med
# 114           Pente_Max
# 110    Rugosite_Moyenne
# Name: variable, dtype: object

# %%
S10=A["variable"][0:23].values.tolist()

# %%
S10
# Out:
# ['Pente_Min',
#  'Vent_Dec',
#  'Vent_Oct',
#  'Vent_Fev',
#  'Amp3_TempJ',
#  'Tmax_Sept',
#  'Vent_Sept',
#  'Tmax_Oct',
#  'Vent_Mars',
#  'Vent_Janv',
#  'IPT_Moy',
#  'Tmax_Aout',
#  'Bio_Tmax',
#  'Tmax_Juill',
#  'Pente_Moy',
#  'Tmax_Nov',
#  'Vent_Nov',
#  'Rugosite_Min',
#  'Tmax_Mars',
#  'Vent_Avril',
#  'IPT_Med',
#  'Pente_Max',
#  'Rugosite_Moyenne']

# %%
XR10=X[S10]

# %%
XR10
# Out:
#      Pente_Min  Vent_Dec  Vent_Oct  Vent_Fev  Amp3_TempJ  Tmax_Sept  \
# 0     0.123749       4.9       5.4       5.6           7  26.500000
# 1     0.043752       3.8       4.3       4.1          31  29.200001
# 2     0.043752       3.8       4.3       4.1          31  29.200001
# 3     0.333201       3.8       4.2       4.2          33  29.400000
# 4     1.701891       3.9       4.6       4.5          23  29.400000
# ..         ...       ...       ...       ...         ...        ...
# 205   6.155148       3.1       3.3       3.5          12  25.799999
# 206   7.233225       3.8       4.3       4.7          13  24.600000
# 207   0.000000       3.4       3.1       3.6           0  26.400000
# 208   2.629093       3.5       3.7       3.9           8  26.100000
# 209   0.255113       3.9       3.5       4.4          14  26.100000
#
#      Vent_Sept   Tmax_Oct  Vent_Mars  Vent_Janv  ...  Tmax_Juill  Pente_Moy  \
# 0          6.3  26.000000        6.1        4.8  ...   25.200001   0.459993
# 1          5.7  27.600000        4.8        4.2  ...   28.600000   0.293817
# 2          5.7  27.600000        4.8        4.2  ...   28.600000   0.293817
# 3          5.6  27.799999        5.0        4.2  ...   28.700001   1.974215
# 4          5.7  27.799999        5.1        4.3  ...   28.799999   2.695184
# ..         ...        ...        ...        ...  ...         ...        ...
# 205        3.1  21.200001        3.6        3.3  ...   29.400000   8.070340
# 206        4.0  18.799999        5.0        4.0  ...   27.000000  21.158220
# 207        3.3  23.299999        3.7        3.6  ...   27.100000   1.656707
# 208        3.6  22.700001        3.9        3.4  ...   28.100000   5.326967
# 209        3.4  22.700001        4.2        3.6  ...   27.000000   1.493826
#
#       Tmax_Nov  Vent_Nov  Rugosite_Min  Tmax_Mars  Vent_Avril  IPT_Med  \
# 0    24.500000       5.5             3  22.700001         6.9  -0.1875
# 1    25.100000       3.7             2  24.000000         5.6  -0.5000
# 2    25.100000       3.7             2  24.000000         5.6  -0.5000
# 3    25.299999       3.6             8  24.100000         5.2  -3.7500
# 4    25.299999       3.8            18  24.200001         5.6  -0.6250
# ..         ...       ...           ...        ...         ...      ...
# 205  17.799999       3.2            62  18.000000         3.8  -2.7500
# 206  15.400000       3.9           148  14.900000         4.6  13.0625
# 207  20.000000       3.4             0  18.200001         3.7  -0.3125
# 208  19.400000       3.5            34  19.100000         3.9   1.0000
# 209  19.400000       3.8            12  18.500000         3.9  -0.1875
#
#      Pente_Max  Rugosite_Moyenne
# 0     1.043530               5.0
# 1     0.526827               4.0
# 2     0.526827               4.0
# 3     4.500561              18.0
# 4     3.416714              27.0
# ..         ...               ...
# 205  10.078780              83.5
# 206  30.126017             243.5
# 207   2.672656              22.5
# 208   8.719540              47.5
# 209   3.031543              18.5
#
# [210 rows x 23 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR10, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR10, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR10, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR10, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR10, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR10, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR10, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR10, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR10, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR10, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR10, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.66666667 0.71428571 0.69047619 0.61904762 0.66666667]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.68181818 0.78947368 0.68181818 0.77777778 0.625     ]
# moy_sensibilité: 0.71
# -------------------------------------------------
# spécificité : [0.65       0.65217391 0.7        0.5        0.72222222]
# moy_spécificité: 0.64
# -------------------------------------------------
# MCC : [0.33181818 0.4416476  0.38138504 0.28306926 0.34405118]
# MCC: 0.36
# -------------------------------------------------
# precision-po: [0.68181818 0.65217391 0.71428571 0.53846154 0.75      ]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.65       0.78947368 0.66666667 0.75       0.59090909]
# moy_precision-ne: 0.69
# -------------------------------------------------
# AUC : [0.64204545 0.77574371 0.83409091 0.74305556 0.69212963]
# moy_AUC: 0.74
# -------------------------------------------------
# VN : [13 15 14 12 13]
# VP : [15 15 15 14 15]
# FP : [ 7  8  6 12  5]
# FN : [7 4 7 4 9]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.57142857 0.61904762 0.64285714 0.5        0.54761905]
# moy_accuracy: 0.58
# -------------------------------------------------
# sensibilité : [0.63636364 0.47368421 0.59090909 0.33333333 0.5       ]
# moy_sensibilité: 0.51
# -------------------------------------------------
# spécificité : [0.5        0.73913043 0.7        0.625      0.61111111]
# moy_spécificité: 0.64
# -------------------------------------------------
# MCC : [ 0.13762047  0.22106232  0.29190593 -0.04303315  0.11047364]
# MCC: 0.14
# -------------------------------------------------
# precision-po: [0.58333333 0.6        0.68421053 0.4        0.63157895]
# moy_precision-po: 0.58
# -------------------------------------------------
# precision-ne : [0.55555556 0.62962963 0.60869565 0.55555556 0.47826087]
# moy_precision-ne: 0.57
# -------------------------------------------------
# AUC : [0.64204545 0.62929062 0.72954545 0.62268519 0.63425926]
# moy_AUC: 0.65
# -------------------------------------------------
# VN : [10 17 14 15 11]
# VP : [14  9 13  6 12]
# FP : [10  6  6  9  7]
# FN : [ 8 10  9 12 12]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.66666667 0.66666667 0.78571429 0.66666667 0.52380952]
# moy_accuracy: 0.66
# -------------------------------------------------
# sensibilité : [0.68181818 0.78947368 0.68181818 0.72222222 0.54166667]
# moy_sensibilité: 0.68
# -------------------------------------------------
# spécificité : [0.55       0.60869565 0.8        0.625      0.55555556]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [ 0.23373675  0.27618409  0.48346919  0.27618409 -0.11047364]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.65384615 0.56521739 0.83333333 0.54545455 0.58333333]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.68421053 0.77777778 0.70833333 0.71428571 0.47368421]
# moy_precision-ne: 0.67
# -------------------------------------------------
# AUC : [0.65340909 0.72768879 0.88181818 0.72222222 0.57638889]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [11 15 16 17  9]
# VP : [15 14 17 13 14]
# FP : [ 9  8  3 10  9]
# FN : [ 5  5  8  6 11]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.64285714 0.71428571 0.76190476 0.69047619 0.57142857]
# moy_accuracy: 0.68
# -------------------------------------------------
# sensibilité : [0.63636364 0.73684211 0.68181818 0.72222222 0.58333333]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.65       0.69565217 0.85       0.66666667 0.55555556]
# moy_spécificité: 0.68
# -------------------------------------------------
# MCC : [0.28603878 0.43052839 0.53671984 0.38490018 0.13762047]
# MCC: 0.36
# -------------------------------------------------
# precision-po: [0.66666667 0.66666667 0.83333333 0.61904762 0.63636364]
# moy_precision-po: 0.68
# -------------------------------------------------
# precision-ne : [0.61904762 0.76190476 0.70833333 0.76190476 0.5       ]
# moy_precision-ne: 0.67
# -------------------------------------------------
# AUC : [0.63068182 0.73913043 0.85454545 0.77777778 0.6412037 ]
# moy_AUC: 0.73
# -------------------------------------------------
# VN : [13 16 17 16 10]
# VP : [14 14 15 13 14]
# FP : [7 7 3 8 8]
# FN : [ 8  5  7  5 10]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.57142857 0.57142857 0.54761905 0.64285714 0.47619048]
# moy_accuracy: 0.56
# -------------------------------------------------
# sensibilité : [0.59090909 0.42105263 0.36363636 0.38888889 0.375     ]
# moy_sensibilité: 0.43
# -------------------------------------------------
# spécificité : [0.55       0.69565217 0.75       0.83333333 0.61111111]
# moy_spécificité: 0.69
# -------------------------------------------------
# MCC : [ 0.14090909  0.12122772  0.12276455  0.25012216 -0.01415346]
# MCC: 0.12
# -------------------------------------------------
# precision-po: [0.59090909 0.53333333 0.61538462 0.63636364 0.5625    ]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.55       0.59259259 0.51724138 0.64516129 0.42307692]
# moy_precision-ne: 0.55
# -------------------------------------------------
# AUC : [0.66704545 0.58810069 0.69204545 0.72800926 0.53240741]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [11 16 15 20 11]
# VP : [13  8  8  7  9]
# FP : [9 7 5 4 7]
# FN : [ 9 11 14 11 15]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.64285714 0.66666667 0.73809524 0.57142857 0.61904762]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.63636364 0.84210526 0.72727273 0.5        0.625     ]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.65       0.52173913 0.75       0.625      0.61111111]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.28603878 0.37794525 0.47673129 0.125      0.2339548 ]
# MCC: 0.30
# -------------------------------------------------
# precision-po: [0.66666667 0.59259259 0.76190476 0.5        0.68181818]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.61904762 0.8        0.71428571 0.625      0.55      ]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.67840909 0.67048055 0.7375     0.58680556 0.64930556]
# moy_AUC: 0.66
# -------------------------------------------------
# VN : [13 12 15 15 11]
# VP : [14 16 16  9 15]
# FP : [ 7 11  5  9  7]
# FN : [8 3 6 9 9]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 20 %  (45 variables)

# %%
A["variable"][0:45]
# Out:
# 116           Pente_Min
# 224            Vent_Dec
# 222            Vent_Oct
# 214            Vent_Fev
# 35           Amp3_TempJ
# 185           Tmax_Sept
# 221           Vent_Sept
# 186            Tmax_Oct
# 215           Vent_Mars
# 213           Vent_Janv
# 122             IPT_Moy
# 184           Tmax_Aout
# 138            Bio_Tmax
# 183          Tmax_Juill
# 117           Pente_Moy
# 187            Tmax_Nov
# 223            Vent_Nov
# 111        Rugosite_Min
# 179           Tmax_Mars
# 216          Vent_Avril
# 120             IPT_Med
# 114           Pente_Max
# 110    Rugosite_Moyenne
# 112        Rugosite_Moy
# 178            Tmax_Fev
# 180          Tmax_Avril
# 142        Bio_Tsec_Moy
# 135          Bio_Tj_Moy
# 115       Pente_Moyenne
# 143         Bio_Tch_Moy
# 109        Rugosite_Max
# 126              IR_Min
# 89           Sol_teneur
# 134          Bio_Ta_moy
# 181            Tmax_Mai
# 127              IR_Moy
# 105             Elev_sd
# 161           Prec_Sept
# 160           Prec_Aout
# 125              IR_Med
# 124              IR_Max
# 92          ProfAbs_Sub
# 141        Bio_Thum_Moy
# 57            Ph2_TempN
# 82              Min_EVI
# Name: variable, dtype: object

# %%
S20=A["variable"][0:45].values.tolist()

# %%
S20
# Out:
# ['Pente_Min',
#  'Vent_Dec',
#  'Vent_Oct',
#  'Vent_Fev',
#  'Amp3_TempJ',
#  'Tmax_Sept',
#  'Vent_Sept',
#  'Tmax_Oct',
#  'Vent_Mars',
#  'Vent_Janv',
#  'IPT_Moy',
#  'Tmax_Aout',
#  'Bio_Tmax',
#  'Tmax_Juill',
#  'Pente_Moy',
#  'Tmax_Nov',
#  'Vent_Nov',
#  'Rugosite_Min',
#  'Tmax_Mars',
#  'Vent_Avril',
#  'IPT_Med',
#  'Pente_Max',
#  'Rugosite_Moyenne',
#  'Rugosite_Moy',
#  'Tmax_Fev',
#  'Tmax_Avril',
#  'Bio_Tsec_Moy',
#  'Bio_Tj_Moy',
#  'Pente_Moyenne',
#  'Bio_Tch_Moy',
#  'Rugosite_Max',
#  'IR_Min',
#  'Sol_teneur',
#  'Bio_Ta_moy',
#  'Tmax_Mai',
#  'IR_Moy',
#  'Elev_sd',
#  'Prec_Sept',
#  'Prec_Aout',
#  'IR_Med',
#  'IR_Max',
#  'ProfAbs_Sub',
#  'Bio_Thum_Moy',
#  'Ph2_TempN',
#  'Min_EVI']

# %%
XR20=X[S20]

# %%
XR20
# Out:
#      Pente_Min  Vent_Dec  Vent_Oct  Vent_Fev  Amp3_TempJ  Tmax_Sept  \
# 0     0.123749       4.9       5.4       5.6           7  26.500000
# 1     0.043752       3.8       4.3       4.1          31  29.200001
# 2     0.043752       3.8       4.3       4.1          31  29.200001
# 3     0.333201       3.8       4.2       4.2          33  29.400000
# 4     1.701891       3.9       4.6       4.5          23  29.400000
# ..         ...       ...       ...       ...         ...        ...
# 205   6.155148       3.1       3.3       3.5          12  25.799999
# 206   7.233225       3.8       4.3       4.7          13  24.600000
# 207   0.000000       3.4       3.1       3.6           0  26.400000
# 208   2.629093       3.5       3.7       3.9           8  26.100000
# 209   0.255113       3.9       3.5       4.4          14  26.100000
#
#      Vent_Sept   Tmax_Oct  Vent_Mars  Vent_Janv  ...     IR_Moy   Elev_sd  \
# 0          6.3  26.000000        6.1        4.8  ...   1.968750  0.768013
# 1          5.7  27.600000        4.8        4.2  ...   1.375000  0.484123
# 2          5.7  27.600000        4.8        4.2  ...   1.375000  0.484123
# 3          5.6  27.799999        5.0        4.2  ...   7.515625  5.418429
# 4          5.7  27.799999        5.1        4.3  ...   8.593750  1.434780
# ..         ...        ...        ...        ...  ...        ...       ...
# 205        3.1  21.200001        3.6        3.3  ...  26.226562  2.598076
# 206        4.0  18.799999        5.0        4.0  ...  77.507812  9.931012
# 207        3.3  23.299999        3.7        3.6  ...   5.562500  1.363589
# 208        3.6  22.700001        3.9        3.4  ...  17.335938  4.723611
# 209        3.4  22.700001        4.2        3.6  ...   7.125000  1.235857
#
#      Prec_Sept  Prec_Aout   IR_Med   IR_Max  ProfAbs_Sub  Bio_Thum_Moy  \
# 0           15          3   1.6250    3.375         4143     22.050000
# 1            1          0   1.3750    2.125         1828     20.200000
# 2            1          0   1.3750    2.125         1828     20.200000
# 3            1          0   6.1250   15.125         6537     20.500000
# 4            1          0   8.7500   11.000          416     20.400000
# ..         ...        ...      ...      ...          ...           ...
# 205         13          2  26.6875   32.375         1446     10.650000
# 206         17          3  77.4375  109.250          898      9.016667
# 207         13          3   6.5000    8.500         3125     12.816667
# 208         16          2  16.4375   29.375          725     12.983333
# 209         19          2   6.8125   11.000         1408     13.916667
#
#      Ph2_TempN  Min_EVI
# 0          325     2839
# 1          321     2570
# 2          321     2570
# 3          319     2043
# 4          333     2363
# ..         ...      ...
# 205        135     3800
# 206        119     5028
# 207          0     3108
# 208        157     3339
# 209        185     2863
#
# [210 rows x 45 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR20, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR20, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR20, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR20, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR20, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR20, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR20, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR20, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR20, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR20, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR20, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.66666667 0.61904762 0.71428571 0.69047619 0.5952381 ]
# moy_accuracy: 0.66
# -------------------------------------------------
# sensibilité : [0.77272727 0.57894737 0.59090909 0.77777778 0.54166667]
# moy_sensibilité: 0.65
# -------------------------------------------------
# spécificité : [0.55       0.65217391 0.85       0.625      0.66666667]
# moy_spécificité: 0.67
# -------------------------------------------------
# MCC : [0.33190618 0.23112128 0.45344929 0.40046693 0.20713807]
# MCC: 0.32
# -------------------------------------------------
# precision-po: [0.65384615 0.57894737 0.8125     0.60869565 0.68421053]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.6875     0.65217391 0.65384615 0.78947368 0.52173913]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.6125     0.69565217 0.85909091 0.74305556 0.62962963]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [11 15 17 15 12]
# VP : [17 11 13 14 13]
# FP : [9 8 3 9 6]
# FN : [ 5  8  9  4 11]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.69047619 0.5952381  0.5952381  0.5952381  0.69047619]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.72727273 0.57894737 0.40909091 0.38888889 0.58333333]
# moy_sensibilité: 0.54
# -------------------------------------------------
# spécificité : [0.65       0.60869565 0.8        0.75       0.83333333]
# moy_spécificité: 0.73
# -------------------------------------------------
# MCC : [0.3785655  0.18700223 0.22588678 0.14867526 0.42008403]
# MCC: 0.27
# -------------------------------------------------
# precision-po: [0.69565217 0.55       0.69230769 0.53846154 0.82352941]
# moy_precision-po: 0.66
# -------------------------------------------------
# precision-ne : [0.68421053 0.63636364 0.55172414 0.62068966 0.6       ]
# moy_precision-ne: 0.62
# -------------------------------------------------
# AUC : [0.70795455 0.59267735 0.68636364 0.61111111 0.72685185]
# moy_AUC: 0.66
# -------------------------------------------------
# VN : [13 14 16 18 15]
# VP : [16 11  9  7 14]
# FP : [7 9 4 6 3]
# FN : [ 6  8 13 11 10]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.61904762 0.64285714 0.80952381 0.69047619 0.52380952]
# moy_accuracy: 0.66
# -------------------------------------------------
# sensibilité : [0.72727273 0.73684211 0.68181818 0.66666667 0.45833333]
# moy_sensibilité: 0.65
# -------------------------------------------------
# spécificité : [0.55       0.65217391 0.85       0.625      0.72222222]
# moy_spécificité: 0.68
# -------------------------------------------------
# MCC : [0.23636364 0.32723112 0.4948721  0.41666667 0.06944444]
# MCC: 0.31
# -------------------------------------------------
# precision-po: [0.625      0.59090909 0.88235294 0.52173913 0.61904762]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.66666667 0.64       0.75       0.75       0.43478261]
# moy_precision-ne: 0.65
# -------------------------------------------------
# AUC : [0.68977273 0.74370709 0.86590909 0.73148148 0.51157407]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [11 16 15 15 11]
# VP : [15 12 17 14 13]
# FP : [8 7 3 8 6]
# FN : [ 5  8  5  7 14]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.5952381  0.61904762 0.76190476 0.71428571 0.57142857]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.63636364 0.52631579 0.63636364 0.72222222 0.54166667]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.55       0.69565217 0.9        0.70833333 0.61111111]
# moy_spécificité: 0.69
# -------------------------------------------------
# MCC : [0.18700223 0.22507982 0.55161872 0.42662346 0.15138252]
# MCC: 0.31
# -------------------------------------------------
# precision-po: [0.60869565 0.58823529 0.875      0.65       0.65      ]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.57894737 0.64       0.69230769 0.77272727 0.5       ]
# moy_precision-ne: 0.64
# -------------------------------------------------
# AUC : [0.62386364 0.66819222 0.84772727 0.78703704 0.61805556]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [11 16 18 17 11]
# VP : [14 10 14 13 13]
# FP : [9 7 2 7 7]
# FN : [ 8  9  8  5 11]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.61904762 0.54761905 0.54761905 0.57142857 0.52380952]
# moy_accuracy: 0.56
# -------------------------------------------------
# sensibilité : [0.59090909 0.36842105 0.36363636 0.33333333 0.20833333]
# moy_sensibilité: 0.37
# -------------------------------------------------
# spécificité : [0.65       0.69565217 0.75       0.75       0.94444444]
# moy_spécificité: 0.76
# -------------------------------------------------
# MCC : [0.24090909 0.06765101 0.12276455 0.09128709 0.21606041]
# MCC: 0.15
# -------------------------------------------------
# precision-po: [0.65       0.5        0.61538462 0.5        0.83333333]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.59090909 0.57142857 0.51724138 0.6        0.47222222]
# moy_precision-ne: 0.55
# -------------------------------------------------
# AUC : [0.68977273 0.5812357  0.70227273 0.68865741 0.47453704]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [13 16 15 18 17]
# VP : [13  7  8  6  5]
# FP : [7 7 5 6 1]
# FN : [ 9 12 14 12 19]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.45238095 0.57142857 0.5        0.47619048 0.71428571]
# moy_accuracy: 0.54
# -------------------------------------------------
# sensibilité : [0.5        0.52631579 0.45454545 0.55555556 0.79166667]
# moy_sensibilité: 0.57
# -------------------------------------------------
# spécificité : [0.4        0.60869565 0.55       0.41666667 0.61111111]
# moy_spécificité: 0.52
# -------------------------------------------------
# MCC : [-0.10034266  0.13501144  0.00456103 -0.02777778  0.41045042]
# MCC: 0.08
# -------------------------------------------------
# precision-po: [0.47826087 0.52631579 0.52631579 0.41666667 0.73076923]
# moy_precision-po: 0.54
# -------------------------------------------------
# precision-ne : [0.42105263 0.60869565 0.47826087 0.55555556 0.6875    ]
# moy_precision-ne: 0.55
# -------------------------------------------------
# AUC : [0.50340909 0.53089245 0.48863636 0.52430556 0.75810185]
# moy_AUC: 0.56
# -------------------------------------------------
# VN : [ 8 14 11 10 11]
# VP : [11 10 10 10 19]
# FP : [12  9  9 14  7]
# FN : [11  9 12  8  5]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 40 %  (90 variables)

# %%
A["variable"][0:90]
# Out:
# 116       Pente_Min
# 224        Vent_Dec
# 222        Vent_Oct
# 214        Vent_Fev
# 35       Amp3_TempJ
#            ...
# 157        Prec_Mai
# 165        Rad_Janv
# 197       Tmin_Sept
# 174         Rad_Oct
# 102    Elev_Moyenne
# Name: variable, Length: 90, dtype: object

# %%
S40=A["variable"][0:90].values.tolist()

# %%
S40
# Out:
# ['Pente_Min',
#  'Vent_Dec',
#  'Vent_Oct',
#  'Vent_Fev',
#  'Amp3_TempJ',
#  'Tmax_Sept',
#  'Vent_Sept',
#  'Tmax_Oct',
#  'Vent_Mars',
#  'Vent_Janv',
#  'IPT_Moy',
#  'Tmax_Aout',
#  'Bio_Tmax',
#  'Tmax_Juill',
#  'Pente_Moy',
#  'Tmax_Nov',
#  'Vent_Nov',
#  'Rugosite_Min',
#  'Tmax_Mars',
#  'Vent_Avril',
#  'IPT_Med',
#  'Pente_Max',
#  'Rugosite_Moyenne',
#  'Rugosite_Moy',
#  'Tmax_Fev',
#  'Tmax_Avril',
#  'Bio_Tsec_Moy',
#  'Bio_Tj_Moy',
#  'Pente_Moyenne',
#  'Bio_Tch_Moy',
#  'Rugosite_Max',
#  'IR_Min',
#  'Sol_teneur',
#  'Bio_Ta_moy',
#  'Tmax_Mai',
#  'IR_Moy',
#  'Elev_sd',
#  'Prec_Sept',
#  'Prec_Aout',
#  'IR_Med',
#  'IR_Max',
#  'ProfAbs_Sub',
#  'Bio_Thum_Moy',
#  'Ph2_TempN',
#  'Min_EVI',
#  'Tmax_Dec',
#  'Rad_Avril',
#  'Moy_NDVI',
#  'Tmax_Janv',
#  'IPT_Max',
#  'Bio_Pre_sec',
#  'Tmax_Juin',
#  'Rugosite_sd',
#  'Rad_Nov',
#  'Min_NDVI',
#  'Max_NDVI',
#  'Bio_Pre_Qsec',
#  'Prob_R',
#  'Rad_Aout',
#  'Moy_EVI',
#  'Prec_Mars',
#  'Vent_Mai',
#  'IR_sd',
#  'Prec_Juill',
#  'ZoneAride',
#  'Equides',
#  'Bio_Pre_Qch',
#  'Ph2_TempJ',
#  'Sol_pH_KCL',
#  'Rad_Mars',
#  'Min_IRM',
#  'Prec_Janv',
#  'Elev_Max',
#  'Geom_unif',
#  'Prec_Fev',
#  'Tmin_Oct',
#  'Tmin_Juin',
#  'Rad_Dec',
#  'Tmin_Mai',
#  'Bio_Tfr_Moy',
#  'Substratum',
#  'Moy_IRM',
#  'Arbrisseau',
#  'Bio_Pre_Saison',
#  'Ph1_EVI',
#  'Prec_Mai',
#  'Rad_Janv',
#  'Tmin_Sept',
#  'Rad_Oct',
#  'Elev_Moyenne']

# %%
XR40=X[S40]

# %%
XR40
# Out:
#      Pente_Min  Vent_Dec  Vent_Oct  Vent_Fev  Amp3_TempJ  Tmax_Sept  \
# 0     0.123749       4.9       5.4       5.6           7  26.500000
# 1     0.043752       3.8       4.3       4.1          31  29.200001
# 2     0.043752       3.8       4.3       4.1          31  29.200001
# 3     0.333201       3.8       4.2       4.2          33  29.400000
# 4     1.701891       3.9       4.6       4.5          23  29.400000
# ..         ...       ...       ...       ...         ...        ...
# 205   6.155148       3.1       3.3       3.5          12  25.799999
# 206   7.233225       3.8       4.3       4.7          13  24.600000
# 207   0.000000       3.4       3.1       3.6           0  26.400000
# 208   2.629093       3.5       3.7       3.9           8  26.100000
# 209   0.255113       3.9       3.5       4.4          14  26.100000
#
#      Vent_Sept   Tmax_Oct  Vent_Mars  Vent_Janv  ...  Substratum  Moy_IRM  \
# 0          6.3  26.000000        6.1        4.8  ...         200     3340
# 1          5.7  27.600000        4.8        4.2  ...         199     4010
# 2          5.7  27.600000        4.8        4.2  ...         199     4010
# 3          5.6  27.799999        5.0        4.2  ...         200     3000
# 4          5.7  27.799999        5.1        4.3  ...         164     2490
# ..         ...        ...        ...        ...  ...         ...      ...
# 205        3.1  21.200001        3.6        3.3  ...         200     1910
# 206        4.0  18.799999        5.0        4.0  ...         183     1790
# 207        3.3  23.299999        3.7        3.6  ...         200     1830
# 208        3.6  22.700001        3.9        3.4  ...         200     2510
# 209        3.4  22.700001        4.2        3.6  ...         200     2340
#
#      Arbrisseau  Bio_Pre_Saison  Ph1_EVI  Prec_Mai  Rad_Janv  Tmin_Sept  \
# 0             0      105.140599      227         1     14965  19.200001
# 1             0       77.394709      232         0     13864  19.400000
# 2             0       77.394709      232         0     13864  19.400000
# 3             0       79.471941      421         0     13863  19.700001
# 4             0       80.226951      591         0     13834  19.500000
# ..          ...             ...      ...       ...       ...        ...
# 205           0       87.607802      282        33      9328  17.900000
# 206          11       82.705765      447        40      9364  17.400000
# 207          18       82.235406      223        25      9254  19.500000
# 208           0       78.149593      157        33      8910  19.700001
# 209           0       75.072807      254        39      9008  19.900000
#
#      Rad_Oct  Elev_Moyenne
# 0      18177           6.0
# 1      17092          69.0
# 2      17092          69.0
# 3      17075          16.5
# 4      17107          37.0
# ..       ...           ...
# 205    14416         556.0
# 206    14158         832.0
# 207    14672           9.0
# 208    13978          88.5
# 209    14358          52.5
#
# [210 rows x 90 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR40, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR40, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR40, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR40, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR40, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR40, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR40, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR40, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR40, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR40, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR40, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.64285714 0.54761905 0.64285714 0.57142857 0.61904762]
# moy_accuracy: 0.60
# -------------------------------------------------
# sensibilité : [0.63636364 0.52631579 0.63636364 0.66666667 0.45833333]
# moy_sensibilité: 0.58
# -------------------------------------------------
# spécificité : [0.65       0.56521739 0.65       0.5        0.83333333]
# moy_spécificité: 0.64
# -------------------------------------------------
# MCC : [0.28603878 0.0912206  0.28603878 0.16666667 0.30618622]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.66666667 0.5        0.66666667 0.5        0.78571429]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.61904762 0.59090909 0.61904762 0.66666667 0.53571429]
# moy_precision-ne: 0.61
# -------------------------------------------------
# AUC : [0.70340909 0.63615561 0.81363636 0.6712963  0.62731481]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [13 13 13 12 15]
# VP : [14 10 14 12 11]
# FP : [ 7 10  7 12  3]
# FN : [ 8  9  8  6 13]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.57142857 0.5952381  0.61904762 0.57142857 0.52380952]
# moy_accuracy: 0.58
# -------------------------------------------------
# sensibilité : [0.54545455 0.63157895 0.68181818 0.5        0.45833333]
# moy_sensibilité: 0.56
# -------------------------------------------------
# spécificité : [0.6        0.56521739 0.55       0.625      0.61111111]
# moy_spécificité: 0.59
# -------------------------------------------------
# MCC : [0.14545455 0.19612429 0.2339548  0.125      0.06944444]
# MCC: 0.15
# -------------------------------------------------
# precision-po: [0.6        0.54545455 0.625      0.5        0.61111111]
# moy_precision-po: 0.58
# -------------------------------------------------
# precision-ne : [0.54545455 0.65       0.61111111 0.625      0.45833333]
# moy_precision-ne: 0.58
# -------------------------------------------------
# AUC : [0.65113636 0.69565217 0.63636364 0.6412037  0.52546296]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [12 13 11 15 11]
# VP : [12 12 15  9 11]
# FP : [ 8 10  9  9  7]
# FN : [10  7  7  9 13]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.61904762 0.64285714 0.71428571 0.66666667 0.57142857]
# moy_accuracy: 0.64
# -------------------------------------------------
# sensibilité : [0.63636364 0.57894737 0.68181818 0.72222222 0.5       ]
# moy_sensibilité: 0.62
# -------------------------------------------------
# spécificité : [0.7        0.69565217 0.8        0.70833333 0.55555556]
# moy_spécificité: 0.69
# -------------------------------------------------
# MCC : [0.33636364 0.28278387 0.52727273 0.20713807 0.        ]
# MCC: 0.27
# -------------------------------------------------
# precision-po: [0.66666667 0.55       0.9        0.57142857 0.55555556]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.63157895 0.65217391 0.78947368 0.72727273 0.52173913]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.7125     0.71167048 0.89090909 0.72453704 0.57175926]
# moy_AUC: 0.72
# -------------------------------------------------
# VN : [13 14 16 17  9]
# VP : [14 11 16 13 13]
# FP : [ 7  7  5  7 10]
# FN : [ 6  8  5  4 12]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.64285714 0.64285714 0.76190476 0.69047619 0.61904762]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.68181818 0.57894737 0.72727273 0.77777778 0.58333333]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.6        0.69565217 0.8        0.625      0.66666667]
# moy_spécificité: 0.68
# -------------------------------------------------
# MCC : [0.28278387 0.27618409 0.52727273 0.40046693 0.24771685]
# MCC: 0.35
# -------------------------------------------------
# precision-po: [0.65217391 0.61111111 0.8        0.60869565 0.7       ]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.63157895 0.66666667 0.72727273 0.78947368 0.54545455]
# moy_precision-ne: 0.67
# -------------------------------------------------
# AUC : [0.68522727 0.71167048 0.87954545 0.74074074 0.63425926]
# moy_AUC: 0.73
# -------------------------------------------------
# VN : [12 16 16 15 12]
# VP : [15 11 16 14 14]
# FP : [8 7 4 9 6]
# FN : [ 7  8  6  4 10]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.66666667 0.54761905 0.54761905 0.5952381  0.5       ]
# moy_accuracy: 0.57
# -------------------------------------------------
# sensibilité : [0.59090909 0.36842105 0.36363636 0.38888889 0.16666667]
# moy_sensibilité: 0.38
# -------------------------------------------------
# spécificité : [0.75       0.69565217 0.75       0.75       0.94444444]
# moy_spécificité: 0.78
# -------------------------------------------------
# MCC : [0.34405118 0.06765101 0.12276455 0.14867526 0.16979054]
# MCC: 0.17
# -------------------------------------------------
# precision-po: [0.72222222 0.5        0.61538462 0.53846154 0.8       ]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.625      0.57142857 0.51724138 0.62068966 0.45945946]
# moy_precision-ne: 0.56
# -------------------------------------------------
# AUC : [0.70113636 0.60869565 0.69545455 0.71990741 0.45138889]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [15 16 15 18 17]
# VP : [13  7  8  7  4]
# FP : [5 7 5 6 1]
# FN : [ 9 12 14 11 20]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.61904762 0.52380952 0.73809524 0.66666667 0.57142857]
# moy_accuracy: 0.62
# -------------------------------------------------
# sensibilité : [0.59090909 0.52631579 0.63636364 0.61111111 0.625     ]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.65       0.52173913 0.85       0.70833333 0.5       ]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.24090909 0.04783649 0.4948721  0.31944444 0.125     ]
# MCC: 0.25
# -------------------------------------------------
# precision-po: [0.65       0.47619048 0.82352941 0.61111111 0.625     ]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.59090909 0.57142857 0.68       0.70833333 0.5       ]
# moy_precision-ne: 0.61
# -------------------------------------------------
# AUC : [0.65681818 0.60983982 0.78636364 0.71527778 0.59027778]
# moy_AUC: 0.67
# -------------------------------------------------
# VN : [13 12 17 17  9]
# VP : [13 10 14 11 15]
# FP : [ 7 11  3  7  9]
# FN : [9 9 8 7 9]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 50 %  (113 variables)

# %%
A["variable"][0:113]
# Out:
# 116      Pente_Min
# 224       Vent_Dec
# 222       Vent_Oct
# 214       Vent_Fev
# 35      Amp3_TempJ
#           ...
# 0           X_long
# 70        Ph1_NDVI
# 27         Max_IRM
# 10     Lesfeuillus
# 21        Amp3_IRM
# Name: variable, Length: 113, dtype: object

# %%
S50=A["variable"][0:113].values.tolist()

# %%
S50
# Out:
# ['Pente_Min',
#  'Vent_Dec',
#  'Vent_Oct',
#  'Vent_Fev',
#  'Amp3_TempJ',
#  'Tmax_Sept',
#  'Vent_Sept',
#  'Tmax_Oct',
#  'Vent_Mars',
#  'Vent_Janv',
#  'IPT_Moy',
#  'Tmax_Aout',
#  'Bio_Tmax',
#  'Tmax_Juill',
#  'Pente_Moy',
#  'Tmax_Nov',
#  'Vent_Nov',
#  'Rugosite_Min',
#  'Tmax_Mars',
#  'Vent_Avril',
#  'IPT_Med',
#  'Pente_Max',
#  'Rugosite_Moyenne',
#  'Rugosite_Moy',
#  'Tmax_Fev',
#  'Tmax_Avril',
#  'Bio_Tsec_Moy',
#  'Bio_Tj_Moy',
#  'Pente_Moyenne',
#  'Bio_Tch_Moy',
#  'Rugosite_Max',
#  'IR_Min',
#  'Sol_teneur',
#  'Bio_Ta_moy',
#  'Tmax_Mai',
#  'IR_Moy',
#  'Elev_sd',
#  'Prec_Sept',
#  'Prec_Aout',
#  'IR_Med',
#  'IR_Max',
#  'ProfAbs_Sub',
#  'Bio_Thum_Moy',
#  'Ph2_TempN',
#  'Min_EVI',
#  'Tmax_Dec',
#  'Rad_Avril',
#  'Moy_NDVI',
#  'Tmax_Janv',
#  'IPT_Max',
#  'Bio_Pre_sec',
#  'Tmax_Juin',
#  'Rugosite_sd',
#  'Rad_Nov',
#  'Min_NDVI',
#  'Max_NDVI',
#  'Bio_Pre_Qsec',
#  'Prob_R',
#  'Rad_Aout',
#  'Moy_EVI',
#  'Prec_Mars',
#  'Vent_Mai',
#  'IR_sd',
#  'Prec_Juill',
#  'ZoneAride',
#  'Equides',
#  'Bio_Pre_Qch',
#  'Ph2_TempJ',
#  'Sol_pH_KCL',
#  'Rad_Mars',
#  'Min_IRM',
#  'Prec_Janv',
#  'Elev_Max',
#  'Geom_unif',
#  'Prec_Fev',
#  'Tmin_Oct',
#  'Tmin_Juin',
#  'Rad_Dec',
#  'Tmin_Mai',
#  'Bio_Tfr_Moy',
#  'Substratum',
#  'Moy_IRM',
#  'Arbrisseau',
#  'Bio_Pre_Saison',
#  'Ph1_EVI',
#  'Prec_Mai',
#  'Rad_Janv',
#  'Tmin_Sept',
#  'Rad_Oct',
#  'Elev_Moyenne',
#  'Tmin_Mars',
#  'Prec_Nov',
#  'Elev_Moy',
#  'Sol_Sable',
#  'Ph2_NDVI',
#  'Tmin_Avril',
#  'Rad_Fev',
#  'Bio_Pre_Ann',
#  'Vent_Juin',
#  'Isoth',
#  'Tmin_Aout',
#  'Ph3_EVI',
#  'Max_EVI',
#  'VarT_tri_TempN',
#  'Pente_sd',
#  'Y_lat',
#  'Bio_Pre_Qhum',
#  'Tmin_Fev',
#  'X_long',
#  'Ph1_NDVI',
#  'Max_IRM',
#  'Lesfeuillus',
#  'Amp3_IRM']

# %%
XR50=X[S50]

# %%
XR50
# Out:
#      Pente_Min  Vent_Dec  Vent_Oct  Vent_Fev  Amp3_TempJ  Tmax_Sept  \
# 0     0.123749       4.9       5.4       5.6           7  26.500000
# 1     0.043752       3.8       4.3       4.1          31  29.200001
# 2     0.043752       3.8       4.3       4.1          31  29.200001
# 3     0.333201       3.8       4.2       4.2          33  29.400000
# 4     1.701891       3.9       4.6       4.5          23  29.400000
# ..         ...       ...       ...       ...         ...        ...
# 205   6.155148       3.1       3.3       3.5          12  25.799999
# 206   7.233225       3.8       4.3       4.7          13  24.600000
# 207   0.000000       3.4       3.1       3.6           0  26.400000
# 208   2.629093       3.5       3.7       3.9           8  26.100000
# 209   0.255113       3.9       3.5       4.4          14  26.100000
#
#      Vent_Sept   Tmax_Oct  Vent_Mars  Vent_Janv  ...  VarT_tri_TempN  \
# 0          6.3  26.000000        6.1        4.8  ...               0
# 1          5.7  27.600000        4.8        4.2  ...               1
# 2          5.7  27.600000        4.8        4.2  ...               1
# 3          5.6  27.799999        5.0        4.2  ...               0
# 4          5.7  27.799999        5.1        4.3  ...               1
# ..         ...        ...        ...        ...  ...             ...
# 205        3.1  21.200001        3.6        3.3  ...               0
# 206        4.0  18.799999        5.0        4.0  ...               0
# 207        3.3  23.299999        3.7        3.6  ...               0
# 208        3.6  22.700001        3.9        3.4  ...               0
# 209        3.4  22.700001        4.2        3.6  ...               0
#
#      Pente_sd      Y_lat  Bio_Pre_Qhum  Tmin_Fev     X_long  Ph1_NDVI  \
# 0    0.308601  23.794740            22      14.8 -15.911420       953
# 1    0.110143  27.132950            18      12.8 -13.188370       137
# 2    0.110143  27.132950            18      12.8 -13.188370       137
# 3    1.371832  27.157730            17      13.2 -13.167180       474
# 4    0.464678  27.165000            18      13.0 -13.207000       312
# ..        ...        ...           ...       ...        ...       ...
# 205  1.128258  35.266667           439       4.7  -5.333333       239
# 206  7.117875  35.348765           463       4.2  -5.218206        89
# 207  0.776164  35.466667           330      10.0  -6.033333       215
# 208  1.731205  35.566667           343       8.7  -5.366667       132
# 209  0.782154  35.759465           378       9.5  -5.833954       158
#
#      Max_IRM  Lesfeuillus  Amp3_IRM
# 0       3950            0        50
# 1       4660            0        50
# 2       4660            0        50
# 3       3540            0        10
# 4       3010            0        30
# ..       ...          ...       ...
# 205     2470            0        70
# 206     2080           23        20
# 207     2370            0        60
# 208     3120            0        10
# 209     3120            0        40
#
# [210 rows x 113 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR50, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR50, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR50, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR50, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR50, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR50, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR50, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR50, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR50, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR50, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR50, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.61904762 0.64285714 0.71428571 0.57142857 0.61904762]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.59090909 0.63157895 0.63636364 0.66666667 0.5       ]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.65       0.65217391 0.8        0.5        0.77777778]
# moy_spécificité: 0.68
# -------------------------------------------------
# MCC : [0.24090909 0.28278387 0.44038551 0.16666667 0.28306926]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.65       0.6        0.77777778 0.5        0.75      ]
# moy_precision-po: 0.66
# -------------------------------------------------
# precision-ne : [0.59090909 0.68181818 0.66666667 0.66666667 0.53846154]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.67840909 0.68421053 0.85227273 0.67361111 0.59490741]
# moy_AUC: 0.70
# -------------------------------------------------
# VN : [13 15 16 12 14]
# VP : [13 12 14 12 12]
# FP : [ 7  8  4 12  4]
# FN : [ 9  7  8  6 12]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.54761905 0.57142857 0.57142857 0.64285714 0.54761905]
# moy_accuracy: 0.58
# -------------------------------------------------
# sensibilité : [0.59090909 0.57894737 0.5        0.55555556 0.625     ]
# moy_sensibilité: 0.57
# -------------------------------------------------
# spécificité : [0.5        0.56521739 0.65       0.70833333 0.44444444]
# moy_spécificité: 0.57
# -------------------------------------------------
# MCC : [0.0912206  0.14350946 0.15138252 0.26605322 0.070014  ]
# MCC: 0.14
# -------------------------------------------------
# precision-po: [0.56521739 0.52380952 0.61111111 0.58823529 0.6       ]
# moy_precision-po: 0.58
# -------------------------------------------------
# precision-ne : [0.52631579 0.61904762 0.54166667 0.68       0.47058824]
# moy_precision-ne: 0.57
# -------------------------------------------------
# AUC : [0.61477273 0.66590389 0.62727273 0.63194444 0.50462963]
# moy_AUC: 0.61
# -------------------------------------------------
# VN : [10 13 13 17  8]
# VP : [13 11 11 10 15]
# FP : [10 10  7  7 10]
# FN : [ 9  8 11  8  9]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.64285714 0.64285714 0.78571429 0.64285714 0.57142857]
# moy_accuracy: 0.66
# -------------------------------------------------
# sensibilité : [0.68181818 0.52631579 0.77272727 0.66666667 0.58333333]
# moy_sensibilité: 0.65
# -------------------------------------------------
# spécificité : [0.65       0.65217391 0.75       0.70833333 0.61111111]
# moy_spécificité: 0.67
# -------------------------------------------------
# MCC : [ 0.28278387  0.27618409  0.47637221  0.36111111 -0.0138092 ]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.68181818 0.57894737 0.81818182 0.59090909 0.54545455]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.6        0.625      0.84210526 0.76190476 0.5       ]
# moy_precision-ne: 0.67
# -------------------------------------------------
# AUC : [0.69886364 0.76659039 0.84318182 0.77777778 0.58333333]
# moy_AUC: 0.73
# -------------------------------------------------
# VN : [13 14 16 15  7]
# VP : [14  9 15 15 12]
# FP : [ 7  7  5  7 10]
# FN : [ 7  7  3  6 10]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.52380952 0.66666667 0.73809524 0.69047619 0.61904762]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.5        0.57894737 0.68181818 0.77777778 0.54166667]
# moy_sensibilité: 0.62
# -------------------------------------------------
# spécificité : [0.55       0.73913043 0.8        0.625      0.72222222]
# moy_spécificité: 0.69
# -------------------------------------------------
# MCC : [0.05       0.32253706 0.48346919 0.40046693 0.26388889]
# MCC: 0.30
# -------------------------------------------------
# precision-po: [0.55       0.64705882 0.78947368 0.60869565 0.72222222]
# moy_precision-po: 0.66
# -------------------------------------------------
# precision-ne : [0.5        0.68       0.69565217 0.78947368 0.54166667]
# moy_precision-ne: 0.64
# -------------------------------------------------
# AUC : [0.65795455 0.70709382 0.82954545 0.71990741 0.63657407]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [11 17 16 15 13]
# VP : [11 11 15 14 13]
# FP : [9 6 4 9 5]
# FN : [11  8  7  4 11]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.64285714 0.57142857 0.54761905 0.5952381  0.52380952]
# moy_accuracy: 0.58
# -------------------------------------------------
# sensibilité : [0.54545455 0.36842105 0.40909091 0.38888889 0.29166667]
# moy_sensibilité: 0.40
# -------------------------------------------------
# spécificité : [0.75       0.73913043 0.7        0.75       0.83333333]
# moy_spécificité: 0.75
# -------------------------------------------------
# MCC : [0.30062324 0.11579411 0.11370705 0.14867526 0.14523688]
# MCC: 0.16
# -------------------------------------------------
# precision-po: [0.70588235 0.53846154 0.6        0.53846154 0.7       ]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.6        0.5862069  0.51851852 0.62068966 0.46875   ]
# moy_precision-ne: 0.56
# -------------------------------------------------
# AUC : [0.67954545 0.61556064 0.66022727 0.71527778 0.48611111]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [15 17 14 18 15]
# VP : [12  7  9  7  7]
# FP : [5 6 6 6 3]
# FN : [10 12 13 11 17]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.69047619 0.52380952 0.69047619 0.61904762 0.54761905]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.72727273 0.52631579 0.63636364 0.55555556 0.54166667]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.65       0.52173913 0.75       0.66666667 0.55555556]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.3785655  0.04783649 0.38768756 0.22222222 0.09622504]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.69565217 0.47619048 0.73684211 0.55555556 0.61904762]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.68421053 0.57142857 0.65217391 0.66666667 0.47619048]
# moy_precision-ne: 0.61
# -------------------------------------------------
# AUC : [0.69318182 0.59038902 0.76590909 0.70023148 0.64814815]
# moy_AUC: 0.68
# -------------------------------------------------
# VN : [13 12 15 16 10]
# VP : [16 10 14 10 13]
# FP : [ 7 11  5  8  8]
# FN : [ 6  9  8  8 11]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # log2  (7 variables)

# %%
A["variable"][0:7]
# Out:
# 116     Pente_Min
# 224      Vent_Dec
# 222      Vent_Oct
# 214      Vent_Fev
# 35     Amp3_TempJ
# 185     Tmax_Sept
# 221     Vent_Sept
# Name: variable, dtype: object

# %%
SL=A["variable"][0:7].values.tolist()

# %%
SL
# Out:
# ['Pente_Min',
#  'Vent_Dec',
#  'Vent_Oct',
#  'Vent_Fev',
#  'Amp3_TempJ',
#  'Tmax_Sept',
#  'Vent_Sept']

# %%
XRL=X[SL]

# %%
XRL
# Out:
#      Pente_Min  Vent_Dec  Vent_Oct  Vent_Fev  Amp3_TempJ  Tmax_Sept  Vent_Sept
# 0     0.123749       4.9       5.4       5.6           7  26.500000        6.3
# 1     0.043752       3.8       4.3       4.1          31  29.200001        5.7
# 2     0.043752       3.8       4.3       4.1          31  29.200001        5.7
# 3     0.333201       3.8       4.2       4.2          33  29.400000        5.6
# 4     1.701891       3.9       4.6       4.5          23  29.400000        5.7
# ..         ...       ...       ...       ...         ...        ...        ...
# 205   6.155148       3.1       3.3       3.5          12  25.799999        3.1
# 206   7.233225       3.8       4.3       4.7          13  24.600000        4.0
# 207   0.000000       3.4       3.1       3.6           0  26.400000        3.3
# 208   2.629093       3.5       3.7       3.9           8  26.100000        3.6
# 209   0.255113       3.9       3.5       4.4          14  26.100000        3.4
#
# [210 rows x 7 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XRL, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XRL, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XRL, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XRL, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XRL, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XRL, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XRL, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XRL, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XRL, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XRL, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XRL, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.5952381  0.61904762 0.71428571 0.5        0.73809524]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.59090909 0.52631579 0.77272727 0.55555556 0.66666667]
# moy_sensibilité: 0.62
# -------------------------------------------------
# spécificité : [0.6        0.69565217 0.65       0.45833333 0.83333333]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.19069252 0.22507982 0.42662346 0.0138092  0.49713136]
# MCC: 0.27
# -------------------------------------------------
# precision-po: [0.61904762 0.58823529 0.70833333 0.43478261 0.84210526]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.57142857 0.64       0.72222222 0.57894737 0.65217391]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.69659091 0.75743707 0.76136364 0.62731481 0.64351852]
# moy_AUC: 0.70
# -------------------------------------------------
# VN : [12 16 13 11 15]
# VP : [13 10 17 10 16]
# FP : [ 8  7  7 13  3]
# FN : [9 9 5 8 8]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.64285714 0.54761905 0.61904762 0.61904762 0.5952381 ]
# moy_accuracy: 0.60
# -------------------------------------------------
# sensibilité : [0.63636364 0.36842105 0.5        0.5        0.45833333]
# moy_sensibilité: 0.49
# -------------------------------------------------
# spécificité : [0.65       0.69565217 0.75       0.70833333 0.77777778]
# moy_spécificité: 0.72
# -------------------------------------------------
# MCC : [0.28603878 0.06765101 0.25711042 0.21230194 0.24385451]
# MCC: 0.21
# -------------------------------------------------
# precision-po: [0.66666667 0.5        0.6875     0.5625     0.73333333]
# moy_precision-po: 0.63
# -------------------------------------------------
# precision-ne : [0.61904762 0.57142857 0.57692308 0.65384615 0.51851852]
# moy_precision-ne: 0.59
# -------------------------------------------------
# AUC : [0.64204545 0.57894737 0.62727273 0.66435185 0.59953704]
# moy_AUC: 0.62
# -------------------------------------------------
# VN : [13 16 15 17 14]
# VP : [14  7 11  9 11]
# FP : [7 7 5 7 4]
# FN : [ 8 12 11  9 13]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.61904762 0.61904762 0.71428571 0.64285714 0.64285714]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.68181818 0.57894737 0.77272727 0.5        0.58333333]
# moy_sensibilité: 0.62
# -------------------------------------------------
# spécificité : [0.6        0.60869565 0.65       0.625      0.55555556]
# moy_spécificité: 0.61
# -------------------------------------------------
# MCC : [0.33190618 0.17951966 0.42662346 0.31944444 0.08285523]
# MCC: 0.27
# -------------------------------------------------
# precision-po: [0.66666667 0.64705882 0.75       0.58823529 0.71428571]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.53333333 0.65217391 0.66666667 0.625      0.52380952]
# moy_precision-ne: 0.60
# -------------------------------------------------
# AUC : [0.67386364 0.72997712 0.8        0.66898148 0.63194444]
# moy_AUC: 0.70
# -------------------------------------------------
# VN : [ 9 16 13 15 10]
# VP : [15 10 16 11 15]
# FP : [9 8 7 8 7]
# FN : [6 8 6 8 9]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.5952381  0.66666667 0.73809524 0.52380952 0.66666667]
# moy_accuracy: 0.64
# -------------------------------------------------
# sensibilité : [0.63636364 0.57894737 0.81818182 0.55555556 0.625     ]
# moy_sensibilité: 0.64
# -------------------------------------------------
# spécificité : [0.55       0.73913043 0.65       0.5        0.72222222]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.18700223 0.32253706 0.47637221 0.05504819 0.34405118]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.60869565 0.64705882 0.72       0.45454545 0.75      ]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.57894737 0.68       0.76470588 0.6        0.59090909]
# moy_precision-ne: 0.64
# -------------------------------------------------
# AUC : [0.69659091 0.73455378 0.80454545 0.62268519 0.70833333]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [11 17 13 12 13]
# VP : [14 11 18 10 15]
# FP : [ 9  6  7 12  5]
# FN : [8 8 4 8 9]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.57142857 0.54761905 0.57142857 0.66666667 0.64285714]
# moy_accuracy: 0.60
# -------------------------------------------------
# sensibilité : [0.40909091 0.31578947 0.36363636 0.5        0.5       ]
# moy_sensibilité: 0.42
# -------------------------------------------------
# spécificité : [0.75       0.73913043 0.8        0.79166667 0.83333333]
# moy_spécificité: 0.78
# -------------------------------------------------
# MCC : [0.16854997 0.0605089  0.18090681 0.30618622 0.34426519]
# MCC: 0.21
# -------------------------------------------------
# precision-po: [0.64285714 0.5        0.66666667 0.64285714 0.8       ]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.53571429 0.56666667 0.53333333 0.67857143 0.55555556]
# moy_precision-ne: 0.57
# -------------------------------------------------
# AUC : [0.6625     0.61327231 0.67727273 0.72222222 0.65509259]
# moy_AUC: 0.67
# -------------------------------------------------
# VN : [15 17 16 19 15]
# VP : [ 9  6  8  9 12]
# FP : [5 6 4 5 3]
# FN : [13 13 14  9 12]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.66666667 0.5952381  0.73809524 0.54761905 0.52380952]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.72727273 0.47368421 0.77272727 0.55555556 0.45833333]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.6        0.69565217 0.7        0.54166667 0.61111111]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.33028913 0.17355788 0.47434713 0.09622504 0.06944444]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.66666667 0.5625     0.73913043 0.47619048 0.61111111]
# moy_precision-po: 0.61
# -------------------------------------------------
# precision-ne : [0.66666667 0.61538462 0.73684211 0.61904762 0.45833333]
# moy_precision-ne: 0.62
# -------------------------------------------------
# AUC : [0.71818182 0.62585812 0.825      0.5150463  0.48032407]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [12 16 14 13 11]
# VP : [16  9 17 10 11]
# FP : [ 8  7  6 11  7]
# FN : [ 6 10  5  8 13]
# -------------------------------------------------
# -------------------------------------------------
