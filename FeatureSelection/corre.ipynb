# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/mois1-mois2/blob/main/FeatureSelection/corre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
def corr(x,y):
    moyenne_x = np.mean(x)
    classes = []
    for classe in y.unique():
        xi_classe = x[y==classe]
        classes.append({'ni': len(xi_classe),
                        'moyenne_classe': np.mean(xi_classe)})
    SCT = np.sum([(xj-moyenne_x)**2 for xj in x])
    SCE = np.sum([c['ni']*(c['moyenne_classe']-moyenne_x)**2 for c in classes])
    return SCE/SCT

# %% [markdown]
# # cs_longia

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data["Source"] 
del data["CodeSite"] 
data
# Out:
#         X_long      Y_lat  Cs_longia    Bovins    Volaille   Caprins  \
# 0   -15.911420  23.794740          1  0.000000    0.000000  0.000000
# 1   -13.188370  27.132950          1  0.000214    0.000000  0.063449
# 2   -13.188370  27.132950          1  0.000214    0.000000  0.063449
# 3   -13.185620  27.157940          0  0.000000    0.000000  0.000000
# 4   -13.167180  27.157730          0  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249  -5.366667  35.766667          1  8.495770  105.550156  8.691405
# 250  -5.816667  35.783333          1  0.000000    0.000000  0.000000
# 251  -5.366667  35.833333          1  7.411978  111.459663  7.364459
# 252  -5.558611  35.841944          1  5.696193    5.641273  0.602672
# 253  -5.483333  35.900000          1  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 249  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 250  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
# 251  -5.366667  35.833333  7.411978  111.459663  7.364459  15.054404
# 252  -5.558611  35.841944  5.696193    5.641273  0.602672   4.306276
# 253  -5.483333  35.900000  6.839514   15.082421  0.782080   6.042903
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.269410          0        100        0  ...        5.1         5.6
# 4    0.379107          0        100        0  ...        5.0         5.2
# ..        ...        ...        ...      ...  ...        ...         ...
# 249  0.698221          0          0        0  ...        4.6         4.3
# 250  1.725019          0          0        0  ...        4.6         4.1
# 251  0.991284          0          0        0  ...        4.5         4.3
# 252  0.000000          0          0       58  ...        4.6         4.0
# 253  0.595441          0          0        5  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 225 columns]

# %%
F=X.columns

# %%
F
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
lst=[]

# %%
for variable in F :
  x=X[variable]
  print("variable : ",variable,"/corrélation:",corr(x,y))
  lst.append([variable,corr(x,y)])
# Out:
# variable :  X_long /corrélation: 0.018035016584068687
# variable :  Y_lat /corrélation: 0.023606413275045663
# variable :  Bovins /corrélation: 0.014830724361901967
# variable :  Volaille /corrélation: 0.002499578851072806
# variable :  Caprins /corrélation: 0.008532686903290114
# variable :  Ovins /corrélation: 0.03256614341841968
# variable :  Equides /corrélation: 0.023241081313290262
# variable :  Coniferes /corrélation: 0.0035341826951984555
# variable :  ZoneAride /corrélation: 0.03921746847887352
# variable :  ZonePel /corrélation: 1.812860431903929e-05
# variable :  Lesfeuillus /corrélation: 0.00617430050320549
# variable :  Caduc /corrélation: 1.7195795627969148e-05
# variable :  Autres /corrélation: 0.0011837732470266005
# variable :  Arbrisseau /corrélation: 0.01710366465070794
# variable :  Pl_herb /corrélation: 0.01720742179181809
# variable :  VegCul /corrélation: 0.04358255904140737
# variable :  VegInond /corrélation: 0.0011649037789478592
# variable :  ZoneUrbaine /corrélation: 0.0027286369140562873
# variable :  Moy_IRM /corrélation: 0.05353265712232122
# variable :  Amp1_IRM /corrélation: 0.019157670014505725
# variable :  Amp2_IRM /corrélation: 0.0038117701238125127
# variable :  Amp3_IRM /corrélation: 0.04215957795441548
# variable :  VarT_ann_IRM /corrélation: 0.001571021143660946
# variable :  VarT_bi_IRM /corrélation: 0.0016083443569953476
# variable :  VarT_tri_IRM /corrélation: 0.00838894895790612
# variable :  VarT_Cy_IRM /corrélation: 0.0015057734501821671
# variable :  Min_IRM /corrélation: 0.0689620105125122
# variable :  Max_IRM /corrélation: 0.039253670711210664
# variable :  Ph1_IRM /corrélation: 0.031090448746006312
# variable :  Ph2_IRM /corrélation: 0.0005620313902782623
# variable :  Ph3_IRM /corrélation: 0.021953522049572443
# variable :  Var_IRM /corrélation: 0.022756005056890016
# variable :  Moy_TempJ /corrélation: 0.007576609281287213
# variable :  Amp1_TempJ /corrélation: 0.00043558283477332675
# variable :  Amp2_TempJ /corrélation: 0.028090383714013345
# variable :  Amp3_TempJ /corrélation: 0.11215544330024903
# variable :  VarT_ann_TempJ /corrélation: 0.0004652734441110614
# variable :  VarT_bi_TempJ /corrélation: 0.012026758970336652
# variable :  VarT_tri_TempJ /corrélation: 0.004705439488048185
# variable :  VarT_cy_TempJ /corrélation: 0.002334577844388318
# variable :  Min_TempJ /corrélation: 0.00818922495558938
# variable :  Max_TempJ /corrélation: 0.007054124150798878
# variable :  Ph1_TempJ /corrélation: 0.005439289108518907
# variable :  Ph2_TempJ /corrélation: 0.00041244545269403894
# variable :  Ph3_TempJ /corrélation: 0.006662683092963833
# variable :  Var_TempJ /corrélation: 0.0017950752903151041
# variable :  Moy_TempN /corrélation: 0.007203045140379597
# variable :  Amp1_TempN /corrélation: 7.382897647430278e-05
# variable :  Amp2_TempN /corrélation: 0.0366443733570036
# variable :  Amp3_TempN /corrélation: 6.0444435847902236e-05
# variable :  VarT_ann_TempN /corrélation: 1.1089937545166683e-05
# variable :  VarT_bi_TempN /corrélation: 0.0172442084222146
# variable :  VarT_tri_TempN /corrélation: 0.0010341261633919341
# variable :  VarT_cy_TempN /corrélation: 0.0005638890295909157
# variable :  Min_TempN /corrélation: 0.007499374194981148
# variable :  Max_TempN /corrélation: 0.007016694677842401
# variable :  Ph1_TempN /corrélation: 0.008297901363483537
# variable :  Ph2_TempN /corrélation: 5.2708510692829575e-05
# variable :  Ph3_TempN /corrélation: 0.029409467287328652
# variable :  Var_TempN /corrélation: 0.00034474193504453797
# variable :  Moy_NDVI /corrélation: 0.0354576758885103
# variable :  Amp1_NDVI /corrélation: 0.04755600317397195
# variable :  Amp2_NDVI /corrélation: 0.03687281692191885
# variable :  Amp3_NDVI /corrélation: 0.02939602720608111
# variable :  VarT_ann_NDVI /corrélation: 0.012585784423825935
# variable :  VarT_bi_NDVI /corrélation: 0.003617174886126464
# variable :  VarT_tri_NDVI /corrélation: 0.004430611497619921
# variable :  VarT_cy_NDVI /corrélation: 0.016542138652843718
# variable :  Min_NDVI /corrélation: 0.01918094288579935
# variable :  Max_NDVI /corrélation: 0.05271062189803721
# variable :  Ph1_NDVI /corrélation: 7.501635295516932e-06
# variable :  Ph2_NDVI /corrélation: 2.5172136611845936e-06
# variable :  Ph3_NDVI /corrélation: 0.002234480827946941
# variable :  Var_NDVI /corrélation: 0.05558553385268393
# variable :  Moy_EVI /corrélation: 0.028626589183256446
# variable :  Amp1_EVI /corrélation: 0.037796034920591574
# variable :  Amp2_EVI /corrélation: 0.033476621612422985
# variable :  Amp3_EVI /corrélation: 0.03745883064294013
# variable :  VarT_ann_EVI /corrélation: 0.013272489659470789
# variable :  VarT_bi_EVI /corrélation: 0.003774003774003773
# variable :  VarT_tri_EVI /corrélation: 0.007052147323765185
# variable :  VarT_cy_EVI /corrélation: 0.015244429248848335
# variable :  Min_EVI /corrélation: 0.012127447562695074
# variable :  Max_EVI /corrélation: 0.040968846686582
# variable :  Ph1_EVI /corrélation: 7.139867500422436e-07
# variable :  Ph2_EVI /corrélation: 0.002113399136176777
# variable :  Ph3_EVI /corrélation: 0.007115297434949406
# variable :  Var_EVI /corrélation: 0.03938334334137261
# variable :  Ret_eau /corrélation: 0.012428915884236225
# variable :  Sol_teneur /corrélation: 0.0018374644342417893
# variable :  Substratum /corrélation: 0.022770133559952967
# variable :  Prob_R /corrélation: 0.04391776082283815
# variable :  ProfAbs_Sub /corrélation: 0.011327491375546433
# variable :  CEC /corrélation: 0.01426504050045669
# variable :  Sol_Argile /corrélation: 0.00039705513641338823
# variable :  Sol_Carbone /corrélation: 0.011484204224463586
# variable :  Sol_Carbone_stock /corrélation: 0.005076397553127697
# variable :  Sol_Carbone_terreFine /corrélation: 0.002229168623369558
# variable :  Sol_pH_KCL /corrélation: 0.0022039164972702113
# variable :  Sol_Limon /corrélation: 0.01984107799612163
# variable :  Sol_Sable /corrélation: 0.02670118591055257
# variable :  Elev_Max /corrélation: 0.015614884946092877
# variable :  Elev_Moyenne /corrélation: 0.014353077065355197
# variable :  Elev_Min /corrélation: 0.012400970995858232
# variable :  Elev_Moy /corrélation: 0.014105469391896382
# variable :  Elev_sd /corrélation: 0.008759548655204102
# variable :  Geom_maj /corrélation: 0.007957426680862226
# variable :  Geom_Shan /corrélation: 0.0005778192049421957
# variable :  Geom_unif /corrélation: 0.0023726970401245946
# variable :  Rugosite_Max /corrélation: 0.012449635475361327
# variable :  Rugosite_Moyenne /corrélation: 0.015918982883064897
# variable :  Rugosite_Min /corrélation: 0.02017112248122916
# variable :  Rugosite_Moy /corrélation: 0.015840119330402646
# variable :  Rugosite_sd /corrélation: 0.007396921605036936
# variable :  Pente_Max /corrélation: 0.01384458785294139
# variable :  Pente_Moyenne /corrélation: 0.015225039633853426
# variable :  Pente_Min /corrélation: 0.01942919726070493
# variable :  Pente_Moy /corrélation: 0.016670748883797666
# variable :  Pente_sd /corrélation: 0.010046893434826924
# variable :  IPT_Max /corrélation: 0.010475840442125161
# variable :  IPT_Med /corrélation: 0.003107054613762725
# variable :  IPT_Min /corrélation: 0.009738183096133272
# variable :  IPT_Moy /corrélation: 5.993459948270709e-05
# variable :  IPT_sd /corrélation: 0.011332659227189172
# variable :  IR_Max /corrélation: 0.013542207641265479
# variable :  IR_Med /corrélation: 0.01357884080832969
# variable :  IR_Min /corrélation: 0.017699929268265115
# variable :  IR_Moy /corrélation: 0.015173145227896388
# variable :  IR_sd /corrélation: 0.005631879646503733
# variable :  RV_Max /corrélation: 0.007219835561973496
# variable :  RV_Med /corrélation: 0.0031027439428926392
# variable :  RV_Min /corrélation: 0.002603239584447924
# variable :  RV_Moy /corrélation: 0.004127996980816732
# variable :  RV_sd /corrélation: 0.00588109738357782
# variable :  Bio_Ta_moy /corrélation: 0.0028526160023376827
# variable :  Bio_Tj_Moy /corrélation: 0.002747310613230909
# variable :  Isoth /corrélation: 1.0566245794202693e-05
# variable :  Bio_Saison /corrélation: 0.0009194049611336583
# variable :  Bio_Tmax /corrélation: 0.009843548629276838
# variable :  Bio_Tmin /corrélation: 0.0002479108431654086
# variable :  Bio_Tint /corrélation: 0.002011114410955403
# variable :  Bio_Thum_Moy /corrélation: 0.003140148960243242
# variable :  Bio_Tsec_Moy /corrélation: 0.008957298645086138
# variable :  Bio_Tch_Moy /corrélation: 0.008521883677350042
# variable :  Bio_Tfr_Moy /corrélation: 0.0010384444162298485
# variable :  Bio_Pre_Ann /corrélation: 0.0019784516804478456
# variable :  Bio_Pre_hum /corrélation: 0.004413424751896077
# variable :  Bio_Pre_sec /corrélation: 0.007588788829302845
# variable :  Bio_Pre_Saison /corrélation: 4.4677135702156414e-05
# variable :  Bio_Pre_Qhum /corrélation: 0.0018378407512449953
# variable :  Bio_Pre_Qsec /corrélation: 0.0011593045618853983
# variable :  Bio_Pre_Qch /corrélation: 6.081014313187418e-05
# variable :  Bio_Pre_Qfr /corrélation: 0.0019462822398991647
# variable :  Prec_Janv /corrélation: 0.0008992442974956365
# variable :  Prec_Fev /corrélation: 0.00035828133880853587
# variable :  Prec_Mars /corrélation: 5.138676609205765e-07
# variable :  Prec_Avril /corrélation: 0.005580193397653113
# variable :  Prec_Mai /corrélation: 0.0032963174229654955
# variable :  Prec_Juin /corrélation: 0.00012077800755725207
# variable :  Prec_Juill /corrélation: 0.025536415835599867
# variable :  Prec_Aout /corrélation: 0.0007895970587509534
# variable :  Prec_Sept /corrélation: 1.0144881075617067e-05
# variable :  Prec_Oct /corrélation: 0.008117802195031323
# variable :  Prec_Nov /corrélation: 0.0016460316641005515
# variable :  Prec_Dec /corrélation: 0.005700229682576219
# variable :  Rad_Janv /corrélation: 0.022499212328357734
# variable :  Rad_Fev /corrélation: 0.02357618167018065
# variable :  Rad_Mars /corrélation: 0.013750731360232813
# variable :  Rad_Avril /corrélation: 0.004120076891502946
# variable :  Rad_Mai /corrélation: 0.011982025312655891
# variable :  Rad_Juin /corrélation: 0.015325832967506175
# variable :  Rad_Juill /corrélation: 0.015391823527749142
# variable :  Rad_Aout /corrélation: 0.005757829024806936
# variable :  Rad_Sept /corrélation: 1.495911697858652e-05
# variable :  Rad_Oct /corrélation: 0.02107421373478943
# variable :  Rad_Nov /corrélation: 0.01947075738757206
# variable :  Rad_Dec /corrélation: 0.022049972250504292
# variable :  Tmax_Janv /corrélation: 0.0012948225782254406
# variable :  Tmax_Fev /corrélation: 0.0018872745713975582
# variable :  Tmax_Mars /corrélation: 0.00019509905863204042
# variable :  Tmax_Avril /corrélation: 8.537347194985189e-05
# variable :  Tmax_Mai /corrélation: 0.0011335230088934298
# variable :  Tmax_Juin /corrélation: 0.0027269474857262214
# variable :  Tmax_Juill /corrélation: 0.009456590226651662
# variable :  Tmax_Aout /corrélation: 0.009542668856620223
# variable :  Tmax_Sept /corrélation: 0.01181574685242366
# variable :  Tmax_Oct /corrélation: 0.007414454224221443
# variable :  Tmax_Nov /corrélation: 0.0044995092613646995
# variable :  Tmax_Dec /corrélation: 0.0029435811729961164
# variable :  Tmin_Janv /corrélation: 0.00039024581787930096
# variable :  Tmin_Fev /corrélation: 0.0007482792130739721
# variable :  Tmin_Mars /corrélation: 1.2937614983428926e-05
# variable :  Tmin_Avril /corrélation: 3.129651350198562e-06
# variable :  Tmin_Mai /corrélation: 0.0006241933764101577
# variable :  Tmin_Juin /corrélation: 0.0034422393310297545
# variable :  Tmin_Juill /corrélation: 0.0034544027500693127
# variable :  Tmin_Aout /corrélation: 0.004050113354905964
# variable :  Tmin_Sept /corrélation: 0.003922439485984178
# variable :  Tmin_Oct /corrélation: 0.0017198600014045155
# variable :  Tmin_Nov /corrélation: 0.000368599284034404
# variable :  Tmin_Dec /corrélation: 5.5372031015818445e-05
# variable :  Vap_Janv /corrélation: 0.00535789544758633
# variable :  Vap_Fev /corrélation: 0.0048438037675369045
# variable :  Vap_Mars /corrélation: 0.004394186499133611
# variable :  Vap_Avril /corrélation: 0.0018223766298575317
# variable :  Vap_Mai /corrélation: 0.004569352303460274
# variable :  Vap_Juin /corrélation: 0.0058910907979365665
# variable :  Vap_Juill /corrélation: 0.008715922217208377
# variable :  Vap_Aout /corrélation: 0.008862126089235397
# variable :  Vap_Sept /corrélation: 0.006557557895700216
# variable :  Vap_Oct /corrélation: 0.0026779038224991726
# variable :  Vap_Nov /corrélation: 0.0027190440139840525
# variable :  Vap_Dec /corrélation: 0.0022950337983268635
# variable :  Vent_Janv /corrélation: 0.031995173423209074
# variable :  Vent_Fev /corrélation: 0.022015348608801978
# variable :  Vent_Mars /corrélation: 0.043194171115894894
# variable :  Vent_Avril /corrélation: 0.03256539329730113
# variable :  Vent_Mai /corrélation: 0.05219110771528597
# variable :  Vent_Juin /corrélation: 0.026662096308316386
# variable :  Vent_Juill /corrélation: 0.02129866077851152
# variable :  Vent_Aout /corrélation: 0.02951165006541225
# variable :  Vent_Sept /corrélation: 0.05953884299153794
# variable :  Vent_Oct /corrélation: 0.051577882335665556
# variable :  Vent_Nov /corrélation: 0.020077892797502387
# variable :  Vent_Dec /corrélation: 0.04735505975928694

# %%
lst
# Out:
# [['X_long', 0.018035016584068687],
#  ['Y_lat', 0.023606413275045663],
#  ['Bovins', 0.014830724361901967],
#  ['Volaille', 0.002499578851072806],
#  ['Caprins', 0.008532686903290114],
#  ['Ovins', 0.03256614341841968],
#  ['Equides', 0.023241081313290262],
#  ['Coniferes', 0.0035341826951984555],
#  ['ZoneAride', 0.03921746847887352],
#  ['ZonePel', 1.812860431903929e-05],
#  ['Lesfeuillus', 0.00617430050320549],
#  ['Caduc', 1.7195795627969148e-05],
#  ['Autres', 0.0011837732470266005],
#  ['Arbrisseau', 0.01710366465070794],
#  ['Pl_herb', 0.01720742179181809],
#  ['VegCul', 0.04358255904140737],
#  ['VegInond', 0.0011649037789478592],
#  ['ZoneUrbaine', 0.0027286369140562873],
#  ['Moy_IRM', 0.05353265712232122],
#  ['Amp1_IRM', 0.019157670014505725],
#  ['Amp2_IRM', 0.0038117701238125127],
#  ['Amp3_IRM', 0.04215957795441548],
#  ['VarT_ann_IRM', 0.001571021143660946],
#  ['VarT_bi_IRM', 0.0016083443569953476],
#  ['VarT_tri_IRM', 0.00838894895790612],
#  ['VarT_Cy_IRM', 0.0015057734501821671],
#  ['Min_IRM', 0.0689620105125122],
#  ['Max_IRM', 0.039253670711210664],
#  ['Ph1_IRM', 0.031090448746006312],
#  ['Ph2_IRM', 0.0005620313902782623],
#  ['Ph3_IRM', 0.021953522049572443],
#  ['Var_IRM', 0.022756005056890016],
#  ['Moy_TempJ', 0.007576609281287213],
#  ['Amp1_TempJ', 0.00043558283477332675],
#  ['Amp2_TempJ', 0.028090383714013345],
#  ['Amp3_TempJ', 0.11215544330024903],
#  ['VarT_ann_TempJ', 0.0004652734441110614],
#  ['VarT_bi_TempJ', 0.012026758970336652],
#  ['VarT_tri_TempJ', 0.004705439488048185],
#  ['VarT_cy_TempJ', 0.002334577844388318],
#  ['Min_TempJ', 0.00818922495558938],
#  ['Max_TempJ', 0.007054124150798878],
#  ['Ph1_TempJ', 0.005439289108518907],
#  ['Ph2_TempJ', 0.00041244545269403894],
#  ['Ph3_TempJ', 0.006662683092963833],
#  ['Var_TempJ', 0.0017950752903151041],
#  ['Moy_TempN', 0.007203045140379597],
#  ['Amp1_TempN', 7.382897647430278e-05],
#  ['Amp2_TempN', 0.0366443733570036],
#  ['Amp3_TempN', 6.0444435847902236e-05],
#  ['VarT_ann_TempN', 1.1089937545166683e-05],
#  ['VarT_bi_TempN', 0.0172442084222146],
#  ['VarT_tri_TempN', 0.0010341261633919341],
#  ['VarT_cy_TempN', 0.0005638890295909157],
#  ['Min_TempN', 0.007499374194981148],
#  ['Max_TempN', 0.007016694677842401],
#  ['Ph1_TempN', 0.008297901363483537],
#  ['Ph2_TempN', 5.2708510692829575e-05],
#  ['Ph3_TempN', 0.029409467287328652],
#  ['Var_TempN', 0.00034474193504453797],
#  ['Moy_NDVI', 0.0354576758885103],
#  ['Amp1_NDVI', 0.04755600317397195],
#  ['Amp2_NDVI', 0.03687281692191885],
#  ['Amp3_NDVI', 0.02939602720608111],
#  ['VarT_ann_NDVI', 0.012585784423825935],
#  ['VarT_bi_NDVI', 0.003617174886126464],
#  ['VarT_tri_NDVI', 0.004430611497619921],
#  ['VarT_cy_NDVI', 0.016542138652843718],
#  ['Min_NDVI', 0.01918094288579935],
#  ['Max_NDVI', 0.05271062189803721],
#  ['Ph1_NDVI', 7.501635295516932e-06],
#  ['Ph2_NDVI', 2.5172136611845936e-06],
#  ['Ph3_NDVI', 0.002234480827946941],
#  ['Var_NDVI', 0.05558553385268393],
#  ['Moy_EVI', 0.028626589183256446],
#  ['Amp1_EVI', 0.037796034920591574],
#  ['Amp2_EVI', 0.033476621612422985],
#  ['Amp3_EVI', 0.03745883064294013],
#  ['VarT_ann_EVI', 0.013272489659470789],
#  ['VarT_bi_EVI', 0.003774003774003773],
#  ['VarT_tri_EVI', 0.007052147323765185],
#  ['VarT_cy_EVI', 0.015244429248848335],
#  ['Min_EVI', 0.012127447562695074],
#  ['Max_EVI', 0.040968846686582],
#  ['Ph1_EVI', 7.139867500422436e-07],
#  ['Ph2_EVI', 0.002113399136176777],
#  ['Ph3_EVI', 0.007115297434949406],
#  ['Var_EVI', 0.03938334334137261],
#  ['Ret_eau', 0.012428915884236225],
#  ['Sol_teneur', 0.0018374644342417893],
#  ['Substratum', 0.022770133559952967],
#  ['Prob_R', 0.04391776082283815],
#  ['ProfAbs_Sub', 0.011327491375546433],
#  ['CEC', 0.01426504050045669],
#  ['Sol_Argile', 0.00039705513641338823],
#  ['Sol_Carbone', 0.011484204224463586],
#  ['Sol_Carbone_stock', 0.005076397553127697],
#  ['Sol_Carbone_terreFine', 0.002229168623369558],
#  ['Sol_pH_KCL', 0.0022039164972702113],
#  ['Sol_Limon', 0.01984107799612163],
#  ['Sol_Sable', 0.02670118591055257],
#  ['Elev_Max', 0.015614884946092877],
#  ['Elev_Moyenne', 0.014353077065355197],
#  ['Elev_Min', 0.012400970995858232],
#  ['Elev_Moy', 0.014105469391896382],
#  ['Elev_sd', 0.008759548655204102],
#  ['Geom_maj', 0.007957426680862226],
#  ['Geom_Shan', 0.0005778192049421957],
#  ['Geom_unif', 0.0023726970401245946],
#  ['Rugosite_Max', 0.012449635475361327],
#  ['Rugosite_Moyenne', 0.015918982883064897],
#  ['Rugosite_Min', 0.02017112248122916],
#  ['Rugosite_Moy', 0.015840119330402646],
#  ['Rugosite_sd', 0.007396921605036936],
#  ['Pente_Max', 0.01384458785294139],
#  ['Pente_Moyenne', 0.015225039633853426],
#  ['Pente_Min', 0.01942919726070493],
#  ['Pente_Moy', 0.016670748883797666],
#  ['Pente_sd', 0.010046893434826924],
#  ['IPT_Max', 0.010475840442125161],
#  ['IPT_Med', 0.003107054613762725],
#  ['IPT_Min', 0.009738183096133272],
#  ['IPT_Moy', 5.993459948270709e-05],
#  ['IPT_sd', 0.011332659227189172],
#  ['IR_Max', 0.013542207641265479],
#  ['IR_Med', 0.01357884080832969],
#  ['IR_Min', 0.017699929268265115],
#  ['IR_Moy', 0.015173145227896388],
#  ['IR_sd', 0.005631879646503733],
#  ['RV_Max', 0.007219835561973496],
#  ['RV_Med', 0.0031027439428926392],
#  ['RV_Min', 0.002603239584447924],
#  ['RV_Moy', 0.004127996980816732],
#  ['RV_sd', 0.00588109738357782],
#  ['Bio_Ta_moy', 0.0028526160023376827],
#  ['Bio_Tj_Moy', 0.002747310613230909],
#  ['Isoth', 1.0566245794202693e-05],
#  ['Bio_Saison', 0.0009194049611336583],
#  ['Bio_Tmax', 0.009843548629276838],
#  ['Bio_Tmin', 0.0002479108431654086],
#  ['Bio_Tint', 0.002011114410955403],
#  ['Bio_Thum_Moy', 0.003140148960243242],
#  ['Bio_Tsec_Moy', 0.008957298645086138],
#  ['Bio_Tch_Moy', 0.008521883677350042],
#  ['Bio_Tfr_Moy', 0.0010384444162298485],
#  ['Bio_Pre_Ann', 0.0019784516804478456],
#  ['Bio_Pre_hum', 0.004413424751896077],
#  ['Bio_Pre_sec', 0.007588788829302845],
#  ['Bio_Pre_Saison', 4.4677135702156414e-05],
#  ['Bio_Pre_Qhum', 0.0018378407512449953],
#  ['Bio_Pre_Qsec', 0.0011593045618853983],
#  ['Bio_Pre_Qch', 6.081014313187418e-05],
#  ['Bio_Pre_Qfr', 0.0019462822398991647],
#  ['Prec_Janv', 0.0008992442974956365],
#  ['Prec_Fev', 0.00035828133880853587],
#  ['Prec_Mars', 5.138676609205765e-07],
#  ['Prec_Avril', 0.005580193397653113],
#  ['Prec_Mai', 0.0032963174229654955],
#  ['Prec_Juin', 0.00012077800755725207],
#  ['Prec_Juill', 0.025536415835599867],
#  ['Prec_Aout', 0.0007895970587509534],
#  ['Prec_Sept', 1.0144881075617067e-05],
#  ['Prec_Oct', 0.008117802195031323],
#  ['Prec_Nov', 0.0016460316641005515],
#  ['Prec_Dec', 0.005700229682576219],
#  ['Rad_Janv', 0.022499212328357734],
#  ['Rad_Fev', 0.02357618167018065],
#  ['Rad_Mars', 0.013750731360232813],
#  ['Rad_Avril', 0.004120076891502946],
#  ['Rad_Mai', 0.011982025312655891],
#  ['Rad_Juin', 0.015325832967506175],
#  ['Rad_Juill', 0.015391823527749142],
#  ['Rad_Aout', 0.005757829024806936],
#  ['Rad_Sept', 1.495911697858652e-05],
#  ['Rad_Oct', 0.02107421373478943],
#  ['Rad_Nov', 0.01947075738757206],
#  ['Rad_Dec', 0.022049972250504292],
#  ['Tmax_Janv', 0.0012948225782254406],
#  ['Tmax_Fev', 0.0018872745713975582],
#  ['Tmax_Mars', 0.00019509905863204042],
#  ['Tmax_Avril', 8.537347194985189e-05],
#  ['Tmax_Mai', 0.0011335230088934298],
#  ['Tmax_Juin', 0.0027269474857262214],
#  ['Tmax_Juill', 0.009456590226651662],
#  ['Tmax_Aout', 0.009542668856620223],
#  ['Tmax_Sept', 0.01181574685242366],
#  ['Tmax_Oct', 0.007414454224221443],
#  ['Tmax_Nov', 0.0044995092613646995],
#  ['Tmax_Dec', 0.0029435811729961164],
#  ['Tmin_Janv', 0.00039024581787930096],
#  ['Tmin_Fev', 0.0007482792130739721],
#  ['Tmin_Mars', 1.2937614983428926e-05],
#  ['Tmin_Avril', 3.129651350198562e-06],
#  ['Tmin_Mai', 0.0006241933764101577],
#  ['Tmin_Juin', 0.0034422393310297545],
#  ['Tmin_Juill', 0.0034544027500693127],
#  ['Tmin_Aout', 0.004050113354905964],
#  ['Tmin_Sept', 0.003922439485984178],
#  ['Tmin_Oct', 0.0017198600014045155],
#  ['Tmin_Nov', 0.000368599284034404],
#  ['Tmin_Dec', 5.5372031015818445e-05],
#  ['Vap_Janv', 0.00535789544758633],
#  ['Vap_Fev', 0.0048438037675369045],
#  ['Vap_Mars', 0.004394186499133611],
#  ['Vap_Avril', 0.0018223766298575317],
#  ['Vap_Mai', 0.004569352303460274],
#  ['Vap_Juin', 0.0058910907979365665],
#  ['Vap_Juill', 0.008715922217208377],
#  ['Vap_Aout', 0.008862126089235397],
#  ['Vap_Sept', 0.006557557895700216],
#  ['Vap_Oct', 0.0026779038224991726],
#  ['Vap_Nov', 0.0027190440139840525],
#  ['Vap_Dec', 0.0022950337983268635],
#  ['Vent_Janv', 0.031995173423209074],
#  ['Vent_Fev', 0.022015348608801978],
#  ['Vent_Mars', 0.043194171115894894],
#  ['Vent_Avril', 0.03256539329730113],
#  ['Vent_Mai', 0.05219110771528597],
#  ['Vent_Juin', 0.026662096308316386],
#  ['Vent_Juill', 0.02129866077851152],
#  ['Vent_Aout', 0.02951165006541225],
#  ['Vent_Sept', 0.05953884299153794],
#  ['Vent_Oct', 0.051577882335665556],
#  ['Vent_Nov', 0.020077892797502387],
#  ['Vent_Dec', 0.04735505975928694]]

# %%
df1 = pd.DataFrame(lst, columns = ['variable','corrélation'])
print(df1)
# Out:
#       variable  corrélation
# 0       X_long     0.018035
# 1        Y_lat     0.023606
# 2       Bovins     0.014831
# 3     Volaille     0.002500
# 4      Caprins     0.008533
# ..         ...          ...
# 220  Vent_Aout     0.029512
# 221  Vent_Sept     0.059539
# 222   Vent_Oct     0.051578
# 223   Vent_Nov     0.020078
# 224   Vent_Dec     0.047355
#
# [225 rows x 2 columns]

# %%
df1.to_excel("cs_longia_corrélation.xlsx")

# %%
A=df1.sort_values(by=["corrélation"],ascending=False)

# %%
A
# Out:
#        variable   corrélation
# 35   Amp3_TempJ  1.121554e-01
# 26      Min_IRM  6.896201e-02
# 221   Vent_Sept  5.953884e-02
# 73     Var_NDVI  5.558553e-02
# 18      Moy_IRM  5.353266e-02
# ..          ...           ...
# 70     Ph1_NDVI  7.501635e-06
# 192  Tmin_Avril  3.129651e-06
# 71     Ph2_NDVI  2.517214e-06
# 84      Ph1_EVI  7.139868e-07
# 155   Prec_Mars  5.138677e-07
#
# [225 rows x 2 columns]

# %%
type(A)
# Out:
# pandas.core.frame.DataFrame

# %%
A["variable"][0:10]
# Out:
# 35     Amp3_TempJ
# 26        Min_IRM
# 221     Vent_Sept
# 73       Var_NDVI
# 18        Moy_IRM
# 69       Max_NDVI
# 217      Vent_Mai
# 222      Vent_Oct
# 61      Amp1_NDVI
# 224      Vent_Dec
# Name: variable, dtype: object

# %% [markdown]
# # Modélisation

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %% [markdown]
# # three-shold 10 %  (23 variables)

# %%
A["variable"][0:23]
# Out:
# 35     Amp3_TempJ
# 26        Min_IRM
# 221     Vent_Sept
# 73       Var_NDVI
# 18        Moy_IRM
# 69       Max_NDVI
# 217      Vent_Mai
# 222      Vent_Oct
# 61      Amp1_NDVI
# 224      Vent_Dec
# 91         Prob_R
# 15         VegCul
# 215     Vent_Mars
# 21       Amp3_IRM
# 83        Max_EVI
# 87        Var_EVI
# 27        Max_IRM
# 8       ZoneAride
# 75       Amp1_EVI
# 77       Amp3_EVI
# 62      Amp2_NDVI
# 48     Amp2_TempN
# 60       Moy_NDVI
# Name: variable, dtype: object

# %%
S10=A["variable"][0:23].values.tolist()

# %%
S10
# Out:
# ['Amp3_TempJ',
#  'Min_IRM',
#  'Vent_Sept',
#  'Var_NDVI',
#  'Moy_IRM',
#  'Max_NDVI',
#  'Vent_Mai',
#  'Vent_Oct',
#  'Amp1_NDVI',
#  'Vent_Dec',
#  'Prob_R',
#  'VegCul',
#  'Vent_Mars',
#  'Amp3_IRM',
#  'Max_EVI',
#  'Var_EVI',
#  'Max_IRM',
#  'ZoneAride',
#  'Amp1_EVI',
#  'Amp3_EVI',
#  'Amp2_NDVI',
#  'Amp2_TempN',
#  'Moy_NDVI']

# %%
XR10=X[S10]

# %%
XR10
# Out:
#      Amp3_TempJ  Min_IRM  Vent_Sept  Var_NDVI  Moy_IRM  Max_NDVI  Vent_Mai  \
# 0             7     2690        6.3         7     3340      1113       7.2
# 1            31     3350        5.7         1     4010      1090       5.7
# 2            31     3350        5.7         1     4010      1090       5.7
# 3            23     2930        5.7         1     3580      1094       5.5
# 4            33     2350        5.6        20     3000      1064       5.4
# ..          ...      ...        ...       ...      ...       ...       ...
# 249           5      880        4.0       100     1390      1604       4.1
# 250           1     1400        3.3        11     2050      1265       3.8
# 251           6     1080        3.9       155     1670      1612       4.0
# 252           0      620        3.6        61     1070      1375       3.8
# 253           2      990        4.0        85     1400      1566       3.9
#
#      Vent_Oct  Amp1_NDVI  Vent_Dec  ...  Amp3_IRM  Max_EVI  Var_EVI  Max_IRM  \
# 0         5.4          5       4.9  ...        50     2973        1     3950
# 1         4.3          6       3.8  ...        50     2648        0     4660
# 2         4.3          6       3.8  ...        50     2648        0     4660
# 3         4.1          4       3.9  ...        50     2599        0     4140
# 4         4.2          5       3.8  ...        10     2310       35     3540
# ..        ...        ...       ...  ...       ...      ...      ...      ...
# 249       4.0        102       4.2  ...        20     6090       47     1950
# 250       3.6         34       4.0  ...        10     3738        7     2690
# 251       4.0        161       4.3  ...        30     6066       70     2430
# 252       3.6         67       3.6  ...        10     4112       40     1530
# 253       4.0        115       4.2  ...        20     5324       39     1870
#
#      ZoneAride  Amp1_EVI  Amp3_EVI  Amp2_NDVI  Amp2_TempN  Moy_NDVI
# 0           97        13        15          4          44      1106
# 1          100        34         4          2          55      1082
# 2          100        34         4          2          55      1082
# 3          100        17         2          1          61      1090
# 4          100        85         6          4          58      1060
# ..         ...       ...       ...        ...         ...       ...
# 249          0       784       110         26          40      1512
# 250          0       182        59         10          26      1231
# 251          0      1050        99         28          27      1483
# 252          0       455        23         25           0      1284
# 253          0       590        93         26          19      1473
#
# [254 rows x 23 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR10, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR10, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR10, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR10, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR10, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR10, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR10, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR10, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR10, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR10, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR10, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.62745098 0.68627451 0.66666667 0.58823529 0.7       ]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.61290323 0.77272727 0.66666667 0.65       0.625     ]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.65       0.62068966 0.66666667 0.5483871  0.76923077]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.25676456 0.39157995 0.3286711  0.19405363 0.39905629]
# MCC: 0.31
# -------------------------------------------------
# precision-po: [0.73076923 0.60714286 0.74074074 0.48148148 0.71428571]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.52       0.7826087  0.58333333 0.70833333 0.68965517]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.68064516 0.7468652  0.72222222 0.68548387 0.72435897]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [13 18 14 17 20]
# VP : [19 17 20 13 15]
# FP : [ 7 11  7 14  6]
# FN : [12  5 10  7  9]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.64705882 0.74509804 0.68627451 0.68627451 0.66      ]
# moy_accuracy: 0.68
# -------------------------------------------------
# sensibilité : [0.58064516 0.90909091 0.66666667 0.7        0.54166667]
# moy_sensibilité: 0.68
# -------------------------------------------------
# spécificité : [0.75       0.62068966 0.71428571 0.67741935 0.76923077]
# moy_spécificité: 0.71
# -------------------------------------------------
# MCC : [0.32442557 0.53741591 0.37504578 0.36917519 0.32000133]
# MCC: 0.39
# -------------------------------------------------
# precision-po: [0.7826087  0.64516129 0.76923077 0.58333333 0.68421053]
# moy_precision-po: 0.69
# -------------------------------------------------
# precision-ne : [0.53571429 0.9        0.6        0.77777778 0.64516129]
# moy_precision-ne: 0.69
# -------------------------------------------------
# AUC : [0.76451613 0.72413793 0.69206349 0.81451613 0.59455128]
# moy_AUC: 0.72
# -------------------------------------------------
# VN : [15 18 15 21 20]
# VP : [18 20 20 14 13]
# FP : [ 5 11  6 10  6]
# FN : [13  2 10  6 11]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.62745098 0.60784314 0.66666667 0.68627451 0.68      ]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.51612903 0.68181818 0.7        0.65       0.58333333]
# moy_sensibilité: 0.63
# -------------------------------------------------
# spécificité : [0.8        0.62068966 0.61904762 0.70967742 0.84615385]
# moy_spécificité: 0.72
# -------------------------------------------------
# MCC : [0.29414776 0.2892778  0.29534856 0.3545673  0.27742513]
# MCC: 0.30
# -------------------------------------------------
# precision-po: [0.8        0.57692308 0.69230769 0.59090909 0.66666667]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.53333333 0.69230769 0.57692308 0.73333333 0.63636364]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.7016129  0.7531348  0.72698413 0.73225806 0.70032051]
# moy_AUC: 0.72
# -------------------------------------------------
# VN : [16 19 15 20 20]
# VP : [16 13 21 13 11]
# FP : [ 4 11  6 11  6]
# FN : [14  7 11  8 10]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.62745098 0.68627451 0.66666667 0.62745098 0.72      ]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.58064516 0.72727273 0.7        0.65       0.70833333]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.7        0.65517241 0.61904762 0.61290323 0.73076923]
# moy_spécificité: 0.66
# -------------------------------------------------
# MCC : [0.27451489 0.37889843 0.31704101 0.25676456 0.43910256]
# MCC: 0.33
# -------------------------------------------------
# precision-po: [0.75       0.61538462 0.72413793 0.52       0.70833333]
# moy_precision-po: 0.66
# -------------------------------------------------
# precision-ne : [0.51851852 0.76       0.59090909 0.73076923 0.73076923]
# moy_precision-ne: 0.67
# -------------------------------------------------
# AUC : [0.7016129  0.73902821 0.72698413 0.72903226 0.74358974]
# moy_AUC: 0.73
# -------------------------------------------------
# VN : [14 19 13 19 19]
# VP : [18 16 21 13 17]
# FP : [ 6 10  8 12  7]
# FN : [13  6  9  7  7]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.52941176 0.54901961 0.68627451 0.56862745 0.6       ]
# moy_accuracy: 0.59
# -------------------------------------------------
# sensibilité : [0.58064516 0.63636364 0.7        0.6        0.54166667]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.45       0.48275862 0.66666667 0.5483871  0.65384615]
# moy_spécificité: 0.56
# -------------------------------------------------
# MCC : [0.03020977 0.11912226 0.36265926 0.14492233 0.19677829]
# MCC: 0.17
# -------------------------------------------------
# precision-po: [0.62068966 0.48275862 0.75       0.46153846 0.59090909]
# moy_precision-po: 0.58
# -------------------------------------------------
# precision-ne : [0.40909091 0.63636364 0.60869565 0.68       0.60714286]
# moy_precision-ne: 0.59
# -------------------------------------------------
# AUC : [0.55967742 0.6653605  0.73174603 0.68064516 0.66987179]
# moy_AUC: 0.66
# -------------------------------------------------
# VN : [ 9 14 14 17 17]
# VP : [18 14 21 12 13]
# FP : [11 15  7 14  9]
# FN : [13  8  9  8 11]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.52941176 0.62745098 0.64705882 0.68627451 0.7       ]
# moy_accuracy: 0.64
# -------------------------------------------------
# sensibilité : [0.5483871  0.68181818 0.56666667 0.75       0.625     ]
# moy_sensibilité: 0.63
# -------------------------------------------------
# spécificité : [0.5        0.5862069  0.76190476 0.64516129 0.76923077]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.04733015 0.26594894 0.32650492 0.38593446 0.39905629]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.62962963 0.55555556 0.77272727 0.57692308 0.71428571]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.41666667 0.70833333 0.55172414 0.8        0.68965517]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.52741935 0.64263323 0.62857143 0.7        0.71073718]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [10 17 16 20 20]
# VP : [17 15 17 15 15]
# FP : [10 12  5 11  6]
# FN : [14  7 13  5  9]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 20 %  (45 variables)

# %%
A["variable"][0:45]
# Out:
# 35     Amp3_TempJ
# 26        Min_IRM
# 221     Vent_Sept
# 73       Var_NDVI
# 18        Moy_IRM
# 69       Max_NDVI
# 217      Vent_Mai
# 222      Vent_Oct
# 61      Amp1_NDVI
# 224      Vent_Dec
# 91         Prob_R
# 15         VegCul
# 215     Vent_Mars
# 21       Amp3_IRM
# 83        Max_EVI
# 87        Var_EVI
# 27        Max_IRM
# 8       ZoneAride
# 75       Amp1_EVI
# 77       Amp3_EVI
# 62      Amp2_NDVI
# 48     Amp2_TempN
# 60       Moy_NDVI
# 76       Amp2_EVI
# 5           Ovins
# 216    Vent_Avril
# 213     Vent_Janv
# 28        Ph1_IRM
# 220     Vent_Aout
# 58      Ph3_TempN
# 63      Amp3_NDVI
# 74        Moy_EVI
# 34     Amp2_TempJ
# 100     Sol_Sable
# 218     Vent_Juin
# 159    Prec_Juill
# 1           Y_lat
# 166       Rad_Fev
# 6         Equides
# 90     Substratum
# 31        Var_IRM
# 165      Rad_Janv
# 176       Rad_Dec
# 214      Vent_Fev
# 30        Ph3_IRM
# Name: variable, dtype: object

# %%
S20=A["variable"][0:45].values.tolist()

# %%
S20
# Out:
# ['Amp3_TempJ',
#  'Min_IRM',
#  'Vent_Sept',
#  'Var_NDVI',
#  'Moy_IRM',
#  'Max_NDVI',
#  'Vent_Mai',
#  'Vent_Oct',
#  'Amp1_NDVI',
#  'Vent_Dec',
#  'Prob_R',
#  'VegCul',
#  'Vent_Mars',
#  'Amp3_IRM',
#  'Max_EVI',
#  'Var_EVI',
#  'Max_IRM',
#  'ZoneAride',
#  'Amp1_EVI',
#  'Amp3_EVI',
#  'Amp2_NDVI',
#  'Amp2_TempN',
#  'Moy_NDVI',
#  'Amp2_EVI',
#  'Ovins',
#  'Vent_Avril',
#  'Vent_Janv',
#  'Ph1_IRM',
#  'Vent_Aout',
#  'Ph3_TempN',
#  'Amp3_NDVI',
#  'Moy_EVI',
#  'Amp2_TempJ',
#  'Sol_Sable',
#  'Vent_Juin',
#  'Prec_Juill',
#  'Y_lat',
#  'Rad_Fev',
#  'Equides',
#  'Substratum',
#  'Var_IRM',
#  'Rad_Janv',
#  'Rad_Dec',
#  'Vent_Fev',
#  'Ph3_IRM']

# %%
XR20=X[S20]

# %%
XR20
# Out:
#      Amp3_TempJ  Min_IRM  Vent_Sept  Var_NDVI  Moy_IRM  Max_NDVI  Vent_Mai  \
# 0             7     2690        6.3         7     3340      1113       7.2
# 1            31     3350        5.7         1     4010      1090       5.7
# 2            31     3350        5.7         1     4010      1090       5.7
# 3            23     2930        5.7         1     3580      1094       5.5
# 4            33     2350        5.6        20     3000      1064       5.4
# ..          ...      ...        ...       ...      ...       ...       ...
# 249           5      880        4.0       100     1390      1604       4.1
# 250           1     1400        3.3        11     2050      1265       3.8
# 251           6     1080        3.9       155     1670      1612       4.0
# 252           0      620        3.6        61     1070      1375       3.8
# 253           2      990        4.0        85     1400      1566       3.9
#
#      Vent_Oct  Amp1_NDVI  Vent_Dec  ...  Prec_Juill      Y_lat  Rad_Fev  \
# 0         5.4          5       4.9  ...           1  23.794740    17773
# 1         4.3          6       3.8  ...           0  27.132950    16620
# 2         4.3          6       3.8  ...           0  27.132950    16620
# 3         4.1          4       3.9  ...           0  27.157940    16659
# 4         4.2          5       3.8  ...           0  27.157730    16615
# ..        ...        ...       ...  ...         ...        ...      ...
# 249       4.0        102       4.2  ...           1  35.766667    11971
# 250       3.6         34       4.0  ...           1  35.783333    11863
# 251       4.0        161       4.3  ...           1  35.833333    11905
# 252       3.6         67       3.6  ...           1  35.841944    12046
# 253       4.0        115       4.2  ...           1  35.900000    11978
#
#       Equides  Substratum  Var_IRM  Rad_Janv  Rad_Dec  Vent_Fev  Ph3_IRM
# 0    0.624435         200        0     14965    13965       5.6      231
# 1    0.040295         199        0     13864    12663       4.1       49
# 2    0.040295         199        0     13864    12663       4.1       49
# 3    0.269410         166        0     13845    12642       4.5      106
# 4    0.379107         200       10     13863    12635       4.2       64
# ..        ...         ...      ...       ...      ...       ...      ...
# 249  0.698221         200        0      9145     8001       4.6      241
# 250  1.725019         200        0      8985     7808       4.3      146
# 251  0.991284         200        0      9113     7936       4.4      173
# 252  0.000000         200        0      9187     8016       3.9      247
# 253  0.595441         188        0      9191     7946       4.5      240
#
# [254 rows x 45 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR20, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR20, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR20, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR20, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR20, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR20, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR20, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR20, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR20, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR20, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR20, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.58823529 0.62745098 0.68627451 0.68627451 0.66      ]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.61290323 0.63636364 0.63333333 0.7        0.75      ]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.55       0.62068966 0.76190476 0.67741935 0.57692308]
# moy_spécificité: 0.64
# -------------------------------------------------
# MCC : [0.15983894 0.25466944 0.38971002 0.36917519 0.33092473]
# MCC: 0.30
# -------------------------------------------------
# precision-po: [0.67857143 0.56       0.79166667 0.58333333 0.62068966]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.47826087 0.69230769 0.59259259 0.77777778 0.71428571]
# moy_precision-ne: 0.65
# -------------------------------------------------
# AUC : [0.61774194 0.72884013 0.74285714 0.79516129 0.74038462]
# moy_AUC: 0.72
# -------------------------------------------------
# VN : [11 18 16 21 15]
# VP : [19 14 19 14 18]
# FP : [ 9 11  5 10 11]
# FN : [12  8 11  6  6]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.52941176 0.74509804 0.58823529 0.68627451 0.62      ]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.51612903 0.86363636 0.56666667 0.65       0.54166667]
# moy_sensibilité: 0.63
# -------------------------------------------------
# spécificité : [0.55       0.65517241 0.61904762 0.70967742 0.69230769]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.06458495 0.51880878 0.18283482 0.3545673  0.23683829]
# MCC: 0.27
# -------------------------------------------------
# precision-po: [0.64       0.65517241 0.68       0.59090909 0.61904762]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.42307692 0.86363636 0.5        0.75862069 0.62068966]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.60967742 0.74451411 0.65714286 0.80645161 0.66987179]
# moy_AUC: 0.70
# -------------------------------------------------
# VN : [11 19 13 22 18]
# VP : [16 19 17 13 13]
# FP : [ 9 10  8  9  8]
# FN : [15  3 13  7 11]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.64705882 0.60784314 0.68627451 0.68627451 0.58      ]
# moy_accuracy: 0.64
# -------------------------------------------------
# sensibilité : [0.48387097 0.68181818 0.56666667 0.7        0.58333333]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.8        0.5862069  0.71428571 0.83870968 0.61538462]
# moy_spécificité: 0.71
# -------------------------------------------------
# MCC : [0.20359278 0.14131048 0.32650492 0.38881244 0.23683829]
# MCC: 0.26
# -------------------------------------------------
# precision-po: [0.84210526 0.53846154 0.82608696 0.61904762 0.57894737]
# moy_precision-po: 0.68
# -------------------------------------------------
# precision-ne : [0.56666667 0.68       0.53333333 0.77419355 0.62068966]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.67580645 0.7492163  0.78253968 0.81612903 0.66025641]
# moy_AUC: 0.74
# -------------------------------------------------
# VN : [17 17 18 22 17]
# VP : [16 14 18 13 13]
# FP : [ 4 10  5  9  9]
# FN : [15  8 12  7 12]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.66666667 0.58823529 0.66666667 0.7254902  0.68      ]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.61290323 0.63636364 0.63333333 0.65       0.70833333]
# moy_sensibilité: 0.65
# -------------------------------------------------
# spécificité : [0.75       0.55172414 0.71428571 0.77419355 0.65384615]
# moy_spécificité: 0.69
# -------------------------------------------------
# MCC : [0.35497615 0.18663084 0.34222928 0.42419355 0.36217949]
# MCC: 0.33
# -------------------------------------------------
# precision-po: [0.79166667 0.51851852 0.76       0.65       0.65384615]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.55555556 0.66666667 0.57692308 0.77419355 0.70833333]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.71693548 0.70062696 0.74285714 0.78548387 0.77083333]
# moy_AUC: 0.74
# -------------------------------------------------
# VN : [15 16 15 24 17]
# VP : [19 14 19 13 17]
# FP : [ 5 13  6  7  9]
# FN : [12  8 11  7  7]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.52941176 0.52941176 0.7254902  0.58823529 0.56      ]
# moy_accuracy: 0.59
# -------------------------------------------------
# sensibilité : [0.5483871  0.63636364 0.73333333 0.55       0.54166667]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.5        0.44827586 0.71428571 0.61290323 0.57692308]
# moy_spécificité: 0.57
# -------------------------------------------------
# MCC : [0.04733015 0.0851752  0.44272689 0.15983894 0.11858974]
# MCC: 0.17
# -------------------------------------------------
# precision-po: [0.62962963 0.46666667 0.78571429 0.47826087 0.54166667]
# moy_precision-po: 0.58
# -------------------------------------------------
# precision-ne : [0.41666667 0.61904762 0.65217391 0.67857143 0.57692308]
# moy_precision-ne: 0.59
# -------------------------------------------------
# AUC : [0.58225806 0.65830721 0.72063492 0.66290323 0.67307692]
# moy_AUC: 0.66
# -------------------------------------------------
# VN : [10 13 15 19 15]
# VP : [17 14 22 11 13]
# FP : [10 16  6 12 11]
# FN : [14  8  8  9 11]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.50980392 0.60784314 0.45098039 0.62745098 0.6       ]
# moy_accuracy: 0.56
# -------------------------------------------------
# sensibilité : [0.38709677 0.72727273 0.43333333 0.55       0.45833333]
# moy_sensibilité: 0.51
# -------------------------------------------------
# spécificité : [0.7        0.51724138 0.47619048 0.67741935 0.73076923]
# moy_spécificité: 0.62
# -------------------------------------------------
# MCC : [ 0.08898252  0.24606168 -0.08921073  0.22560722  0.19682419]
# MCC: 0.13
# -------------------------------------------------
# precision-po: [0.66666667 0.53333333 0.54166667 0.52380952 0.61111111]
# moy_precision-po: 0.58
# -------------------------------------------------
# precision-ne : [0.42424242 0.71428571 0.37037037 0.7        0.59375   ]
# moy_precision-ne: 0.56
# -------------------------------------------------
# AUC : [0.56451613 0.59326019 0.47063492 0.6266129  0.58173077]
# moy_AUC: 0.57
# -------------------------------------------------
# VN : [14 15 10 21 19]
# VP : [12 16 13 11 11]
# FP : [ 6 14 11 10  7]
# FN : [19  6 17  9 13]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 40 %  (90 variables)

# %%
A["variable"][0:90]
# Out:
# 35      Amp3_TempJ
# 26         Min_IRM
# 221      Vent_Sept
# 73        Var_NDVI
# 18         Moy_IRM
#           ...
# 185      Tmax_Sept
# 95     Sol_Carbone
# 123         IPT_sd
# 92     ProfAbs_Sub
# 119        IPT_Max
# Name: variable, Length: 90, dtype: object

# %%
S40=A["variable"][0:90].values.tolist()

# %%
S40
# Out:
# ['Amp3_TempJ',
#  'Min_IRM',
#  'Vent_Sept',
#  'Var_NDVI',
#  'Moy_IRM',
#  'Max_NDVI',
#  'Vent_Mai',
#  'Vent_Oct',
#  'Amp1_NDVI',
#  'Vent_Dec',
#  'Prob_R',
#  'VegCul',
#  'Vent_Mars',
#  'Amp3_IRM',
#  'Max_EVI',
#  'Var_EVI',
#  'Max_IRM',
#  'ZoneAride',
#  'Amp1_EVI',
#  'Amp3_EVI',
#  'Amp2_NDVI',
#  'Amp2_TempN',
#  'Moy_NDVI',
#  'Amp2_EVI',
#  'Ovins',
#  'Vent_Avril',
#  'Vent_Janv',
#  'Ph1_IRM',
#  'Vent_Aout',
#  'Ph3_TempN',
#  'Amp3_NDVI',
#  'Moy_EVI',
#  'Amp2_TempJ',
#  'Sol_Sable',
#  'Vent_Juin',
#  'Prec_Juill',
#  'Y_lat',
#  'Rad_Fev',
#  'Equides',
#  'Substratum',
#  'Var_IRM',
#  'Rad_Janv',
#  'Rad_Dec',
#  'Vent_Fev',
#  'Ph3_IRM',
#  'Vent_Juill',
#  'Rad_Oct',
#  'Rugosite_Min',
#  'Vent_Nov',
#  'Sol_Limon',
#  'Rad_Nov',
#  'Pente_Min',
#  'Min_NDVI',
#  'Amp1_IRM',
#  'X_long',
#  'IR_Min',
#  'VarT_bi_TempN',
#  'Pl_herb',
#  'Arbrisseau',
#  'Pente_Moy',
#  'VarT_cy_NDVI',
#  'Rugosite_Moyenne',
#  'Rugosite_Moy',
#  'Elev_Max',
#  'Rad_Juill',
#  'Rad_Juin',
#  'VarT_cy_EVI',
#  'Pente_Moyenne',
#  'IR_Moy',
#  'Bovins',
#  'Elev_Moyenne',
#  'CEC',
#  'Elev_Moy',
#  'Pente_Max',
#  'Rad_Mars',
#  'IR_Med',
#  'IR_Max',
#  'VarT_ann_EVI',
#  'VarT_ann_NDVI',
#  'Rugosite_Max',
#  'Ret_eau',
#  'Elev_Min',
#  'Min_EVI',
#  'VarT_bi_TempJ',
#  'Rad_Mai',
#  'Tmax_Sept',
#  'Sol_Carbone',
#  'IPT_sd',
#  'ProfAbs_Sub',
#  'IPT_Max']

# %%
XR40=X[S40]

# %%
XR40
# Out:
#      Amp3_TempJ  Min_IRM  Vent_Sept  Var_NDVI  Moy_IRM  Max_NDVI  Vent_Mai  \
# 0             7     2690        6.3         7     3340      1113       7.2
# 1            31     3350        5.7         1     4010      1090       5.7
# 2            31     3350        5.7         1     4010      1090       5.7
# 3            23     2930        5.7         1     3580      1094       5.5
# 4            33     2350        5.6        20     3000      1064       5.4
# ..          ...      ...        ...       ...      ...       ...       ...
# 249           5      880        4.0       100     1390      1604       4.1
# 250           1     1400        3.3        11     2050      1265       3.8
# 251           6     1080        3.9       155     1670      1612       4.0
# 252           0      620        3.6        61     1070      1375       3.8
# 253           2      990        4.0        85     1400      1566       3.9
#
#      Vent_Oct  Amp1_NDVI  Vent_Dec  ...    Ret_eau  Elev_Min  Min_EVI  \
# 0         5.4          5       4.9  ...  15.416667         0     2839
# 1         4.3          6       3.8  ...  13.750000        60     2570
# 2         4.3          6       3.8  ...  13.750000        60     2570
# 3         4.1          4       3.9  ...  12.833333         7     2557
# 4         4.2          5       3.8  ...  15.666667       -49     2043
# ..        ...        ...       ...  ...        ...       ...      ...
# 249       4.0        102       4.2  ...  13.416667        35     4449
# 250       3.6         34       4.0  ...  14.166667        45     3247
# 251       4.0        161       4.3  ...  13.750000        48     3910
# 252       3.6         67       3.6  ...  14.416667         0     2999
# 253       4.0        115       4.2  ...  14.833333         7     4179
#
#      VarT_bi_TempJ  Rad_Mai  Tmax_Sept  Sol_Carbone     IPT_sd  ProfAbs_Sub  \
# 0               23    24920  26.500000    70.000000   1.531569         4143
# 1               12    24082  29.200001    42.333333   1.125434         1828
# 2               12    24082  29.200001    42.333333   1.125434         1828
# 3               11    24019  29.200001    59.333333   4.907189            0
# 4               10    24002  29.400000    45.166667   3.097851         6537
# ..             ...      ...        ...          ...        ...          ...
# 249              2    23341  25.700001   249.750000   7.943265            0
# 250              1    23582  25.700001   150.000000   3.477291          846
# 251              2    23425  25.600000   154.500000   9.801444         1729
# 252              0    23716  25.500000   178.000000  15.237539         2786
# 253              1    23699  24.799999   216.666667  27.734352         2264
#
#      IPT_Max
# 0      2.875
# 1      2.000
# 2      2.000
# 3      9.500
# 4      4.125
# ..       ...
# 249   26.875
# 250    5.375
# 251   19.750
# 252   39.125
# 253   66.125
#
# [254 rows x 90 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR40, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR40, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR40, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR40, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR40, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR40, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR40, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR40, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR40, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR40, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR40, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.60784314 0.70588235 0.70588235 0.70588235 0.68      ]
# moy_accuracy: 0.68
# -------------------------------------------------
# sensibilité : [0.51612903 0.77272727 0.7        0.6        0.75      ]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.75       0.65517241 0.71428571 0.77419355 0.61538462]
# moy_spécificité: 0.70
# -------------------------------------------------
# MCC : [0.26400845 0.42458515 0.40849122 0.3778682  0.36774959]
# MCC: 0.37
# -------------------------------------------------
# precision-po: [0.76190476 0.62962963 0.77777778 0.63157895 0.64285714]
# moy_precision-po: 0.69
# -------------------------------------------------
# precision-ne : [0.5        0.79166667 0.625      0.75       0.72727273]
# moy_precision-ne: 0.68
# -------------------------------------------------
# AUC : [0.70483871 0.7460815  0.75555556 0.72903226 0.72596154]
# moy_AUC: 0.73
# -------------------------------------------------
# VN : [15 19 15 24 16]
# VP : [16 17 21 12 18]
# FP : [ 5 10  6  7 10]
# FN : [15  5  9  8  6]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.49019608 0.64705882 0.54901961 0.70588235 0.64      ]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.41935484 0.81818182 0.56666667 0.6        0.5       ]
# moy_sensibilité: 0.58
# -------------------------------------------------
# spécificité : [0.6        0.51724138 0.52380952 0.77419355 0.76923077]
# moy_spécificité: 0.64
# -------------------------------------------------
# MCC : [0.01920061 0.3435988  0.08921073 0.3778682  0.28022427]
# MCC: 0.22
# -------------------------------------------------
# precision-po: [0.61904762 0.5625     0.62962963 0.63157895 0.66666667]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.4        0.78947368 0.45833333 0.75       0.625     ]
# moy_precision-ne: 0.60
# -------------------------------------------------
# AUC : [0.56774194 0.77115987 0.58888889 0.80806452 0.67467949]
# moy_AUC: 0.68
# -------------------------------------------------
# VN : [12 15 11 24 20]
# VP : [13 18 17 12 12]
# FP : [ 8 14 10  7  6]
# FN : [18  4 13  8 12]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.62745098 0.60784314 0.70588235 0.68627451 0.66      ]
# moy_accuracy: 0.66
# -------------------------------------------------
# sensibilité : [0.51612903 0.68181818 0.56666667 0.7        0.625     ]
# moy_sensibilité: 0.62
# -------------------------------------------------
# spécificité : [0.85       0.65517241 0.66666667 0.70967742 0.69230769]
# moy_spécificité: 0.71
# -------------------------------------------------
# MCC : [0.3983871  0.23245184 0.3579494  0.28871393 0.28022427]
# MCC: 0.31
# -------------------------------------------------
# precision-po: [0.8        0.6        0.82608696 0.54545455 0.63157895]
# moy_precision-po: 0.68
# -------------------------------------------------
# precision-ne : [0.53125    0.81818182 0.55555556 0.80769231 0.5862069 ]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.72419355 0.73510972 0.75555556 0.76451613 0.68429487]
# moy_AUC: 0.73
# -------------------------------------------------
# VN : [16 18 17 21 19]
# VP : [15 17 18 13 11]
# FP : [ 5 13  4  9  7]
# FN : [14  7 11  7 12]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.64705882 0.68627451 0.70588235 0.70588235 0.68      ]
# moy_accuracy: 0.69
# -------------------------------------------------
# sensibilité : [0.58064516 0.68181818 0.63333333 0.65       0.625     ]
# moy_sensibilité: 0.63
# -------------------------------------------------
# spécificité : [0.75       0.68965517 0.80952381 0.74193548 0.73076923]
# moy_spécificité: 0.74
# -------------------------------------------------
# MCC : [0.32442557 0.3685959  0.43801703 0.38881244 0.35807197]
# MCC: 0.38
# -------------------------------------------------
# precision-po: [0.7826087  0.625      0.82608696 0.61904762 0.68181818]
# moy_precision-po: 0.71
# -------------------------------------------------
# precision-ne : [0.53571429 0.74074074 0.60714286 0.76666667 0.67857143]
# moy_precision-ne: 0.67
# -------------------------------------------------
# AUC : [0.68387097 0.73981191 0.77777778 0.79193548 0.76121795]
# moy_AUC: 0.75
# -------------------------------------------------
# VN : [15 20 17 23 19]
# VP : [18 15 19 13 15]
# FP : [5 9 4 8 7]
# FN : [13  7 11  7  9]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.54901961 0.56862745 0.68627451 0.58823529 0.64      ]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.5483871  0.63636364 0.66666667 0.55       0.54166667]
# moy_sensibilité: 0.59
# -------------------------------------------------
# spécificité : [0.55       0.51724138 0.71428571 0.61290323 0.73076923]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.0960898  0.15288779 0.37504578 0.15983894 0.27783119]
# MCC: 0.21
# -------------------------------------------------
# precision-po: [0.65384615 0.5        0.76923077 0.47826087 0.65      ]
# moy_precision-po: 0.61
# -------------------------------------------------
# precision-ne : [0.44       0.65217391 0.6        0.67857143 0.63333333]
# moy_precision-ne: 0.60
# -------------------------------------------------
# AUC : [0.57580645 0.6645768  0.75793651 0.66290323 0.69551282]
# moy_AUC: 0.67
# -------------------------------------------------
# VN : [11 15 15 19 19]
# VP : [17 14 20 11 13]
# FP : [ 9 14  6 12  7]
# FN : [14  8 10  9 11]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.56862745 0.74509804 0.54901961 0.70588235 0.66      ]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.4516129  0.72727273 0.43333333 0.7        0.54166667]
# moy_sensibilité: 0.57
# -------------------------------------------------
# spécificité : [0.75       0.75862069 0.71428571 0.70967742 0.76923077]
# moy_spécificité: 0.74
# -------------------------------------------------
# MCC : [0.20359278 0.48362464 0.15026605 0.4019712  0.32000133]
# MCC: 0.31
# -------------------------------------------------
# precision-po: [0.73684211 0.69565217 0.68421053 0.60869565 0.68421053]
# moy_precision-po: 0.68
# -------------------------------------------------
# precision-ne : [0.46875    0.78571429 0.46875    0.78571429 0.64516129]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.5766129  0.80407524 0.60793651 0.775      0.64823718]
# moy_AUC: 0.68
# -------------------------------------------------
# VN : [15 22 15 22 20]
# VP : [14 16 13 14 13]
# FP : [5 7 6 9 6]
# FN : [17  6 17  6 11]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 50 %  (113 variables)

# %%
A["variable"][0:113]
# Out:
# 35      Amp3_TempJ
# 26         Min_IRM
# 221      Vent_Sept
# 73        Var_NDVI
# 18         Moy_IRM
#           ...
# 54       Min_TempN
# 186       Tmax_Oct
# 113    Rugosite_sd
# 129         RV_Max
# 46       Moy_TempN
# Name: variable, Length: 113, dtype: object

# %%
S50=A["variable"][0:113].values.tolist()

# %%
S50
# Out:
# ['Amp3_TempJ',
#  'Min_IRM',
#  'Vent_Sept',
#  'Var_NDVI',
#  'Moy_IRM',
#  'Max_NDVI',
#  'Vent_Mai',
#  'Vent_Oct',
#  'Amp1_NDVI',
#  'Vent_Dec',
#  'Prob_R',
#  'VegCul',
#  'Vent_Mars',
#  'Amp3_IRM',
#  'Max_EVI',
#  'Var_EVI',
#  'Max_IRM',
#  'ZoneAride',
#  'Amp1_EVI',
#  'Amp3_EVI',
#  'Amp2_NDVI',
#  'Amp2_TempN',
#  'Moy_NDVI',
#  'Amp2_EVI',
#  'Ovins',
#  'Vent_Avril',
#  'Vent_Janv',
#  'Ph1_IRM',
#  'Vent_Aout',
#  'Ph3_TempN',
#  'Amp3_NDVI',
#  'Moy_EVI',
#  'Amp2_TempJ',
#  'Sol_Sable',
#  'Vent_Juin',
#  'Prec_Juill',
#  'Y_lat',
#  'Rad_Fev',
#  'Equides',
#  'Substratum',
#  'Var_IRM',
#  'Rad_Janv',
#  'Rad_Dec',
#  'Vent_Fev',
#  'Ph3_IRM',
#  'Vent_Juill',
#  'Rad_Oct',
#  'Rugosite_Min',
#  'Vent_Nov',
#  'Sol_Limon',
#  'Rad_Nov',
#  'Pente_Min',
#  'Min_NDVI',
#  'Amp1_IRM',
#  'X_long',
#  'IR_Min',
#  'VarT_bi_TempN',
#  'Pl_herb',
#  'Arbrisseau',
#  'Pente_Moy',
#  'VarT_cy_NDVI',
#  'Rugosite_Moyenne',
#  'Rugosite_Moy',
#  'Elev_Max',
#  'Rad_Juill',
#  'Rad_Juin',
#  'VarT_cy_EVI',
#  'Pente_Moyenne',
#  'IR_Moy',
#  'Bovins',
#  'Elev_Moyenne',
#  'CEC',
#  'Elev_Moy',
#  'Pente_Max',
#  'Rad_Mars',
#  'IR_Med',
#  'IR_Max',
#  'VarT_ann_EVI',
#  'VarT_ann_NDVI',
#  'Rugosite_Max',
#  'Ret_eau',
#  'Elev_Min',
#  'Min_EVI',
#  'VarT_bi_TempJ',
#  'Rad_Mai',
#  'Tmax_Sept',
#  'Sol_Carbone',
#  'IPT_sd',
#  'ProfAbs_Sub',
#  'IPT_Max',
#  'Pente_sd',
#  'Bio_Tmax',
#  'IPT_Min',
#  'Tmax_Aout',
#  'Tmax_Juill',
#  'Bio_Tsec_Moy',
#  'Vap_Aout',
#  'Elev_sd',
#  'Vap_Juill',
#  'Caprins',
#  'Bio_Tch_Moy',
#  'VarT_tri_IRM',
#  'Ph1_TempN',
#  'Min_TempJ',
#  'Prec_Oct',
#  'Geom_maj',
#  'Bio_Pre_sec',
#  'Moy_TempJ',
#  'Min_TempN',
#  'Tmax_Oct',
#  'Rugosite_sd',
#  'RV_Max',
#  'Moy_TempN']

# %%
XR50=X[S50]

# %%
XR50
# Out:
#      Amp3_TempJ  Min_IRM  Vent_Sept  Var_NDVI  Moy_IRM  Max_NDVI  Vent_Mai  \
# 0             7     2690        6.3         7     3340      1113       7.2
# 1            31     3350        5.7         1     4010      1090       5.7
# 2            31     3350        5.7         1     4010      1090       5.7
# 3            23     2930        5.7         1     3580      1094       5.5
# 4            33     2350        5.6        20     3000      1064       5.4
# ..          ...      ...        ...       ...      ...       ...       ...
# 249           5      880        4.0       100     1390      1604       4.1
# 250           1     1400        3.3        11     2050      1265       3.8
# 251           6     1080        3.9       155     1670      1612       4.0
# 252           0      620        3.6        61     1070      1375       3.8
# 253           2      990        4.0        85     1400      1566       3.9
#
#      Vent_Oct  Amp1_NDVI  Vent_Dec  ...  Min_TempJ  Prec_Oct  Geom_maj  \
# 0         5.4          5       4.9  ...      14721         3         1
# 1         4.3          6       3.8  ...      14941         3         1
# 2         4.3          6       3.8  ...      14941         3         1
# 3         4.1          4       3.9  ...      14854         3         6
# 4         4.2          5       3.8  ...      14918         3         8
# ..        ...        ...       ...  ...        ...       ...       ...
# 249       4.0        102       4.2  ...      14387        59         6
# 250       3.6         34       4.0  ...      14350        76         6
# 251       4.0        161       4.3  ...      14385        61         5
# 252       3.6         67       3.6  ...          0        62         1
# 253       4.0        115       4.2  ...      14343        63         9
#
#      Bio_Pre_sec  Moy_TempJ  Min_TempN   Tmax_Oct  Rugosite_sd    RV_Max  \
# 0              0      14905      14309  26.000000     2.290435  0.000066
# 1              0      15360      14311  27.600000     1.268611  0.000019
# 2              0      15360      14311  27.600000     1.268611  0.000019
# 3              0      15264      14315  27.600000     6.422616  0.000410
# 4              0      15310      14309  27.799999    11.361772  0.000689
# ..           ...        ...        ...        ...          ...       ...
# 249            1      14903      14078  22.100000    10.976538  0.004252
# 250            1      14838      14120  22.400000     5.626041  0.000570
# 251            1      14819      14109  22.000000    11.835956  0.001527
# 252            1          0          0  22.299999    22.621546  0.005992
# 253            1      14703      14103  21.900000    41.477734  0.033557
#
#      Moy_TempN
# 0        14436
# 1        14516
# 2        14516
# 3        14512
# 4        14526
# ..         ...
# 249      14347
# 250      14419
# 251      14364
# 252          0
# 253      14360
#
# [254 rows x 113 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR50, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR50, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR50, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR50, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR50, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR50, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR50, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR50, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR50, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR50, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR50, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.64705882 0.64705882 0.62745098 0.70588235 0.74      ]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.61290323 0.77272727 0.66666667 0.7        0.75      ]
# moy_sensibilité: 0.70
# -------------------------------------------------
# spécificité : [0.7        0.55172414 0.57142857 0.70967742 0.73076923]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.30559708 0.32650492 0.23659777 0.4019712  0.48038446]
# MCC: 0.35
# -------------------------------------------------
# precision-po: [0.76       0.56666667 0.68965517 0.60869565 0.72      ]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.53846154 0.76190476 0.54545455 0.78571429 0.76      ]
# moy_precision-ne: 0.68
# -------------------------------------------------
# AUC : [0.66774194 0.73510972 0.72222222 0.7483871  0.76762821]
# moy_AUC: 0.73
# -------------------------------------------------
# VN : [14 16 12 22 19]
# VP : [19 17 20 14 18]
# FP : [ 6 13  9  9  7]
# FN : [12  5 10  6  6]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.52941176 0.66666667 0.60784314 0.76470588 0.6       ]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.51612903 0.72727273 0.63333333 0.7        0.5       ]
# moy_sensibilité: 0.62
# -------------------------------------------------
# spécificité : [0.55       0.62068966 0.57142857 0.80645161 0.69230769]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.06458495 0.34526705 0.202524   0.50645161 0.19611614]
# MCC: 0.26
# -------------------------------------------------
# precision-po: [0.64       0.59259259 0.67857143 0.7        0.6       ]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.42307692 0.75       0.52173913 0.80645161 0.6       ]
# moy_precision-ne: 0.62
# -------------------------------------------------
# AUC : [0.55967742 0.76332288 0.63650794 0.79032258 0.67147436]
# moy_AUC: 0.68
# -------------------------------------------------
# VN : [11 18 12 25 18]
# VP : [16 16 19 14 12]
# FP : [ 9 11  9  6  8]
# FN : [15  6 11  6 12]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.62745098 0.64705882 0.64705882 0.74509804 0.62      ]
# moy_accuracy: 0.66
# -------------------------------------------------
# sensibilité : [0.51612903 0.72727273 0.63333333 0.75       0.54166667]
# moy_sensibilité: 0.63
# -------------------------------------------------
# spécificité : [0.9        0.44827586 0.71428571 0.67741935 0.76923077]
# moy_spécificité: 0.70
# -------------------------------------------------
# MCC : [0.40513633 0.35893417 0.38971002 0.33710194 0.31794729]
# MCC: 0.36
# -------------------------------------------------
# precision-po: [0.83333333 0.59259259 0.75       0.60869565 0.65217391]
# moy_precision-po: 0.69
# -------------------------------------------------
# precision-ne : [0.5483871  0.75       0.57142857 0.79310345 0.7037037 ]
# moy_precision-ne: 0.67
# -------------------------------------------------
# AUC : [0.69677419 0.75862069 0.76507937 0.77096774 0.70032051]
# moy_AUC: 0.74
# -------------------------------------------------
# VN : [15 17 15 22 18]
# VP : [16 15 20 15 14]
# FP : [ 3 10  7  7  6]
# FN : [13  5 11  5  9]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.64705882 0.68627451 0.68627451 0.7254902  0.72      ]
# moy_accuracy: 0.69
# -------------------------------------------------
# sensibilité : [0.5483871  0.72727273 0.63333333 0.65       0.70833333]
# moy_sensibilité: 0.65
# -------------------------------------------------
# spécificité : [0.8        0.65517241 0.76190476 0.77419355 0.73076923]
# moy_spécificité: 0.74
# -------------------------------------------------
# MCC : [0.34561106 0.37889843 0.38971002 0.42419355 0.43910256]
# MCC: 0.40
# -------------------------------------------------
# precision-po: [0.80952381 0.61538462 0.79166667 0.65       0.70833333]
# moy_precision-po: 0.71
# -------------------------------------------------
# precision-ne : [0.53333333 0.76       0.59259259 0.77419355 0.73076923]
# moy_precision-ne: 0.68
# -------------------------------------------------
# AUC : [0.70241935 0.75548589 0.74126984 0.8016129  0.74358974]
# moy_AUC: 0.75
# -------------------------------------------------
# VN : [16 19 16 24 19]
# VP : [17 16 19 13 17]
# FP : [ 4 10  5  7  7]
# FN : [14  6 11  7  7]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.56862745 0.52941176 0.70588235 0.64705882 0.66      ]
# moy_accuracy: 0.62
# -------------------------------------------------
# sensibilité : [0.58064516 0.81818182 0.7        0.6        0.54166667]
# moy_sensibilité: 0.65
# -------------------------------------------------
# spécificité : [0.55       0.31034483 0.71428571 0.67741935 0.76923077]
# moy_spécificité: 0.60
# -------------------------------------------------
# MCC : [0.12779141 0.14606294 0.40849122 0.27347792 0.32000133]
# MCC: 0.26
# -------------------------------------------------
# precision-po: [0.66666667 0.47368421 0.77777778 0.54545455 0.68421053]
# moy_precision-po: 0.63
# -------------------------------------------------
# precision-ne : [0.45833333 0.69230769 0.625      0.72413793 0.64516129]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.58709677 0.69749216 0.76031746 0.7016129  0.71394231]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [11  9 15 21 20]
# VP : [18 18 21 12 13]
# FP : [ 9 20  6 10  6]
# FN : [13  4  9  8 11]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.56862745 0.74509804 0.54901961 0.7254902  0.66      ]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.4516129  0.72727273 0.43333333 0.7        0.54166667]
# moy_sensibilité: 0.57
# -------------------------------------------------
# spécificité : [0.75       0.75862069 0.71428571 0.74193548 0.76923077]
# moy_spécificité: 0.75
# -------------------------------------------------
# MCC : [0.20359278 0.48362464 0.15026605 0.43565668 0.32000133]
# MCC: 0.32
# -------------------------------------------------
# precision-po: [0.73684211 0.69565217 0.68421053 0.63636364 0.68421053]
# moy_precision-po: 0.69
# -------------------------------------------------
# precision-ne : [0.46875    0.78571429 0.46875    0.79310345 0.64516129]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.58709677 0.79310345 0.60634921 0.78225806 0.67788462]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [15 22 15 23 20]
# VP : [14 16 13 14 13]
# FP : [5 7 6 8 6]
# FN : [17  6 17  6 11]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # log2  (7 variables)

# %%
A["variable"][0:7]
# Out:
# 35     Amp3_TempJ
# 26        Min_IRM
# 221     Vent_Sept
# 73       Var_NDVI
# 18        Moy_IRM
# 69       Max_NDVI
# 217      Vent_Mai
# Name: variable, dtype: object

# %%
SL=A["variable"][0:7].values.tolist()

# %%
SL
# Out:
# ['Amp3_TempJ',
#  'Min_IRM',
#  'Vent_Sept',
#  'Var_NDVI',
#  'Moy_IRM',
#  'Max_NDVI',
#  'Vent_Mai']

# %%
XRL=X[SL]

# %%
XRL
# Out:
#      Amp3_TempJ  Min_IRM  Vent_Sept  Var_NDVI  Moy_IRM  Max_NDVI  Vent_Mai
# 0             7     2690        6.3         7     3340      1113       7.2
# 1            31     3350        5.7         1     4010      1090       5.7
# 2            31     3350        5.7         1     4010      1090       5.7
# 3            23     2930        5.7         1     3580      1094       5.5
# 4            33     2350        5.6        20     3000      1064       5.4
# ..          ...      ...        ...       ...      ...       ...       ...
# 249           5      880        4.0       100     1390      1604       4.1
# 250           1     1400        3.3        11     2050      1265       3.8
# 251           6     1080        3.9       155     1670      1612       4.0
# 252           0      620        3.6        61     1070      1375       3.8
# 253           2      990        4.0        85     1400      1566       3.9
#
# [254 rows x 7 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier( ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XRL, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XRL, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XRL, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XRL, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XRL, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XRL, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XRL, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XRL, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XRL, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XRL, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XRL, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.62745098 0.66666667 0.7254902  0.68627451 0.64      ]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.5483871  0.72727273 0.7        0.8        0.625     ]
# moy_sensibilité: 0.68
# -------------------------------------------------
# spécificité : [0.75       0.62068966 0.76190476 0.61290323 0.65384615]
# moy_spécificité: 0.68
# -------------------------------------------------
# MCC : [0.29414776 0.34526705 0.45474301 0.40513633 0.27884615]
# MCC: 0.36
# -------------------------------------------------
# precision-po: [0.77272727 0.59259259 0.80769231 0.57142857 0.625     ]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.51724138 0.75       0.64       0.82608696 0.65384615]
# moy_precision-ne: 0.68
# -------------------------------------------------
# AUC : [0.63467742 0.70924765 0.74444444 0.75483871 0.68189103]
# moy_AUC: 0.71
# -------------------------------------------------
# VN : [15 18 16 19 17]
# VP : [17 16 21 16 15]
# FP : [ 5 11  5 12  9]
# FN : [14  6  9  4  9]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.56862745 0.64705882 0.70588235 0.74509804 0.56      ]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.48387097 0.81818182 0.7        0.7        0.5       ]
# moy_sensibilité: 0.64
# -------------------------------------------------
# spécificité : [0.7        0.51724138 0.71428571 0.77419355 0.61538462]
# moy_spécificité: 0.66
# -------------------------------------------------
# MCC : [0.18240584 0.3435988  0.40849122 0.47041505 0.11613145]
# MCC: 0.30
# -------------------------------------------------
# precision-po: [0.71428571 0.5625     0.77777778 0.66666667 0.54545455]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.46666667 0.78947368 0.625      0.8        0.57142857]
# moy_precision-ne: 0.65
# -------------------------------------------------
# AUC : [0.6733871  0.72178683 0.82222222 0.75       0.62179487]
# moy_AUC: 0.72
# -------------------------------------------------
# VN : [14 15 15 24 16]
# VP : [15 18 21 14 12]
# FP : [ 6 14  6  7 10]
# FN : [16  4  9  6 12]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.68627451 0.62745098 0.70588235 0.64705882 0.66      ]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.5483871  0.63636364 0.66666667 0.6        0.54166667]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.85       0.65517241 0.71428571 0.70967742 0.73076923]
# moy_spécificité: 0.73
# -------------------------------------------------
# MCC : [0.26400845 0.24493248 0.23006977 0.30720983 0.35807197]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.86363636 0.58333333 0.79166667 0.57142857 0.73684211]
# moy_precision-po: 0.71
# -------------------------------------------------
# precision-ne : [0.5483871  0.66666667 0.54166667 0.71428571 0.68965517]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.71048387 0.76097179 0.72063492 0.74193548 0.67307692]
# moy_AUC: 0.72
# -------------------------------------------------
# VN : [18 19 14 20 20]
# VP : [16 14 17 12 15]
# FP : [ 5 10  7 12  7]
# FN : [14 10 13  8  9]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.62745098 0.62745098 0.62745098 0.60784314 0.66      ]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.51612903 0.68181818 0.6        0.6        0.625     ]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.85       0.55172414 0.66666667 0.64516129 0.69230769]
# moy_spécificité: 0.68
# -------------------------------------------------
# MCC : [0.31612903 0.27899687 0.26253205 0.24054969 0.31807321]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.84210526 0.55172414 0.69230769 0.52173913 0.65217391]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.53125    0.72727273 0.53846154 0.71428571 0.66666667]
# moy_precision-ne: 0.64
# -------------------------------------------------
# AUC : [0.66854839 0.69984326 0.67777778 0.67903226 0.71314103]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [17 16 14 20 18]
# VP : [16 15 18 12 15]
# FP : [ 3 13  7 11  8]
# FN : [15  6 12  8  9]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.52941176 0.58823529 0.70588235 0.64705882 0.66      ]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.38709677 0.68181818 0.63333333 0.55       0.41666667]
# moy_sensibilité: 0.53
# -------------------------------------------------
# spécificité : [0.75       0.51724138 0.80952381 0.70967742 0.88461538]
# moy_spécificité: 0.73
# -------------------------------------------------
# MCC : [0.14199046 0.19905956 0.43801703 0.25967742 0.34315712]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.70588235 0.51724138 0.82608696 0.55       0.76923077]
# moy_precision-po: 0.67
# -------------------------------------------------
# precision-ne : [0.44117647 0.68181818 0.60714286 0.70967742 0.62162162]
# moy_precision-ne: 0.61
# -------------------------------------------------
# AUC : [0.59435484 0.68730408 0.75873016 0.71612903 0.66826923]
# moy_AUC: 0.68
# -------------------------------------------------
# VN : [15 15 17 22 23]
# VP : [12 15 19 11 10]
# FP : [ 5 14  4  9  3]
# FN : [19  7 11  9 14]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.56862745 0.7254902  0.64705882 0.64705882 0.66      ]
# moy_accuracy: 0.65
# -------------------------------------------------
# sensibilité : [0.5483871  0.86363636 0.6        0.75       0.58333333]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.6        0.62068966 0.71428571 0.58064516 0.73076923]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.14492233 0.4873914  0.30988989 0.32442557 0.31794729]
# MCC: 0.32
# -------------------------------------------------
# precision-po: [0.68       0.63333333 0.75       0.53571429 0.66666667]
# moy_precision-po: 0.65
# -------------------------------------------------
# precision-ne : [0.46153846 0.85714286 0.55555556 0.7826087  0.65517241]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.56693548 0.72413793 0.6968254  0.70080645 0.67307692]
# moy_AUC: 0.67
# -------------------------------------------------
# VN : [12 18 15 18 19]
# VP : [17 19 18 15 14]
# FP : [ 8 11  6 13  7]
# FN : [14  3 12  5 10]
# -------------------------------------------------
# -------------------------------------------------
