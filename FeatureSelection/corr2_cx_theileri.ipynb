# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/mois1-mois2/blob/main/FeatureSelection/corr2_cx_theileri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
def corr(x,y):
    moyenne_x = np.mean(x)
    classes = []
    for classe in y.unique():
        xi_classe = x[y==classe]
        classes.append({'ni': len(xi_classe),
                        'moyenne_classe': np.mean(xi_classe)})
    SCT = np.sum([(xj-moyenne_x)**2 for xj in x])
    SCE = np.sum([c['ni']*(c['moyenne_classe']-moyenne_x)**2 for c in classes])
    return SCE/SCT

# %% [markdown]
# # cx_thrileri

# %%
Cl1 = '/content/classeurbb.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data["Source"] 
del data["CodeSite"] 
data
# Out:
#         X_long      Y_lat  Cx_theileri    Bovins    Volaille   Caprins  \
# 0   -15.911420  23.794740            0  0.000000    0.000000  0.000000
# 1   -13.188370  27.132950            0  0.000214    0.000000  0.063449
# 2   -13.188370  27.132950            0  0.000214    0.000000  0.063449
# 3   -13.185620  27.157940            1  0.000000    0.000000  0.000000
# 4   -13.167180  27.157730            0  0.000000    0.000000  0.000000
# ..         ...        ...          ...       ...         ...       ...
# 223  -5.283333  35.633333            1  0.000000    0.000000  0.000000
# 224  -5.325286  35.685852            1  7.352805  115.615433  7.495493
# 225  -5.833954  35.759465            1  0.000000    0.000000  0.000000
# 226  -5.366667  35.766667            1  8.495770  105.550156  8.691405
# 227  -5.816667  35.783333            1  0.000000    0.000000  0.000000
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 223   0.000000  0.576012          0          0  ...        4.6         4.2
# 224  18.920124  0.577831          0         21  ...        4.5         4.2
# 225   0.000000  1.795786          0          0  ...        4.2         3.9
# 226  15.116930  0.698221          0          0  ...        4.6         4.3
# 227   0.000000  1.725019          0          0  ...        4.6         4.1
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 223       4.1        4.1         4.0        3.8        3.9       3.9
# 224       4.2        4.1         4.0        4.1        4.0       4.0
# 225       3.7        3.7         3.6        3.3        3.4       3.5
# 226       4.1        3.9         3.9        4.1        4.0       4.0
# 227       3.8        3.7         3.7        3.7        3.3       3.6
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 223       3.4       3.8
# 224       3.9       4.3
# 225       3.8       3.9
# 226       4.0       4.2
# 227       3.8       4.0
#
# [228 rows x 226 columns]

# %%
X = data.loc[:, data.columns != 'Cx_theileri']
y = data.Cx_theileri

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 223  -5.283333  35.633333  0.000000    0.000000  0.000000   0.000000
# 224  -5.325286  35.685852  7.352805  115.615433  7.495493  18.920124
# 225  -5.833954  35.759465  0.000000    0.000000  0.000000   0.000000
# 226  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 227  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.269410          0        100        0  ...        5.1         5.6
# 4    0.379107          0        100        0  ...        5.0         5.2
# ..        ...        ...        ...      ...  ...        ...         ...
# 223  0.576012          0          0        3  ...        4.6         4.2
# 224  0.577831          0         21        1  ...        4.5         4.2
# 225  1.795786          0          0        0  ...        4.2         3.9
# 226  0.698221          0          0        0  ...        4.6         4.3
# 227  1.725019          0          0        0  ...        4.6         4.1
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 223       4.1        4.1         4.0        3.8        3.9       3.9
# 224       4.2        4.1         4.0        4.1        4.0       4.0
# 225       3.7        3.7         3.6        3.3        3.4       3.5
# 226       4.1        3.9         3.9        4.1        4.0       4.0
# 227       3.8        3.7         3.7        3.7        3.3       3.6
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 223       3.4       3.8
# 224       3.9       4.3
# 225       3.8       3.9
# 226       4.0       4.2
# 227       3.8       4.0
#
# [228 rows x 225 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 223    1
# 224    1
# 225    1
# 226    1
# 227    1
# Name: Cx_theileri, Length: 228, dtype: int64

# %%
F=X.columns

# %%
F
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
lst=[]

# %%
for variable in F :
  x=X[variable]
  print("variable : ",variable,"/corrélation:",corr(x,y))
  lst.append([variable,corr(x,y)])
# Out:
# variable :  X_long /corrélation: 0.033446661786267616
# variable :  Y_lat /corrélation: 0.04992229920957633
# variable :  Bovins /corrélation: 4.4551994069963336e-05
# variable :  Volaille /corrélation: 0.008508171096232201
# variable :  Caprins /corrélation: 0.0072081645804304775
# variable :  Ovins /corrélation: 0.0028138572716238553
# variable :  Equides /corrélation: 0.0008924619875205346
# variable :  Coniferes /corrélation: 0.002587214562741175
# variable :  ZoneAride /corrélation: 0.008450166364495436
# variable :  ZonePel /corrélation: 0.001082090971726146
# variable :  Lesfeuillus /corrélation: 0.015006768668652335
# variable :  Caduc /corrélation: 0.004811923365109105
# variable :  Autres /corrélation: 0.004196650944679164
# variable :  Arbrisseau /corrélation: 0.011428517571002572
# variable :  Pl_herb /corrélation: 0.016671577674043512
# variable :  VegCul /corrélation: 1.185118180771033e-05
# variable :  VegInond /corrélation: 0.008829359120667906
# variable :  ZoneUrbaine /corrélation: 1.047756528752663e-05
# variable :  Moy_IRM /corrélation: 0.0008391332447856267
# variable :  Amp1_IRM /corrélation: 0.006281760955209647
# variable :  Amp2_IRM /corrélation: 0.01667337548046945
# variable :  Amp3_IRM /corrélation: 0.00743074634066161
# variable :  VarT_ann_IRM /corrélation: 0.0007513403411689917
# variable :  VarT_bi_IRM /corrélation: 0.01004337096522944
# variable :  VarT_tri_IRM /corrélation: 0.00489620054837446
# variable :  VarT_Cy_IRM /corrélation: 0.0015875187858322563
# variable :  Min_IRM /corrélation: 0.002708337041356292
# variable :  Max_IRM /corrélation: 4.1709302001140556e-05
# variable :  Ph1_IRM /corrélation: 0.012072567724193831
# variable :  Ph2_IRM /corrélation: 0.003920520508765332
# variable :  Ph3_IRM /corrélation: 2.9176930322956325e-06
# variable :  Var_IRM /corrélation: 0.0014737186834779753
# variable :  Moy_TempJ /corrélation: 0.002849591410514849
# variable :  Amp1_TempJ /corrélation: 0.061961587359842946
# variable :  Amp2_TempJ /corrélation: 0.009956981868297044
# variable :  Amp3_TempJ /corrélation: 0.0047869585263074065
# variable :  VarT_ann_TempJ /corrélation: 0.037192770604509685
# variable :  VarT_bi_TempJ /corrélation: 0.044091506758906
# variable :  VarT_tri_TempJ /corrélation: 0.05648720211827007
# variable :  VarT_cy_TempJ /corrélation: 0.022188449848024268
# variable :  Min_TempJ /corrélation: 0.0016059332605357394
# variable :  Max_TempJ /corrélation: 0.005424331230463121
# variable :  Ph1_TempJ /corrélation: 0.007507830006274492
# variable :  Ph2_TempJ /corrélation: 0.03068204873013546
# variable :  Ph3_TempJ /corrélation: 0.009197001111422295
# variable :  Var_TempJ /corrélation: 0.06019360172676468
# variable :  Moy_TempN /corrélation: 0.00273652794472336
# variable :  Amp1_TempN /corrélation: 0.03324120098717723
# variable :  Amp2_TempN /corrélation: 0.00015488967062263635
# variable :  Amp3_TempN /corrélation: 0.0053017352853980074
# variable :  VarT_ann_TempN /corrélation: 0.018240233312098987
# variable :  VarT_bi_TempN /corrélation: 0.03292826342610742
# variable :  VarT_tri_TempN /corrélation: 0.011811023622047242
# variable :  VarT_cy_TempN /corrélation: 0.012216952580602701
# variable :  Min_TempN /corrélation: 0.0021723087741126607
# variable :  Max_TempN /corrélation: 0.0037992527294690454
# variable :  Ph1_TempN /corrélation: 0.0020592267861052034
# variable :  Ph2_TempN /corrélation: 0.03443536403520194
# variable :  Ph3_TempN /corrélation: 9.089068600074355e-05
# variable :  Var_TempN /corrélation: 0.024367182973276336
# variable :  Moy_NDVI /corrélation: 6.310335210106661e-05
# variable :  Amp1_NDVI /corrélation: 0.0022641777745762356
# variable :  Amp2_NDVI /corrélation: 0.006667848596934975
# variable :  Amp3_NDVI /corrélation: 0.00020544095949417412
# variable :  VarT_ann_NDVI /corrélation: 0.002416344686516737
# variable :  VarT_bi_NDVI /corrélation: 0.006041527797577989
# variable :  VarT_tri_NDVI /corrélation: 0.00030111412225233364
# variable :  VarT_cy_NDVI /corrélation: 0.005036424533757282
# variable :  Min_NDVI /corrélation: 0.0007084000041527155
# variable :  Max_NDVI /corrélation: 0.0005709268143741978
# variable :  Ph1_NDVI /corrélation: 0.013203899722311913
# variable :  Ph2_NDVI /corrélation: 0.004268956274529124
# variable :  Ph3_NDVI /corrélation: 0.03355708078882127
# variable :  Var_NDVI /corrélation: 0.0030723170460507264
# variable :  Moy_EVI /corrélation: 0.0005323917051730908
# variable :  Amp1_EVI /corrélation: 0.009318673669148096
# variable :  Amp2_EVI /corrélation: 0.013837887176566054
# variable :  Amp3_EVI /corrélation: 0.010874531491419426
# variable :  VarT_ann_EVI /corrélation: 0.0103464382248531
# variable :  VarT_bi_EVI /corrélation: 0.01336302662244766
# variable :  VarT_tri_EVI /corrélation: 0.0007377407067254872
# variable :  VarT_cy_EVI /corrélation: 0.013498933449809927
# variable :  Min_EVI /corrélation: 0.0006712422747614759
# variable :  Max_EVI /corrélation: 0.005158053968149388
# variable :  Ph1_EVI /corrélation: 0.0211900895316516
# variable :  Ph2_EVI /corrélation: 0.015210437854525532
# variable :  Ph3_EVI /corrélation: 0.0001406861655850198
# variable :  Var_EVI /corrélation: 0.007754086812629864
# variable :  Ret_eau /corrélation: 0.003596816943699013
# variable :  Sol_teneur /corrélation: 0.03589575796377161
# variable :  Substratum /corrélation: 0.008534739837756346
# variable :  Prob_R /corrélation: 0.0038819064877638914
# variable :  ProfAbs_Sub /corrélation: 0.006420572035735462
# variable :  CEC /corrélation: 0.025161701085801853
# variable :  Sol_Argile /corrélation: 6.387601725426296e-05
# variable :  Sol_Carbone /corrélation: 0.03322378901608206
# variable :  Sol_Carbone_stock /corrélation: 0.03849457296155901
# variable :  Sol_Carbone_terreFine /corrélation: 0.028288217259113672
# variable :  Sol_pH_KCL /corrélation: 0.02047928700581785
# variable :  Sol_Limon /corrélation: 0.05666103770489091
# variable :  Sol_Sable /corrélation: 0.03260799763140072
# variable :  Elev_Max /corrélation: 0.022633997592623578
# variable :  Elev_Moyenne /corrélation: 0.023587178162598834
# variable :  Elev_Min /corrélation: 0.02269674194310412
# variable :  Elev_Moy /corrélation: 0.023273628854895673
# variable :  Elev_sd /corrélation: 0.0007409215670880891
# variable :  Geom_maj /corrélation: 0.001441684296731037
# variable :  Geom_Shan /corrélation: 0.008440260474293363
# variable :  Geom_unif /corrélation: 0.006912208795128266
# variable :  Rugosite_Max /corrélation: 0.0046247140704594675
# variable :  Rugosite_Moyenne /corrélation: 0.004293009052148279
# variable :  Rugosite_Min /corrélation: 0.0038003908329773068
# variable :  Rugosite_Moy /corrélation: 0.004241414976491084
# variable :  Rugosite_sd /corrélation: 0.0034561955276904287
# variable :  Pente_Max /corrélation: 0.003935349822929077
# variable :  Pente_Moyenne /corrélation: 0.0038875727867283883
# variable :  Pente_Min /corrélation: 0.010121852037296278
# variable :  Pente_Moy /corrélation: 0.0052386250531303935
# variable :  Pente_sd /corrélation: 0.0013147443965795256
# variable :  IPT_Max /corrélation: 0.0011043342125607691
# variable :  IPT_Med /corrélation: 0.006348842523481089
# variable :  IPT_Min /corrélation: 0.000217788840309351
# variable :  IPT_Moy /corrélation: 0.010720171160688368
# variable :  IPT_sd /corrélation: 0.002182883824539865
# variable :  IR_Max /corrélation: 0.003851421106567376
# variable :  IR_Med /corrélation: 0.004631244527484784
# variable :  IR_Min /corrélation: 0.0033121967624798704
# variable :  IR_Moy /corrélation: 0.004726777229458549
# variable :  IR_sd /corrélation: 0.0016784317922483752
# variable :  RV_Max /corrélation: 0.002262106953391591
# variable :  RV_Med /corrélation: 0.00029332198468840246
# variable :  RV_Min /corrélation: 0.0004680593652339519
# variable :  RV_Moy /corrélation: 0.0009728771566648718
# variable :  RV_sd /corrélation: 0.0019669847101032698
# variable :  Bio_Ta_moy /corrélation: 0.04651916540591004
# variable :  Bio_Tj_Moy /corrélation: 0.00037388161128661774
# variable :  Isoth /corrélation: 0.05825892437857434
# variable :  Bio_Saison /corrélation: 0.04035336634088955
# variable :  Bio_Tmax /corrélation: 0.0048309624559393265
# variable :  Bio_Tmin /corrélation: 0.04926704512571937
# variable :  Bio_Tint /corrélation: 0.020318951501377726
# variable :  Bio_Thum_Moy /corrélation: 0.06800183620435031
# variable :  Bio_Tsec_Moy /corrélation: 0.0015057274608093168
# variable :  Bio_Tch_Moy /corrélation: 0.007285574348864496
# variable :  Bio_Tfr_Moy /corrélation: 0.05571806519643913
# variable :  Bio_Pre_Ann /corrélation: 0.07285724704308948
# variable :  Bio_Pre_hum /corrélation: 0.04802700133092979
# variable :  Bio_Pre_sec /corrélation: 0.01852510522259766
# variable :  Bio_Pre_Saison /corrélation: 0.015992233546275283
# variable :  Bio_Pre_Qhum /corrélation: 0.05592438483860256
# variable :  Bio_Pre_Qsec /corrélation: 0.050459011878371894
# variable :  Bio_Pre_Qch /corrélation: 0.035286846566944766
# variable :  Bio_Pre_Qfr /corrélation: 0.04838795567851117
# variable :  Prec_Janv /corrélation: 0.03971685426061774
# variable :  Prec_Fev /corrélation: 0.06029749036293401
# variable :  Prec_Mars /corrélation: 0.06927524172344814
# variable :  Prec_Avril /corrélation: 0.06863614652783867
# variable :  Prec_Mai /corrélation: 0.07665843305941798
# variable :  Prec_Juin /corrélation: 0.07233759348307355
# variable :  Prec_Juill /corrélation: 0.011001020547559918
# variable :  Prec_Aout /corrélation: 0.02162017287204343
# variable :  Prec_Sept /corrélation: 0.04154284883172499
# variable :  Prec_Oct /corrélation: 0.08684130401003368
# variable :  Prec_Nov /corrélation: 0.0867241968871434
# variable :  Prec_Dec /corrélation: 0.04053403458517846
# variable :  Rad_Janv /corrélation: 0.05674322508651904
# variable :  Rad_Fev /corrélation: 0.05461817188498711
# variable :  Rad_Mars /corrélation: 0.0514348685800513
# variable :  Rad_Avril /corrélation: 0.04739146149580036
# variable :  Rad_Mai /corrélation: 0.0010051132889947578
# variable :  Rad_Juin /corrélation: 0.03582631344583858
# variable :  Rad_Juill /corrélation: 0.07776641497199584
# variable :  Rad_Aout /corrélation: 0.07724295013917151
# variable :  Rad_Sept /corrélation: 0.0032805777377953984
# variable :  Rad_Oct /corrélation: 0.041163169021606404
# variable :  Rad_Nov /corrélation: 0.05478461493289561
# variable :  Rad_Dec /corrélation: 0.05510879164759166
# variable :  Tmax_Janv /corrélation: 0.048493854640171176
# variable :  Tmax_Fev /corrélation: 0.05162765925542702
# variable :  Tmax_Mars /corrélation: 0.04967169541959081
# variable :  Tmax_Avril /corrélation: 0.03525573163721929
# variable :  Tmax_Mai /corrélation: 0.019918815488290147
# variable :  Tmax_Juin /corrélation: 0.004437406318770661
# variable :  Tmax_Juill /corrélation: 0.0024352908004262367
# variable :  Tmax_Aout /corrélation: 0.004738625198409672
# variable :  Tmax_Sept /corrélation: 0.020428879304372535
# variable :  Tmax_Oct /corrélation: 0.041231988367230056
# variable :  Tmax_Nov /corrélation: 0.05991259797679891
# variable :  Tmax_Dec /corrélation: 0.05409331827145371
# variable :  Tmin_Janv /corrélation: 0.050992243066283
# variable :  Tmin_Fev /corrélation: 0.05740166816651619
# variable :  Tmin_Mars /corrélation: 0.06188985655827851
# variable :  Tmin_Avril /corrélation: 0.05979023961881843
# variable :  Tmin_Mai /corrélation: 0.05275284302677198
# variable :  Tmin_Juin /corrélation: 0.03370456212633629
# variable :  Tmin_Juill /corrélation: 4.582457569131599e-05
# variable :  Tmin_Aout /corrélation: 0.0011545618268160676
# variable :  Tmin_Sept /corrélation: 0.018531219392506713
# variable :  Tmin_Oct /corrélation: 0.04094763979599555
# variable :  Tmin_Nov /corrélation: 0.0542177239138182
# variable :  Tmin_Dec /corrélation: 0.04511289351730663
# variable :  Vap_Janv /corrélation: 0.02235846114466034
# variable :  Vap_Fev /corrélation: 0.026524529650881586
# variable :  Vap_Mars /corrélation: 0.026905617990691032
# variable :  Vap_Avril /corrélation: 0.030036754385295395
# variable :  Vap_Mai /corrélation: 0.025048650172243166
# variable :  Vap_Juin /corrélation: 0.020343252781773822
# variable :  Vap_Juill /corrélation: 0.018453992400196302
# variable :  Vap_Aout /corrélation: 0.02011511113280687
# variable :  Vap_Sept /corrélation: 0.024932161020624413
# variable :  Vap_Oct /corrélation: 0.03017527506001068
# variable :  Vap_Nov /corrélation: 0.030653552474610914
# variable :  Vap_Dec /corrélation: 0.027613485155468145
# variable :  Vent_Janv /corrélation: 0.050476516354510594
# variable :  Vent_Fev /corrélation: 0.020024226731149807
# variable :  Vent_Mars /corrélation: 0.03166911444649033
# variable :  Vent_Avril /corrélation: 0.048690047818947674
# variable :  Vent_Mai /corrélation: 0.054364242687829155
# variable :  Vent_Juin /corrélation: 0.0675967126792566
# variable :  Vent_Juill /corrélation: 0.06991357969408969
# variable :  Vent_Aout /corrélation: 0.05996496336771776
# variable :  Vent_Sept /corrélation: 0.028170403843565766
# variable :  Vent_Oct /corrélation: 0.02748355156543296
# variable :  Vent_Nov /corrélation: 0.036194515884382786
# variable :  Vent_Dec /corrélation: 0.025450451890329396

# %%
lst
# Out:
# [['X_long', 0.033446661786267616],
#  ['Y_lat', 0.04992229920957633],
#  ['Bovins', 4.4551994069963336e-05],
#  ['Volaille', 0.008508171096232201],
#  ['Caprins', 0.0072081645804304775],
#  ['Ovins', 0.0028138572716238553],
#  ['Equides', 0.0008924619875205346],
#  ['Coniferes', 0.002587214562741175],
#  ['ZoneAride', 0.008450166364495436],
#  ['ZonePel', 0.001082090971726146],
#  ['Lesfeuillus', 0.015006768668652335],
#  ['Caduc', 0.004811923365109105],
#  ['Autres', 0.004196650944679164],
#  ['Arbrisseau', 0.011428517571002572],
#  ['Pl_herb', 0.016671577674043512],
#  ['VegCul', 1.185118180771033e-05],
#  ['VegInond', 0.008829359120667906],
#  ['ZoneUrbaine', 1.047756528752663e-05],
#  ['Moy_IRM', 0.0008391332447856267],
#  ['Amp1_IRM', 0.006281760955209647],
#  ['Amp2_IRM', 0.01667337548046945],
#  ['Amp3_IRM', 0.00743074634066161],
#  ['VarT_ann_IRM', 0.0007513403411689917],
#  ['VarT_bi_IRM', 0.01004337096522944],
#  ['VarT_tri_IRM', 0.00489620054837446],
#  ['VarT_Cy_IRM', 0.0015875187858322563],
#  ['Min_IRM', 0.002708337041356292],
#  ['Max_IRM', 4.1709302001140556e-05],
#  ['Ph1_IRM', 0.012072567724193831],
#  ['Ph2_IRM', 0.003920520508765332],
#  ['Ph3_IRM', 2.9176930322956325e-06],
#  ['Var_IRM', 0.0014737186834779753],
#  ['Moy_TempJ', 0.002849591410514849],
#  ['Amp1_TempJ', 0.061961587359842946],
#  ['Amp2_TempJ', 0.009956981868297044],
#  ['Amp3_TempJ', 0.0047869585263074065],
#  ['VarT_ann_TempJ', 0.037192770604509685],
#  ['VarT_bi_TempJ', 0.044091506758906],
#  ['VarT_tri_TempJ', 0.05648720211827007],
#  ['VarT_cy_TempJ', 0.022188449848024268],
#  ['Min_TempJ', 0.0016059332605357394],
#  ['Max_TempJ', 0.005424331230463121],
#  ['Ph1_TempJ', 0.007507830006274492],
#  ['Ph2_TempJ', 0.03068204873013546],
#  ['Ph3_TempJ', 0.009197001111422295],
#  ['Var_TempJ', 0.06019360172676468],
#  ['Moy_TempN', 0.00273652794472336],
#  ['Amp1_TempN', 0.03324120098717723],
#  ['Amp2_TempN', 0.00015488967062263635],
#  ['Amp3_TempN', 0.0053017352853980074],
#  ['VarT_ann_TempN', 0.018240233312098987],
#  ['VarT_bi_TempN', 0.03292826342610742],
#  ['VarT_tri_TempN', 0.011811023622047242],
#  ['VarT_cy_TempN', 0.012216952580602701],
#  ['Min_TempN', 0.0021723087741126607],
#  ['Max_TempN', 0.0037992527294690454],
#  ['Ph1_TempN', 0.0020592267861052034],
#  ['Ph2_TempN', 0.03443536403520194],
#  ['Ph3_TempN', 9.089068600074355e-05],
#  ['Var_TempN', 0.024367182973276336],
#  ['Moy_NDVI', 6.310335210106661e-05],
#  ['Amp1_NDVI', 0.0022641777745762356],
#  ['Amp2_NDVI', 0.006667848596934975],
#  ['Amp3_NDVI', 0.00020544095949417412],
#  ['VarT_ann_NDVI', 0.002416344686516737],
#  ['VarT_bi_NDVI', 0.006041527797577989],
#  ['VarT_tri_NDVI', 0.00030111412225233364],
#  ['VarT_cy_NDVI', 0.005036424533757282],
#  ['Min_NDVI', 0.0007084000041527155],
#  ['Max_NDVI', 0.0005709268143741978],
#  ['Ph1_NDVI', 0.013203899722311913],
#  ['Ph2_NDVI', 0.004268956274529124],
#  ['Ph3_NDVI', 0.03355708078882127],
#  ['Var_NDVI', 0.0030723170460507264],
#  ['Moy_EVI', 0.0005323917051730908],
#  ['Amp1_EVI', 0.009318673669148096],
#  ['Amp2_EVI', 0.013837887176566054],
#  ['Amp3_EVI', 0.010874531491419426],
#  ['VarT_ann_EVI', 0.0103464382248531],
#  ['VarT_bi_EVI', 0.01336302662244766],
#  ['VarT_tri_EVI', 0.0007377407067254872],
#  ['VarT_cy_EVI', 0.013498933449809927],
#  ['Min_EVI', 0.0006712422747614759],
#  ['Max_EVI', 0.005158053968149388],
#  ['Ph1_EVI', 0.0211900895316516],
#  ['Ph2_EVI', 0.015210437854525532],
#  ['Ph3_EVI', 0.0001406861655850198],
#  ['Var_EVI', 0.007754086812629864],
#  ['Ret_eau', 0.003596816943699013],
#  ['Sol_teneur', 0.03589575796377161],
#  ['Substratum', 0.008534739837756346],
#  ['Prob_R', 0.0038819064877638914],
#  ['ProfAbs_Sub', 0.006420572035735462],
#  ['CEC', 0.025161701085801853],
#  ['Sol_Argile', 6.387601725426296e-05],
#  ['Sol_Carbone', 0.03322378901608206],
#  ['Sol_Carbone_stock', 0.03849457296155901],
#  ['Sol_Carbone_terreFine', 0.028288217259113672],
#  ['Sol_pH_KCL', 0.02047928700581785],
#  ['Sol_Limon', 0.05666103770489091],
#  ['Sol_Sable', 0.03260799763140072],
#  ['Elev_Max', 0.022633997592623578],
#  ['Elev_Moyenne', 0.023587178162598834],
#  ['Elev_Min', 0.02269674194310412],
#  ['Elev_Moy', 0.023273628854895673],
#  ['Elev_sd', 0.0007409215670880891],
#  ['Geom_maj', 0.001441684296731037],
#  ['Geom_Shan', 0.008440260474293363],
#  ['Geom_unif', 0.006912208795128266],
#  ['Rugosite_Max', 0.0046247140704594675],
#  ['Rugosite_Moyenne', 0.004293009052148279],
#  ['Rugosite_Min', 0.0038003908329773068],
#  ['Rugosite_Moy', 0.004241414976491084],
#  ['Rugosite_sd', 0.0034561955276904287],
#  ['Pente_Max', 0.003935349822929077],
#  ['Pente_Moyenne', 0.0038875727867283883],
#  ['Pente_Min', 0.010121852037296278],
#  ['Pente_Moy', 0.0052386250531303935],
#  ['Pente_sd', 0.0013147443965795256],
#  ['IPT_Max', 0.0011043342125607691],
#  ['IPT_Med', 0.006348842523481089],
#  ['IPT_Min', 0.000217788840309351],
#  ['IPT_Moy', 0.010720171160688368],
#  ['IPT_sd', 0.002182883824539865],
#  ['IR_Max', 0.003851421106567376],
#  ['IR_Med', 0.004631244527484784],
#  ['IR_Min', 0.0033121967624798704],
#  ['IR_Moy', 0.004726777229458549],
#  ['IR_sd', 0.0016784317922483752],
#  ['RV_Max', 0.002262106953391591],
#  ['RV_Med', 0.00029332198468840246],
#  ['RV_Min', 0.0004680593652339519],
#  ['RV_Moy', 0.0009728771566648718],
#  ['RV_sd', 0.0019669847101032698],
#  ['Bio_Ta_moy', 0.04651916540591004],
#  ['Bio_Tj_Moy', 0.00037388161128661774],
#  ['Isoth', 0.05825892437857434],
#  ['Bio_Saison', 0.04035336634088955],
#  ['Bio_Tmax', 0.0048309624559393265],
#  ['Bio_Tmin', 0.04926704512571937],
#  ['Bio_Tint', 0.020318951501377726],
#  ['Bio_Thum_Moy', 0.06800183620435031],
#  ['Bio_Tsec_Moy', 0.0015057274608093168],
#  ['Bio_Tch_Moy', 0.007285574348864496],
#  ['Bio_Tfr_Moy', 0.05571806519643913],
#  ['Bio_Pre_Ann', 0.07285724704308948],
#  ['Bio_Pre_hum', 0.04802700133092979],
#  ['Bio_Pre_sec', 0.01852510522259766],
#  ['Bio_Pre_Saison', 0.015992233546275283],
#  ['Bio_Pre_Qhum', 0.05592438483860256],
#  ['Bio_Pre_Qsec', 0.050459011878371894],
#  ['Bio_Pre_Qch', 0.035286846566944766],
#  ['Bio_Pre_Qfr', 0.04838795567851117],
#  ['Prec_Janv', 0.03971685426061774],
#  ['Prec_Fev', 0.06029749036293401],
#  ['Prec_Mars', 0.06927524172344814],
#  ['Prec_Avril', 0.06863614652783867],
#  ['Prec_Mai', 0.07665843305941798],
#  ['Prec_Juin', 0.07233759348307355],
#  ['Prec_Juill', 0.011001020547559918],
#  ['Prec_Aout', 0.02162017287204343],
#  ['Prec_Sept', 0.04154284883172499],
#  ['Prec_Oct', 0.08684130401003368],
#  ['Prec_Nov', 0.0867241968871434],
#  ['Prec_Dec', 0.04053403458517846],
#  ['Rad_Janv', 0.05674322508651904],
#  ['Rad_Fev', 0.05461817188498711],
#  ['Rad_Mars', 0.0514348685800513],
#  ['Rad_Avril', 0.04739146149580036],
#  ['Rad_Mai', 0.0010051132889947578],
#  ['Rad_Juin', 0.03582631344583858],
#  ['Rad_Juill', 0.07776641497199584],
#  ['Rad_Aout', 0.07724295013917151],
#  ['Rad_Sept', 0.0032805777377953984],
#  ['Rad_Oct', 0.041163169021606404],
#  ['Rad_Nov', 0.05478461493289561],
#  ['Rad_Dec', 0.05510879164759166],
#  ['Tmax_Janv', 0.048493854640171176],
#  ['Tmax_Fev', 0.05162765925542702],
#  ['Tmax_Mars', 0.04967169541959081],
#  ['Tmax_Avril', 0.03525573163721929],
#  ['Tmax_Mai', 0.019918815488290147],
#  ['Tmax_Juin', 0.004437406318770661],
#  ['Tmax_Juill', 0.0024352908004262367],
#  ['Tmax_Aout', 0.004738625198409672],
#  ['Tmax_Sept', 0.020428879304372535],
#  ['Tmax_Oct', 0.041231988367230056],
#  ['Tmax_Nov', 0.05991259797679891],
#  ['Tmax_Dec', 0.05409331827145371],
#  ['Tmin_Janv', 0.050992243066283],
#  ['Tmin_Fev', 0.05740166816651619],
#  ['Tmin_Mars', 0.06188985655827851],
#  ['Tmin_Avril', 0.05979023961881843],
#  ['Tmin_Mai', 0.05275284302677198],
#  ['Tmin_Juin', 0.03370456212633629],
#  ['Tmin_Juill', 4.582457569131599e-05],
#  ['Tmin_Aout', 0.0011545618268160676],
#  ['Tmin_Sept', 0.018531219392506713],
#  ['Tmin_Oct', 0.04094763979599555],
#  ['Tmin_Nov', 0.0542177239138182],
#  ['Tmin_Dec', 0.04511289351730663],
#  ['Vap_Janv', 0.02235846114466034],
#  ['Vap_Fev', 0.026524529650881586],
#  ['Vap_Mars', 0.026905617990691032],
#  ['Vap_Avril', 0.030036754385295395],
#  ['Vap_Mai', 0.025048650172243166],
#  ['Vap_Juin', 0.020343252781773822],
#  ['Vap_Juill', 0.018453992400196302],
#  ['Vap_Aout', 0.02011511113280687],
#  ['Vap_Sept', 0.024932161020624413],
#  ['Vap_Oct', 0.03017527506001068],
#  ['Vap_Nov', 0.030653552474610914],
#  ['Vap_Dec', 0.027613485155468145],
#  ['Vent_Janv', 0.050476516354510594],
#  ['Vent_Fev', 0.020024226731149807],
#  ['Vent_Mars', 0.03166911444649033],
#  ['Vent_Avril', 0.048690047818947674],
#  ['Vent_Mai', 0.054364242687829155],
#  ['Vent_Juin', 0.0675967126792566],
#  ['Vent_Juill', 0.06991357969408969],
#  ['Vent_Aout', 0.05996496336771776],
#  ['Vent_Sept', 0.028170403843565766],
#  ['Vent_Oct', 0.02748355156543296],
#  ['Vent_Nov', 0.036194515884382786],
#  ['Vent_Dec', 0.025450451890329396]]

# %%
df1 = pd.DataFrame(lst, columns = ['variable','corrélation'])
print(df1)
# Out:
#       variable  corrélation
# 0       X_long     0.033447
# 1        Y_lat     0.049922
# 2       Bovins     0.000045
# 3     Volaille     0.008508
# 4      Caprins     0.007208
# ..         ...          ...
# 220  Vent_Aout     0.059965
# 221  Vent_Sept     0.028170
# 222   Vent_Oct     0.027484
# 223   Vent_Nov     0.036195
# 224   Vent_Dec     0.025450
#
# [225 rows x 2 columns]

# %%
df1.to_excel("cx_theileri_corrélation.xlsx")

# %%
A=df1.sort_values(by=["corrélation"],ascending=False)

# %%
A
# Out:
#         variable  corrélation
# 162     Prec_Oct     0.086841
# 163     Prec_Nov     0.086724
# 171    Rad_Juill     0.077766
# 172     Rad_Aout     0.077243
# 157     Prec_Mai     0.076658
# ..           ...          ...
# 2         Bovins     0.000045
# 27       Max_IRM     0.000042
# 15        VegCul     0.000012
# 17   ZoneUrbaine     0.000010
# 30       Ph3_IRM     0.000003
#
# [225 rows x 2 columns]

# %%
type(A)
# Out:
# pandas.core.frame.DataFrame

# %%
A["variable"][0:10]
# Out:
# 162       Prec_Oct
# 163       Prec_Nov
# 171      Rad_Juill
# 172       Rad_Aout
# 157       Prec_Mai
# 145    Bio_Pre_Ann
# 158      Prec_Juin
# 219     Vent_Juill
# 155      Prec_Mars
# 156     Prec_Avril
# Name: variable, dtype: object

# %% [markdown]
# # Modélisation

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_neg =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_neg
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %% [markdown]
# # three-shold 10 %  (23 variables)

# %%
A["variable"][0:23]
# Out:
# 162        Prec_Oct
# 163        Prec_Nov
# 171       Rad_Juill
# 172        Rad_Aout
# 157        Prec_Mai
# 145     Bio_Pre_Ann
# 158       Prec_Juin
# 219      Vent_Juill
# 155       Prec_Mars
# 156      Prec_Avril
# 141    Bio_Thum_Moy
# 218       Vent_Juin
# 33       Amp1_TempJ
# 191       Tmin_Mars
# 154        Prec_Fev
# 45        Var_TempJ
# 220       Vent_Aout
# 187        Tmax_Nov
# 192      Tmin_Avril
# 136           Isoth
# 190        Tmin_Fev
# 165        Rad_Janv
# 99        Sol_Limon
# Name: variable, dtype: object

# %%
S10=A["variable"][0:23].values.tolist()

# %%
S10
# Out:
# ['Prec_Oct',
#  'Prec_Nov',
#  'Rad_Juill',
#  'Rad_Aout',
#  'Prec_Mai',
#  'Bio_Pre_Ann',
#  'Prec_Juin',
#  'Vent_Juill',
#  'Prec_Mars',
#  'Prec_Avril',
#  'Bio_Thum_Moy',
#  'Vent_Juin',
#  'Amp1_TempJ',
#  'Tmin_Mars',
#  'Prec_Fev',
#  'Var_TempJ',
#  'Vent_Aout',
#  'Tmax_Nov',
#  'Tmin_Avril',
#  'Isoth',
#  'Tmin_Fev',
#  'Rad_Janv',
#  'Sol_Limon']

# %%
XR10=X[S10]

# %%
XR10
# Out:
#      Prec_Oct  Prec_Nov  Rad_Juill  Rad_Aout  Prec_Mai  Bio_Pre_Ann  \
# 0           3         4      23739     23115         1           48
# 1           3         7      23135     22648         0           29
# 2           3         7      23135     22648         0           29
# 3           3         7      23055     22569         0           27
# 4           3         6      23035     22619         0           26
# ..        ...       ...        ...       ...       ...          ...
# 223        53        70      26270     23844        30          601
# 224        58        77      25964     23662        32          638
# 225        76       126      27084     24585        39          782
# 226        59        90      26073     23626        33          709
# 227        76       128      27092     24794        39          801
#
#      Prec_Juin  Vent_Juill  Prec_Mars  Prec_Avril  ...  Tmin_Mars  Prec_Fev  \
# 0            0         7.5          1           1  ...       15.7         2
# 1            1         5.9          2           1  ...       14.2         3
# 2            1         5.9          2           1  ...       14.2         3
# 3            1         6.2          1           1  ...       14.4         3
# 4            1         6.2          1           1  ...       14.6         2
# ..         ...         ...        ...         ...  ...        ...       ...
# 223         10         4.0         68          62  ...       11.3        71
# 224          9         4.0         72          63  ...       12.0        77
# 225         12         3.6         95          65  ...       11.3        95
# 226          7         3.9         88          58  ...       11.5        98
# 227         13         3.7        103          65  ...       12.4       100
#
#      Var_TempJ  Vent_Aout   Tmax_Nov  Tmin_Avril      Isoth  Tmin_Fev  \
# 0            6        7.2  24.500000        15.6  59.375002      14.8
# 1           26        5.9  25.100000        14.7  55.461394      12.8
# 2           26        5.9  25.100000        14.7  55.461394      12.8
# 3           25        6.2  25.100000        15.0  54.932949      13.1
# 4           26        5.8  25.299999        15.2  54.952379      13.2
# ..         ...        ...        ...         ...        ...       ...
# 223          0        3.8  19.500000        12.8  36.962365       9.8
# 224         64        4.1  19.100000        13.5  32.022471      10.5
# 225         59        3.3  19.400000        12.7  34.904017       9.5
# 226         64        4.1  18.700001        13.1  32.194897       9.6
# 227         49        3.7  19.000000        13.9  29.519776      10.7
#
#      Rad_Janv  Sol_Limon
# 0       14965  19.083333
# 1       13864  17.500000
# 2       13864  17.500000
# 3       13845  18.083333
# 4       13863  13.916667
# ..        ...        ...
# 223      9265  27.750000
# 224      9204  28.750000
# 225      9008  29.416667
# 226      9145  26.916667
# 227      8985  27.166667
#
# [228 rows x 23 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR10, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR10, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR10, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR10, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR10, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR10, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR10, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR10, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR10, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR10, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR10, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.54347826 0.56521739 0.63043478 0.48888889 0.71111111]
# moy_accuracy: 0.59
# -------------------------------------------------
# sensibilité : [0.53846154 0.57894737 0.6        0.44444444 0.57142857]
# moy_sensibilité: 0.55
# -------------------------------------------------
# spécificité : [0.55       0.55555556 0.6875     0.51851852 0.83333333]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [ 0.0877058   0.13245324  0.27386128 -0.03636965  0.42184792]
# MCC: 0.18
# -------------------------------------------------
# precision-po: [0.60869565 0.47826087 0.7826087  0.38095238 0.75      ]
# moy_precision-po: 0.60
# -------------------------------------------------
# precision-ne : [0.47826087 0.65217391 0.47826087 0.58333333 0.68965517]
# moy_precision-ne: 0.58
# -------------------------------------------------
# AUC : [0.54134615 0.59064327 0.69375    0.58641975 0.74107143]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [11 15 11 14 20]
# VP : [14 11 18  8 12]
# FP : [ 9 12  5 13  4]
# FN : [12  8 12 10  9]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.56521739 0.58695652 0.7173913  0.57777778 0.57777778]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.57692308 0.52631579 0.8        0.5        0.47619048]
# moy_sensibilité: 0.58
# -------------------------------------------------
# spécificité : [0.55       0.62962963 0.5625     0.62962963 0.66666667]
# moy_spécificité: 0.61
# -------------------------------------------------
# MCC : [0.12595787 0.15489223 0.36830037 0.12857571 0.14547859]
# MCC: 0.18
# -------------------------------------------------
# precision-po: [0.625      0.5        0.77419355 0.47368421 0.55555556]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.5        0.65384615 0.6        0.65384615 0.59259259]
# moy_precision-ne: 0.60
# -------------------------------------------------
# AUC : [0.63365385 0.582846   0.68333333 0.59465021 0.5515873 ]
# moy_AUC: 0.61
# -------------------------------------------------
# VN : [11 17  9 17 16]
# VP : [15 10 24  9 10]
# FP : [ 9 10  7 10  8]
# FN : [11  9  6  9 11]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.63043478 0.58695652 0.65217391 0.55555556 0.68888889]
# moy_accuracy: 0.62
# -------------------------------------------------
# sensibilité : [0.61538462 0.63157895 0.56666667 0.55555556 0.61904762]
# moy_sensibilité: 0.60
# -------------------------------------------------
# spécificité : [0.6        0.7037037  0.6875     0.51851852 0.875     ]
# moy_spécificité: 0.68
# -------------------------------------------------
# MCC : [ 0.20384615  0.24395526  0.30590258 -0.01814885  0.42184792]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.64       0.55       0.80952381 0.40909091 0.76470588]
# moy_precision-po: 0.63
# -------------------------------------------------
# precision-ne : [0.61111111 0.66666667 0.47826087 0.63636364 0.68965517]
# moy_precision-ne: 0.62
# -------------------------------------------------
# AUC : [0.58173077 0.62962963 0.74791667 0.60288066 0.73015873]
# moy_AUC: 0.66
# -------------------------------------------------
# VN : [13 17 10 14 20]
# VP : [16  9 20 10 11]
# FP : [ 8  9  5 13  4]
# FN : [12  8 13  8  8]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.56521739 0.58695652 0.60869565 0.51111111 0.64444444]
# moy_accuracy: 0.58
# -------------------------------------------------
# sensibilité : [0.61538462 0.52631579 0.6        0.5        0.47619048]
# moy_sensibilité: 0.54
# -------------------------------------------------
# spécificité : [0.5        0.62962963 0.625      0.51851852 0.79166667]
# moy_spécificité: 0.61
# -------------------------------------------------
# MCC : [0.11538462 0.15489223 0.21452908 0.01814885 0.28347335]
# MCC: 0.16
# -------------------------------------------------
# precision-po: [0.61538462 0.5        0.75       0.40909091 0.66666667]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.5        0.65384615 0.45454545 0.60869565 0.63333333]
# moy_precision-ne: 0.57
# -------------------------------------------------
# AUC : [0.61634615 0.60818713 0.69166667 0.5781893  0.69642857]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [10 17 10 14 19]
# VP : [16 10 18  9 10]
# FP : [10 10  6 13  5]
# FN : [10  9 12  9 11]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.7173913  0.54347826 0.69565217 0.57777778 0.6       ]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.80769231 0.63157895 0.76666667 0.72222222 0.66666667]
# moy_sensibilité: 0.72
# -------------------------------------------------
# spécificité : [0.6        0.48148148 0.5625     0.48148148 0.54166667]
# moy_spécificité: 0.53
# -------------------------------------------------
# MCC : [0.41870749 0.11229687 0.32916667 0.2037037  0.20916501]
# MCC: 0.25
# -------------------------------------------------
# precision-po: [0.72413793 0.46153846 0.76666667 0.48148148 0.56      ]
# moy_precision-po: 0.60
# -------------------------------------------------
# precision-ne : [0.70588235 0.65       0.5625     0.72222222 0.65      ]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.80288462 0.59844055 0.69166667 0.65432099 0.68055556]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [12 13  9 13 13]
# VP : [21 12 23 13 14]
# FP : [ 8 14  7 14 11]
# FN : [5 7 7 5 7]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.56521739 0.54347826 0.7173913  0.57777778 0.57777778]
# moy_accuracy: 0.60
# -------------------------------------------------
# sensibilité : [0.5        0.57894737 0.73333333 0.5        0.47619048]
# moy_sensibilité: 0.56
# -------------------------------------------------
# spécificité : [0.65       0.51851852 0.6875     0.62962963 0.66666667]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.15       0.09607145 0.40707278 0.12857571 0.14547859]
# MCC: 0.19
# -------------------------------------------------
# precision-po: [0.65       0.45833333 0.81481481 0.47368421 0.55555556]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.5        0.63636364 0.57894737 0.65384615 0.59259259]
# moy_precision-ne: 0.59
# -------------------------------------------------
# AUC : [0.57980769 0.59259259 0.66666667 0.6090535  0.65376984]
# moy_AUC: 0.62
# -------------------------------------------------
# VN : [13 14 11 17 16]
# VP : [13 11 22  9 10]
# FP : [ 7 13  5 10  8]
# FN : [13  8  8  9 11]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 20 %  (45 variables)

# %%
A["variable"][0:45]
# Out:
# 162          Prec_Oct
# 163          Prec_Nov
# 171         Rad_Juill
# 172          Rad_Aout
# 157          Prec_Mai
# 145       Bio_Pre_Ann
# 158         Prec_Juin
# 219        Vent_Juill
# 155         Prec_Mars
# 156        Prec_Avril
# 141      Bio_Thum_Moy
# 218         Vent_Juin
# 33         Amp1_TempJ
# 191         Tmin_Mars
# 154          Prec_Fev
# 45          Var_TempJ
# 220         Vent_Aout
# 187          Tmax_Nov
# 192        Tmin_Avril
# 136             Isoth
# 190          Tmin_Fev
# 165          Rad_Janv
# 99          Sol_Limon
# 38     VarT_tri_TempJ
# 149      Bio_Pre_Qhum
# 144       Bio_Tfr_Moy
# 176           Rad_Dec
# 175           Rad_Nov
# 166           Rad_Fev
# 217          Vent_Mai
# 199          Tmin_Nov
# 188          Tmax_Dec
# 193          Tmin_Mai
# 178          Tmax_Fev
# 167          Rad_Mars
# 189         Tmin_Janv
# 213         Vent_Janv
# 150      Bio_Pre_Qsec
# 1               Y_lat
# 179         Tmax_Mars
# 139          Bio_Tmin
# 216        Vent_Avril
# 177         Tmax_Janv
# 152       Bio_Pre_Qfr
# 146       Bio_Pre_hum
# Name: variable, dtype: object

# %%
S20=A["variable"][0:45].values.tolist()

# %%
S20
# Out:
# ['Prec_Oct',
#  'Prec_Nov',
#  'Rad_Juill',
#  'Rad_Aout',
#  'Prec_Mai',
#  'Bio_Pre_Ann',
#  'Prec_Juin',
#  'Vent_Juill',
#  'Prec_Mars',
#  'Prec_Avril',
#  'Bio_Thum_Moy',
#  'Vent_Juin',
#  'Amp1_TempJ',
#  'Tmin_Mars',
#  'Prec_Fev',
#  'Var_TempJ',
#  'Vent_Aout',
#  'Tmax_Nov',
#  'Tmin_Avril',
#  'Isoth',
#  'Tmin_Fev',
#  'Rad_Janv',
#  'Sol_Limon',
#  'VarT_tri_TempJ',
#  'Bio_Pre_Qhum',
#  'Bio_Tfr_Moy',
#  'Rad_Dec',
#  'Rad_Nov',
#  'Rad_Fev',
#  'Vent_Mai',
#  'Tmin_Nov',
#  'Tmax_Dec',
#  'Tmin_Mai',
#  'Tmax_Fev',
#  'Rad_Mars',
#  'Tmin_Janv',
#  'Vent_Janv',
#  'Bio_Pre_Qsec',
#  'Y_lat',
#  'Tmax_Mars',
#  'Bio_Tmin',
#  'Vent_Avril',
#  'Tmax_Janv',
#  'Bio_Pre_Qfr',
#  'Bio_Pre_hum']

# %%
XR20=X[S20]

# %%
XR20
# Out:
#      Prec_Oct  Prec_Nov  Rad_Juill  Rad_Aout  Prec_Mai  Bio_Pre_Ann  \
# 0           3         4      23739     23115         1           48
# 1           3         7      23135     22648         0           29
# 2           3         7      23135     22648         0           29
# 3           3         7      23055     22569         0           27
# 4           3         6      23035     22619         0           26
# ..        ...       ...        ...       ...       ...          ...
# 223        53        70      26270     23844        30          601
# 224        58        77      25964     23662        32          638
# 225        76       126      27084     24585        39          782
# 226        59        90      26073     23626        33          709
# 227        76       128      27092     24794        39          801
#
#      Prec_Juin  Vent_Juill  Prec_Mars  Prec_Avril  ...  Tmin_Janv  Vent_Janv  \
# 0            0         7.5          1           1  ...       14.5        4.8
# 1            1         5.9          2           1  ...       12.0        4.2
# 2            1         5.9          2           1  ...       12.0        4.2
# 3            1         6.2          1           1  ...       12.3        4.2
# 4            1         6.2          1           1  ...       12.4        4.2
# ..         ...         ...        ...         ...  ...        ...        ...
# 223         10         4.0         68          62  ...        9.2        3.7
# 224          9         4.0         72          63  ...        9.7        4.0
# 225         12         3.6         95          65  ...        8.3        3.6
# 226          7         3.9         88          58  ...        9.4        4.1
# 227         13         3.7        103          65  ...        9.6        3.7
#
#      Bio_Pre_Qsec      Y_lat  Tmax_Mars  Bio_Tmin  Vent_Avril  Tmax_Janv  \
# 0               2  23.794740  22.700001      14.5         6.9  21.500000
# 1               1  27.132950  24.000000      12.0         5.6  21.900000
# 2               1  27.132950  24.000000      12.0         5.6  21.900000
# 3               0  27.157940  24.000000      12.3         5.6  21.900000
# 4               1  27.157730  24.100000      12.4         5.2  22.000000
# ..            ...        ...        ...       ...         ...        ...
# 223            14  35.633333  18.799999       9.2         4.2  16.700001
# 224            13  35.685852  17.900000       9.7         4.2  15.600000
# 225            15  35.759465  18.500000       8.3         3.9  15.500000
# 226            11  35.766667  17.299999       9.4         4.3  15.200000
# 227            16  35.783333  17.299999       9.6         4.1  14.500000
#
#      Bio_Pre_Qfr  Bio_Pre_hum
# 0             19           15
# 1             14            8
# 2             14            8
# 3             14            8
# 4             13            8
# ..           ...          ...
# 223          289          119
# 224          307          125
# 225          347          140
# 226          355          132
# 227          355          142
#
# [228 rows x 45 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR20, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR20, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR20, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR20, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR20, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR20, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR20, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR20, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR20, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR20, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR20, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.54347826 0.56521739 0.67391304 0.53333333 0.6       ]
# moy_accuracy: 0.58
# -------------------------------------------------
# sensibilité : [0.5        0.52631579 0.66666667 0.61111111 0.38095238]
# moy_sensibilité: 0.54
# -------------------------------------------------
# spécificité : [0.6        0.59259259 0.6875     0.48148148 0.79166667]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.09952267 0.11754157 0.33864811 0.09128709 0.19000163]
# MCC: 0.17
# -------------------------------------------------
# precision-po: [0.61904762 0.47619048 0.8        0.44       0.61538462]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.48       0.64       0.52380952 0.65       0.59375   ]
# moy_precision-ne: 0.58
# -------------------------------------------------
# AUC : [0.52788462 0.61013645 0.73333333 0.60288066 0.73412698]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [12 16 11 13 19]
# VP : [13 10 20 11  8]
# FP : [ 8 11  5 14  5]
# FN : [13  9 10  7 13]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.58695652 0.52173913 0.67391304 0.57777778 0.6       ]
# moy_accuracy: 0.59
# -------------------------------------------------
# sensibilité : [0.5        0.47368421 0.66666667 0.55555556 0.57142857]
# moy_sensibilité: 0.55
# -------------------------------------------------
# spécificité : [0.7        0.55555556 0.6875     0.59259259 0.625     ]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.2013599  0.02890367 0.33864811 0.14547859 0.19642857]
# MCC: 0.18
# -------------------------------------------------
# precision-po: [0.68421053 0.42857143 0.8        0.47619048 0.57142857]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.51851852 0.6        0.52380952 0.66666667 0.625     ]
# moy_precision-ne: 0.59
# -------------------------------------------------
# AUC : [0.68269231 0.54191033 0.67916667 0.59876543 0.59325397]
# moy_AUC: 0.62
# -------------------------------------------------
# VN : [14 15 11 16 15]
# VP : [13  9 20 10 12]
# FP : [ 6 12  5 11  9]
# FN : [13 10 10  8  9]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.56521739 0.65217391 0.67391304 0.51111111 0.66666667]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.61538462 0.57894737 0.63333333 0.61111111 0.52380952]
# moy_sensibilité: 0.59
# -------------------------------------------------
# spécificité : [0.55       0.59259259 0.6875     0.44444444 0.79166667]
# moy_spécificité: 0.61
# -------------------------------------------------
# MCC : [ 0.13740858  0.14159847  0.30590258 -0.0725954   0.42184792]
# MCC: 0.19
# -------------------------------------------------
# precision-po: [0.66666667 0.45       0.7826087  0.43478261 0.75      ]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.47826087 0.75       0.47826087 0.66666667 0.63333333]
# moy_precision-ne: 0.60
# -------------------------------------------------
# AUC : [0.52403846 0.62573099 0.72708333 0.59259259 0.74801587]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [11 18 11 13 19]
# VP : [16 12 21 10 11]
# FP : [ 9 11  5 14  4]
# FN : [11  8 11  7  8]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.56521739 0.54347826 0.67391304 0.53333333 0.6       ]
# moy_accuracy: 0.58
# -------------------------------------------------
# sensibilité : [0.61538462 0.52631579 0.66666667 0.55555556 0.33333333]
# moy_sensibilité: 0.54
# -------------------------------------------------
# spécificité : [0.5        0.55555556 0.6875     0.51851852 0.83333333]
# moy_spécificité: 0.62
# -------------------------------------------------
# MCC : [0.11538462 0.08070002 0.33864811 0.0725954  0.1934765 ]
# MCC: 0.16
# -------------------------------------------------
# precision-po: [0.61538462 0.45454545 0.8        0.43478261 0.63636364]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.5        0.625      0.52380952 0.63636364 0.58823529]
# moy_precision-ne: 0.57
# -------------------------------------------------
# AUC : [0.54711538 0.65692008 0.71041667 0.54938272 0.74404762]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [10 15 11 14 20]
# VP : [16 10 20 10  7]
# FP : [10 12  5 13  4]
# FN : [10  9 10  8 14]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.69565217 0.54347826 0.7173913  0.55555556 0.62222222]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.84615385 0.63157895 0.76666667 0.66666667 0.66666667]
# moy_sensibilité: 0.72
# -------------------------------------------------
# spécificité : [0.5        0.48148148 0.625      0.48148148 0.58333333]
# moy_spécificité: 0.53
# -------------------------------------------------
# MCC : [0.37293387 0.11229687 0.38646821 0.14694367 0.25      ]
# MCC: 0.25
# -------------------------------------------------
# precision-po: [0.6875     0.46153846 0.79310345 0.46153846 0.58333333]
# moy_precision-po: 0.60
# -------------------------------------------------
# precision-ne : [0.71428571 0.65       0.58823529 0.68421053 0.66666667]
# moy_precision-ne: 0.66
# -------------------------------------------------
# AUC : [0.79423077 0.60038986 0.72291667 0.65020576 0.67857143]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [10 13 10 13 14]
# VP : [22 12 23 12 14]
# FP : [10 14  6 14 10]
# FN : [4 7 7 6 7]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.63043478 0.54347826 0.67391304 0.62222222 0.62222222]
# moy_accuracy: 0.62
# -------------------------------------------------
# sensibilité : [0.53846154 0.57894737 0.7        0.55555556 0.57142857]
# moy_sensibilité: 0.59
# -------------------------------------------------
# spécificité : [0.75       0.51851852 0.625      0.66666667 0.66666667]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.29042293 0.09607145 0.31437304 0.22041551 0.23904572]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.73684211 0.45833333 0.77777778 0.52631579 0.6       ]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.55555556 0.63636364 0.52631579 0.69230769 0.64      ]
# moy_precision-ne: 0.61
# -------------------------------------------------
# AUC : [0.66538462 0.54093567 0.67604167 0.63271605 0.64583333]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [15 14 10 18 16]
# VP : [14 11 21 10 12]
# FP : [ 5 13  6  9  8]
# FN : [12  8  9  8  9]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 40 %  (90 variables)

# %%
A["variable"][0:90]
# Out:
# 162        Prec_Oct
# 163        Prec_Nov
# 171       Rad_Juill
# 172        Rad_Aout
# 157        Prec_Mai
#            ...
# 209        Vap_Sept
# 59        Var_TempN
# 102    Elev_Moyenne
# 104        Elev_Moy
# 103        Elev_Min
# Name: variable, Length: 90, dtype: object

# %%
S40=A["variable"][0:90].values.tolist()

# %%
S40
# Out:
# ['Prec_Oct',
#  'Prec_Nov',
#  'Rad_Juill',
#  'Rad_Aout',
#  'Prec_Mai',
#  'Bio_Pre_Ann',
#  'Prec_Juin',
#  'Vent_Juill',
#  'Prec_Mars',
#  'Prec_Avril',
#  'Bio_Thum_Moy',
#  'Vent_Juin',
#  'Amp1_TempJ',
#  'Tmin_Mars',
#  'Prec_Fev',
#  'Var_TempJ',
#  'Vent_Aout',
#  'Tmax_Nov',
#  'Tmin_Avril',
#  'Isoth',
#  'Tmin_Fev',
#  'Rad_Janv',
#  'Sol_Limon',
#  'VarT_tri_TempJ',
#  'Bio_Pre_Qhum',
#  'Bio_Tfr_Moy',
#  'Rad_Dec',
#  'Rad_Nov',
#  'Rad_Fev',
#  'Vent_Mai',
#  'Tmin_Nov',
#  'Tmax_Dec',
#  'Tmin_Mai',
#  'Tmax_Fev',
#  'Rad_Mars',
#  'Tmin_Janv',
#  'Vent_Janv',
#  'Bio_Pre_Qsec',
#  'Y_lat',
#  'Tmax_Mars',
#  'Bio_Tmin',
#  'Vent_Avril',
#  'Tmax_Janv',
#  'Bio_Pre_Qfr',
#  'Bio_Pre_hum',
#  'Rad_Avril',
#  'Bio_Ta_moy',
#  'Tmin_Dec',
#  'VarT_bi_TempJ',
#  'Prec_Sept',
#  'Tmax_Oct',
#  'Rad_Oct',
#  'Tmin_Oct',
#  'Prec_Dec',
#  'Bio_Saison',
#  'Prec_Janv',
#  'Sol_Carbone_stock',
#  'VarT_ann_TempJ',
#  'Vent_Nov',
#  'Sol_teneur',
#  'Rad_Juin',
#  'Bio_Pre_Qch',
#  'Tmax_Avril',
#  'Ph2_TempN',
#  'Tmin_Juin',
#  'Ph3_NDVI',
#  'X_long',
#  'Amp1_TempN',
#  'Sol_Carbone',
#  'VarT_bi_TempN',
#  'Sol_Sable',
#  'Vent_Mars',
#  'Ph2_TempJ',
#  'Vap_Nov',
#  'Vap_Oct',
#  'Vap_Avril',
#  'Sol_Carbone_terreFine',
#  'Vent_Sept',
#  'Vap_Dec',
#  'Vent_Oct',
#  'Vap_Mars',
#  'Vap_Fev',
#  'Vent_Dec',
#  'CEC',
#  'Vap_Mai',
#  'Vap_Sept',
#  'Var_TempN',
#  'Elev_Moyenne',
#  'Elev_Moy',
#  'Elev_Min']

# %%
XR40=X[S40]

# %%
XR40
# Out:
#      Prec_Oct  Prec_Nov  Rad_Juill  Rad_Aout  Prec_Mai  Bio_Pre_Ann  \
# 0           3         4      23739     23115         1           48
# 1           3         7      23135     22648         0           29
# 2           3         7      23135     22648         0           29
# 3           3         7      23055     22569         0           27
# 4           3         6      23035     22619         0           26
# ..        ...       ...        ...       ...       ...          ...
# 223        53        70      26270     23844        30          601
# 224        58        77      25964     23662        32          638
# 225        76       126      27084     24585        39          782
# 226        59        90      26073     23626        33          709
# 227        76       128      27092     24794        39          801
#
#      Prec_Juin  Vent_Juill  Prec_Mars  Prec_Avril  ...  Vap_Mars  Vap_Fev  \
# 0            0         7.5          1           1  ...      1.55     1.44
# 1            1         5.9          2           1  ...      1.42     1.32
# 2            1         5.9          2           1  ...      1.42     1.32
# 3            1         6.2          1           1  ...      1.43     1.33
# 4            1         6.2          1           1  ...      1.44     1.34
# ..         ...         ...        ...         ...  ...       ...      ...
# 223         10         4.0         68          62  ...      1.24     1.18
# 224          9         4.0         72          63  ...      1.24     1.17
# 225         12         3.6         95          65  ...      1.21     1.15
# 226          7         3.9         88          58  ...      1.20     1.14
# 227         13         3.7        103          65  ...      1.21     1.15
#
#      Vent_Dec        CEC  Vap_Mai  Vap_Sept  Var_TempN  Elev_Moyenne  \
# 0         4.9  11.166667     1.72      2.16          3           6.0
# 1         3.8  12.750000     1.62      2.09          9          69.0
# 2         3.8  12.750000     1.62      2.09          9          69.0
# 3         3.9  12.000000     1.64      2.10          8          50.0
# 4         3.8  12.750000     1.65      2.13          9          16.5
# ..        ...        ...      ...       ...        ...           ...
# 223       3.8  18.250000     1.54      2.02          0           5.0
# 224       4.3  24.333333     1.53      2.01         19          13.5
# 225       3.9  21.083333     1.48      1.93         24          52.5
# 226       4.2  27.000000     1.47      1.93         19         112.0
# 227       4.0  19.250000     1.48      1.92         21          69.0
#
#      Elev_Moy  Elev_Min
# 0      5.7500         0
# 1     69.1250        60
# 2     69.1250        60
# 3     51.1875         7
# 4     16.9375       -49
# ..        ...       ...
# 223    5.3750         0
# 224   14.6250         0
# 225   54.1250        39
# 226  108.1875        35
# 227   66.6875        45
#
# [228 rows x 90 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR40, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR40, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR40, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR40, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR40, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR40, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR40, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR40, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR40, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR40, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR40, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.54347826 0.60869565 0.67391304 0.48888889 0.62222222]
# moy_accuracy: 0.59
# -------------------------------------------------
# sensibilité : [0.53846154 0.57894737 0.66666667 0.5        0.52380952]
# moy_sensibilité: 0.56
# -------------------------------------------------
# spécificité : [0.55       0.62962963 0.6875     0.48148148 0.70833333]
# moy_spécificité: 0.61
# -------------------------------------------------
# MCC : [ 0.0877058   0.20617948  0.33864811 -0.01814885  0.23640271]
# MCC: 0.17
# -------------------------------------------------
# precision-po: [0.60869565 0.52380952 0.8        0.39130435 0.61111111]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.47826087 0.68       0.52380952 0.59090909 0.62962963]
# moy_precision-ne: 0.58
# -------------------------------------------------
# AUC : [0.56634615 0.60038986 0.74375    0.51440329 0.66865079]
# moy_AUC: 0.62
# -------------------------------------------------
# VN : [11 17 11 13 17]
# VP : [14 11 20  9 11]
# FP : [ 9 10  5 14  7]
# FN : [12  8 10  9 10]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.54347826 0.60869565 0.58695652 0.57777778 0.71111111]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.57692308 0.57894737 0.7        0.5        0.71428571]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.5        0.62962963 0.375      0.62962963 0.70833333]
# moy_spécificité: 0.57
# -------------------------------------------------
# MCC : [0.0765559  0.20617948 0.07620008 0.12857571 0.42178301]
# MCC: 0.18
# -------------------------------------------------
# precision-po: [0.6        0.52380952 0.67741935 0.47368421 0.68181818]
# moy_precision-po: 0.59
# -------------------------------------------------
# precision-ne : [0.47619048 0.68       0.4        0.65384615 0.73913043]
# moy_precision-ne: 0.59
# -------------------------------------------------
# AUC : [0.51153846 0.59064327 0.60625    0.70576132 0.70634921]
# moy_AUC: 0.62
# -------------------------------------------------
# VN : [10 17  6 17 17]
# VP : [15 11 21  9 15]
# FP : [10 10 10 10  7]
# FN : [11  8  9  9  6]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.60869565 0.52173913 0.73913043 0.46666667 0.66666667]
# moy_accuracy: 0.60
# -------------------------------------------------
# sensibilité : [0.61538462 0.57894737 0.63333333 0.44444444 0.66666667]
# moy_sensibilité: 0.59
# -------------------------------------------------
# spécificité : [0.5        0.62962963 0.6875     0.44444444 0.79166667]
# moy_spécificité: 0.61
# -------------------------------------------------
# MCC : [0.20384615 0.33301829 0.30590258 0.0725954  0.46294909]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.62962963 0.5        0.79166667 0.44       0.76470588]
# moy_precision-po: 0.63
# -------------------------------------------------
# precision-ne : [0.52631579 0.70833333 0.5        0.66666667 0.66666667]
# moy_precision-ne: 0.61
# -------------------------------------------------
# AUC : [0.54903846 0.63937622 0.75208333 0.55761317 0.73611111]
# moy_AUC: 0.65
# -------------------------------------------------
# VN : [10 17 11 14 18]
# VP : [17 10 22  9 13]
# FP : [ 9 11  4 15  6]
# FN : [11  8  9  9  8]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.58695652 0.56521739 0.7173913  0.53333333 0.68888889]
# moy_accuracy: 0.62
# -------------------------------------------------
# sensibilité : [0.65384615 0.52631579 0.73333333 0.61111111 0.52380952]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.5        0.59259259 0.6875     0.48148148 0.83333333]
# moy_spécificité: 0.62
# -------------------------------------------------
# MCC : [0.15489223 0.11754157 0.40707278 0.09128709 0.37796447]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.62962963 0.47619048 0.81481481 0.44       0.73333333]
# moy_precision-po: 0.62
# -------------------------------------------------
# precision-ne : [0.52631579 0.64       0.57894737 0.65       0.66666667]
# moy_precision-ne: 0.61
# -------------------------------------------------
# AUC : [0.53365385 0.59844055 0.75833333 0.52880658 0.7718254 ]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [10 16 11 13 20]
# VP : [17 10 22 11 11]
# FP : [10 11  5 14  4]
# FN : [ 9  9  8  7 10]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.67391304 0.58695652 0.73913043 0.57777778 0.62222222]
# moy_accuracy: 0.64
# -------------------------------------------------
# sensibilité : [0.84615385 0.68421053 0.8        0.66666667 0.66666667]
# moy_sensibilité: 0.73
# -------------------------------------------------
# spécificité : [0.45       0.51851852 0.625      0.51851852 0.58333333]
# moy_spécificité: 0.54
# -------------------------------------------------
# MCC : [0.32605465 0.2013599  0.425      0.18257419 0.25      ]
# MCC: 0.28
# -------------------------------------------------
# precision-po: [0.66666667 0.5        0.8        0.48       0.58333333]
# moy_precision-po: 0.61
# -------------------------------------------------
# precision-ne : [0.69230769 0.7        0.625      0.7        0.66666667]
# moy_precision-ne: 0.68
# -------------------------------------------------
# AUC : [0.79423077 0.61306043 0.71770833 0.63786008 0.70337302]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [ 9 14 10 14 14]
# VP : [22 13 24 12 14]
# FP : [11 13  6 13 10]
# FN : [4 6 6 6 7]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.58695652 0.54347826 0.63043478 0.57777778 0.68888889]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.53846154 0.52631579 0.66666667 0.55555556 0.57142857]
# moy_sensibilité: 0.57
# -------------------------------------------------
# spécificité : [0.65       0.55555556 0.5625     0.59259259 0.79166667]
# moy_spécificité: 0.63
# -------------------------------------------------
# MCC : [0.18756196 0.08070002 0.2216733  0.14547859 0.37362192]
# MCC: 0.20
# -------------------------------------------------
# precision-po: [0.66666667 0.45454545 0.74074074 0.47619048 0.70588235]
# moy_precision-po: 0.61
# -------------------------------------------------
# precision-ne : [0.52       0.625      0.47368421 0.66666667 0.67857143]
# moy_precision-ne: 0.59
# -------------------------------------------------
# AUC : [0.6        0.52826511 0.66979167 0.61625514 0.74404762]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [13 15  9 16 19]
# VP : [14 10 20 10 12]
# FP : [ 7 12  7 11  5]
# FN : [12  9 10  8  9]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # three-shold 50 %  (113 variables)

# %%
A["variable"][0:113]
# Out:
# 162          Prec_Oct
# 163          Prec_Nov
# 171         Rad_Juill
# 172          Rad_Aout
# 157          Prec_Mai
#             ...
# 148    Bio_Pre_Saison
# 85            Ph2_EVI
# 10        Lesfeuillus
# 76           Amp2_EVI
# 81        VarT_cy_EVI
# Name: variable, Length: 113, dtype: object

# %%
S50=A["variable"][0:113].values.tolist()

# %%
S50
# Out:
# ['Prec_Oct',
#  'Prec_Nov',
#  'Rad_Juill',
#  'Rad_Aout',
#  'Prec_Mai',
#  'Bio_Pre_Ann',
#  'Prec_Juin',
#  'Vent_Juill',
#  'Prec_Mars',
#  'Prec_Avril',
#  'Bio_Thum_Moy',
#  'Vent_Juin',
#  'Amp1_TempJ',
#  'Tmin_Mars',
#  'Prec_Fev',
#  'Var_TempJ',
#  'Vent_Aout',
#  'Tmax_Nov',
#  'Tmin_Avril',
#  'Isoth',
#  'Tmin_Fev',
#  'Rad_Janv',
#  'Sol_Limon',
#  'VarT_tri_TempJ',
#  'Bio_Pre_Qhum',
#  'Bio_Tfr_Moy',
#  'Rad_Dec',
#  'Rad_Nov',
#  'Rad_Fev',
#  'Vent_Mai',
#  'Tmin_Nov',
#  'Tmax_Dec',
#  'Tmin_Mai',
#  'Tmax_Fev',
#  'Rad_Mars',
#  'Tmin_Janv',
#  'Vent_Janv',
#  'Bio_Pre_Qsec',
#  'Y_lat',
#  'Tmax_Mars',
#  'Bio_Tmin',
#  'Vent_Avril',
#  'Tmax_Janv',
#  'Bio_Pre_Qfr',
#  'Bio_Pre_hum',
#  'Rad_Avril',
#  'Bio_Ta_moy',
#  'Tmin_Dec',
#  'VarT_bi_TempJ',
#  'Prec_Sept',
#  'Tmax_Oct',
#  'Rad_Oct',
#  'Tmin_Oct',
#  'Prec_Dec',
#  'Bio_Saison',
#  'Prec_Janv',
#  'Sol_Carbone_stock',
#  'VarT_ann_TempJ',
#  'Vent_Nov',
#  'Sol_teneur',
#  'Rad_Juin',
#  'Bio_Pre_Qch',
#  'Tmax_Avril',
#  'Ph2_TempN',
#  'Tmin_Juin',
#  'Ph3_NDVI',
#  'X_long',
#  'Amp1_TempN',
#  'Sol_Carbone',
#  'VarT_bi_TempN',
#  'Sol_Sable',
#  'Vent_Mars',
#  'Ph2_TempJ',
#  'Vap_Nov',
#  'Vap_Oct',
#  'Vap_Avril',
#  'Sol_Carbone_terreFine',
#  'Vent_Sept',
#  'Vap_Dec',
#  'Vent_Oct',
#  'Vap_Mars',
#  'Vap_Fev',
#  'Vent_Dec',
#  'CEC',
#  'Vap_Mai',
#  'Vap_Sept',
#  'Var_TempN',
#  'Elev_Moyenne',
#  'Elev_Moy',
#  'Elev_Min',
#  'Elev_Max',
#  'Vap_Janv',
#  'VarT_cy_TempJ',
#  'Prec_Aout',
#  'Ph1_EVI',
#  'Sol_pH_KCL',
#  'Tmax_Sept',
#  'Vap_Juin',
#  'Bio_Tint',
#  'Vap_Aout',
#  'Vent_Fev',
#  'Tmax_Mai',
#  'Tmin_Sept',
#  'Bio_Pre_sec',
#  'Vap_Juill',
#  'VarT_ann_TempN',
#  'Amp2_IRM',
#  'Pl_herb',
#  'Bio_Pre_Saison',
#  'Ph2_EVI',
#  'Lesfeuillus',
#  'Amp2_EVI',
#  'VarT_cy_EVI']

# %%
XR50=X[S50]

# %%
XR50
# Out:
#      Prec_Oct  Prec_Nov  Rad_Juill  Rad_Aout  Prec_Mai  Bio_Pre_Ann  \
# 0           3         4      23739     23115         1           48
# 1           3         7      23135     22648         0           29
# 2           3         7      23135     22648         0           29
# 3           3         7      23055     22569         0           27
# 4           3         6      23035     22619         0           26
# ..        ...       ...        ...       ...       ...          ...
# 223        53        70      26270     23844        30          601
# 224        58        77      25964     23662        32          638
# 225        76       126      27084     24585        39          782
# 226        59        90      26073     23626        33          709
# 227        76       128      27092     24794        39          801
#
#      Prec_Juin  Vent_Juill  Prec_Mars  Prec_Avril  ...  Bio_Pre_sec  \
# 0            0         7.5          1           1  ...            0
# 1            1         5.9          2           1  ...            0
# 2            1         5.9          2           1  ...            0
# 3            1         6.2          1           1  ...            0
# 4            1         6.2          1           1  ...            0
# ..         ...         ...        ...         ...  ...          ...
# 223         10         4.0         68          62  ...            1
# 224          9         4.0         72          63  ...            1
# 225         12         3.6         95          65  ...            1
# 226          7         3.9         88          58  ...            1
# 227         13         3.7        103          65  ...            1
#
#      Vap_Juill  VarT_ann_TempN  Amp2_IRM  Pl_herb  Bio_Pre_Saison  Ph2_EVI  \
# 0         2.07              63       110        0      105.140599      419
# 1         2.03              72        10        0       77.394709      243
# 2         2.03              72        10        0       77.394709      243
# 3         2.04              66        40        0       84.137238      372
# 4         2.07              72        70        0       79.471941       21
# ..         ...             ...       ...      ...             ...      ...
# 223       2.06               0        10        0       75.390541      379
# 224       2.05              92        50        0       75.660918      239
# 225       1.97              91        30       10       75.072807      401
# 226       1.96              92        70        0       79.066686      459
# 227       1.97              91         0        0       75.152004      457
#
#      Lesfeuillus  Amp2_EVI  VarT_cy_EVI
# 0              0        48           13
# 1              0        16           15
# 2              0        16           15
# 3              0         7            8
# 4              0        71            2
# ..           ...       ...          ...
# 223            0        93            5
# 224           25        14           44
# 225            0        50           53
# 226            0       155           69
# 227            0        85           32
#
# [228 rows x 113 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XR50, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XR50, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XR50, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XR50, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XR50, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XR50, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XR50, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XR50, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XR50, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XR50, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XR50, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.54347826 0.58695652 0.60869565 0.44444444 0.64444444]
# moy_accuracy: 0.57
# -------------------------------------------------
# sensibilité : [0.53846154 0.63157895 0.56666667 0.38888889 0.57142857]
# moy_sensibilité: 0.54
# -------------------------------------------------
# spécificité : [0.55       0.55555556 0.6875     0.48148148 0.70833333]
# moy_spécificité: 0.60
# -------------------------------------------------
# MCC : [ 0.0877058   0.18445719  0.24233841 -0.12729377  0.28257932]
# MCC: 0.13
# -------------------------------------------------
# precision-po: [0.60869565 0.5        0.77272727 0.33333333 0.63157895]
# moy_precision-po: 0.57
# -------------------------------------------------
# precision-ne : [0.47826087 0.68181818 0.45833333 0.54166667 0.65384615]
# moy_precision-ne: 0.56
# -------------------------------------------------
# AUC : [0.57211538 0.61208577 0.73958333 0.50823045 0.68055556]
# moy_AUC: 0.62
# -------------------------------------------------
# VN : [11 15 11 13 17]
# VP : [14 12 17  7 12]
# FP : [ 9 12  5 14  7]
# FN : [12  7 13 11  9]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.5        0.56521739 0.65217391 0.71111111 0.62222222]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.5        0.52631579 0.73333333 0.66666667 0.61904762]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.5        0.59259259 0.5        0.74074074 0.625     ]
# moy_spécificité: 0.59
# -------------------------------------------------
# MCC : [0.         0.11754157 0.23333333 0.4040951  0.24356483]
# MCC: 0.20
# -------------------------------------------------
# precision-po: [0.56521739 0.47619048 0.73333333 0.63157895 0.59090909]
# moy_precision-po: 0.60
# -------------------------------------------------
# precision-ne : [0.43478261 0.64       0.5        0.76923077 0.65217391]
# moy_precision-ne: 0.60
# -------------------------------------------------
# AUC : [0.52692308 0.59844055 0.65       0.73868313 0.74404762]
# moy_AUC: 0.65
# -------------------------------------------------
# VN : [10 16  8 20 15]
# VP : [13 10 22 12 13]
# FP : [10 11  8  7  9]
# FN : [13  9  8  6  8]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.5        0.65217391 0.7173913  0.57777778 0.68888889]
# moy_accuracy: 0.63
# -------------------------------------------------
# sensibilité : [0.65384615 0.68421053 0.6        0.61111111 0.66666667]
# moy_sensibilité: 0.64
# -------------------------------------------------
# spécificité : [0.5        0.66666667 0.75       0.48148148 0.70833333]
# moy_spécificité: 0.62
# -------------------------------------------------
# MCC : [0.15489223 0.24395526 0.36514837 0.01814885 0.3727642 ]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.62962963 0.5        0.81818182 0.40909091 0.65      ]
# moy_precision-po: 0.60
# -------------------------------------------------
# precision-ne : [0.55       0.70833333 0.61111111 0.61904762 0.66666667]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.52980769 0.66861598 0.73541667 0.56995885 0.73809524]
# moy_AUC: 0.65
# -------------------------------------------------
# VN : [10 16 11 14 18]
# VP : [18 12 17 12 13]
# FP : [11 12  4 15  7]
# FN : [13  6  8  9  8]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.56521739 0.63043478 0.69565217 0.53333333 0.64444444]
# moy_accuracy: 0.61
# -------------------------------------------------
# sensibilité : [0.61538462 0.73684211 0.7        0.61111111 0.47619048]
# moy_sensibilité: 0.63
# -------------------------------------------------
# spécificité : [0.5        0.55555556 0.6875     0.48148148 0.79166667]
# moy_spécificité: 0.60
# -------------------------------------------------
# MCC : [0.11538462 0.29042293 0.37229796 0.09128709 0.28347335]
# MCC: 0.23
# -------------------------------------------------
# precision-po: [0.61538462 0.53846154 0.80769231 0.44       0.66666667]
# moy_precision-po: 0.61
# -------------------------------------------------
# precision-ne : [0.5        0.75       0.55       0.65       0.63333333]
# moy_precision-ne: 0.62
# -------------------------------------------------
# AUC : [0.52980769 0.63352827 0.73333333 0.48765432 0.74603175]
# moy_AUC: 0.63
# -------------------------------------------------
# VN : [10 15 11 13 19]
# VP : [16 14 21 11 10]
# FP : [10 12  5 14  5]
# FN : [10  5  9  7 11]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.73913043 0.60869565 0.7173913  0.57777778 0.71111111]
# moy_accuracy: 0.67
# -------------------------------------------------
# sensibilité : [0.84615385 0.68421053 0.76666667 0.66666667 0.71428571]
# moy_sensibilité: 0.74
# -------------------------------------------------
# spécificité : [0.6        0.55555556 0.625      0.51851852 0.70833333]
# moy_spécificité: 0.60
# -------------------------------------------------
# MCC : [0.46437165 0.23701006 0.38646821 0.18257419 0.42178301]
# MCC: 0.34
# -------------------------------------------------
# precision-po: [0.73333333 0.52       0.79310345 0.48       0.68181818]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.75       0.71428571 0.58823529 0.7        0.73913043]
# moy_precision-ne: 0.70
# -------------------------------------------------
# AUC : [0.79038462 0.61306043 0.69583333 0.62962963 0.73511905]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [12 15 10 14 17]
# VP : [22 13 23 12 15]
# FP : [ 8 12  6 13  7]
# FN : [4 6 7 6 6]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.60869565 0.56521739 0.69565217 0.62222222 0.71111111]
# moy_accuracy: 0.64
# -------------------------------------------------
# sensibilité : [0.53846154 0.52631579 0.73333333 0.61111111 0.61904762]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.7        0.59259259 0.625      0.62962963 0.79166667]
# moy_spécificité: 0.67
# -------------------------------------------------
# MCC : [0.23846154 0.11754157 0.34969753 0.23640271 0.41825096]
# MCC: 0.27
# -------------------------------------------------
# precision-po: [0.7        0.47619048 0.78571429 0.52380952 0.72222222]
# moy_precision-po: 0.64
# -------------------------------------------------
# precision-ne : [0.53846154 0.64       0.55555556 0.70833333 0.7037037 ]
# moy_precision-ne: 0.63
# -------------------------------------------------
# AUC : [0.60288462 0.53216374 0.71666667 0.60596708 0.73115079]
# moy_AUC: 0.64
# -------------------------------------------------
# VN : [14 16 10 17 19]
# VP : [14 10 22 11 13]
# FP : [ 6 11  6 10  5]
# FN : [12  9  8  7  8]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # log2  (7 variables)

# %%
A["variable"][0:7]
# Out:
# 162       Prec_Oct
# 163       Prec_Nov
# 171      Rad_Juill
# 172       Rad_Aout
# 157       Prec_Mai
# 145    Bio_Pre_Ann
# 158      Prec_Juin
# Name: variable, dtype: object

# %%
SL=A["variable"][0:7].values.tolist()

# %%
SL
# Out:
# ['Prec_Oct',
#  'Prec_Nov',
#  'Rad_Juill',
#  'Rad_Aout',
#  'Prec_Mai',
#  'Bio_Pre_Ann',
#  'Prec_Juin']

# %%
XRL=X[SL]

# %%
XRL
# Out:
#      Prec_Oct  Prec_Nov  Rad_Juill  Rad_Aout  Prec_Mai  Bio_Pre_Ann  Prec_Juin
# 0           3         4      23739     23115         1           48          0
# 1           3         7      23135     22648         0           29          1
# 2           3         7      23135     22648         0           29          1
# 3           3         7      23055     22569         0           27          1
# 4           3         6      23035     22619         0           26          1
# ..        ...       ...        ...       ...       ...          ...        ...
# 223        53        70      26270     23844        30          601         10
# 224        58        77      25964     23662        32          638          9
# 225        76       126      27084     24585        39          782         12
# 226        59        90      26073     23626        33          709          7
# 227        76       128      27092     24794        39          801         13
#
# [228 rows x 7 columns]

# %%
classifiers = {
"XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.5,max_depth=5,n_estimators=150,objective="binary:logistic"),
"LogisticRegression": LogisticRegression(max_iter=1000, solver='lbfgs', class_weight='balanced'),
"RandomForestClassifier": RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7 ,min_samples_split=3),
"GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=3, max_depth=5, random_state=0,min_samples_leaf=2,subsample=1 ),
"Gaussian":GaussianNB(),
"KNN":KNeighborsClassifier(n_neighbors=5)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XRL, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XRL, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XRL, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XRL, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XRL, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XRL, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XRL, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XRL, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XRL, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XRL, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XRL, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %.2f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %.2f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %.2f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %.2f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGBClassifier
# Accuracy: [0.5        0.60869565 0.43478261 0.46666667 0.66666667]
# moy_accuracy: 0.54
# -------------------------------------------------
# sensibilité : [0.53846154 0.52631579 0.33333333 0.5        0.52380952]
# moy_sensibilité: 0.48
# -------------------------------------------------
# spécificité : [0.45       0.66666667 0.625      0.44444444 0.79166667]
# moy_spécificité: 0.60
# -------------------------------------------------
# MCC : [-0.01148339  0.19298246 -0.04166667 -0.05455447  0.32879323]
# MCC: 0.08
# -------------------------------------------------
# precision-po: [0.56       0.52631579 0.625      0.375      0.6875    ]
# moy_precision-po: 0.55
# -------------------------------------------------
# precision-ne : [0.42857143 0.66666667 0.33333333 0.57142857 0.65517241]
# moy_precision-ne: 0.53
# -------------------------------------------------
# AUC : [0.50961538 0.55555556 0.6        0.55761317 0.72916667]
# moy_AUC: 0.59
# -------------------------------------------------
# VN : [ 9 18 10 12 19]
# VP : [14 10 10  9 11]
# FP : [11  9  6 15  5]
# FN : [12  9 20  9 10]
# -------------------------------------------------
# -------------------------------------------------
# LogisticRegression
# Accuracy: [0.67391304 0.60869565 0.7173913  0.66666667 0.62222222]
# moy_accuracy: 0.66
# -------------------------------------------------
# sensibilité : [0.61538462 0.57894737 0.73333333 0.61111111 0.52380952]
# moy_sensibilité: 0.61
# -------------------------------------------------
# spécificité : [0.75       0.62962963 0.6875     0.7037037  0.70833333]
# moy_spécificité: 0.70
# -------------------------------------------------
# MCC : [0.36364053 0.20617948 0.40707278 0.3122553  0.23640271]
# MCC: 0.31
# -------------------------------------------------
# precision-po: [0.76190476 0.52380952 0.81481481 0.57894737 0.61111111]
# moy_precision-po: 0.66
# -------------------------------------------------
# precision-ne : [0.6        0.68       0.57894737 0.73076923 0.62962963]
# moy_precision-ne: 0.64
# -------------------------------------------------
# AUC : [0.73461538 0.62183236 0.7375     0.66872428 0.67063492]
# moy_AUC: 0.69
# -------------------------------------------------
# VN : [15 17 11 19 17]
# VP : [16 11 22 11 11]
# FP : [ 5 10  5  8  7]
# FN : [10  8  8  7 10]
# -------------------------------------------------
# -------------------------------------------------
# RandomForestClassifier
# Accuracy: [0.58695652 0.52173913 0.56521739 0.53333333 0.66666667]
# moy_accuracy: 0.57
# -------------------------------------------------
# sensibilité : [0.5        0.42105263 0.53333333 0.55555556 0.42857143]
# moy_sensibilité: 0.49
# -------------------------------------------------
# spécificité : [0.7        0.62962963 0.625      0.51851852 0.79166667]
# moy_spécificité: 0.65
# -------------------------------------------------
# MCC : [0.27560124 0.08948091 0.12315558 0.03636965 0.42184792]
# MCC: 0.19
# -------------------------------------------------
# precision-po: [0.66666667 0.4        0.83333333 0.41666667 0.69230769]
# moy_precision-po: 0.60
# -------------------------------------------------
# precision-ne : [0.53846154 0.57142857 0.43478261 0.61904762 0.65625   ]
# moy_precision-ne: 0.56
# -------------------------------------------------
# AUC : [0.57307692 0.56725146 0.67916667 0.56790123 0.73115079]
# moy_AUC: 0.62
# -------------------------------------------------
# VN : [13 17 12 13 19]
# VP : [14  8 19 10 10]
# FP : [ 9 12  5 15  4]
# FN : [12  9 13  8 10]
# -------------------------------------------------
# -------------------------------------------------
# GradientBoostingClassifier
# Accuracy: [0.54347826 0.52173913 0.5        0.55555556 0.64444444]
# moy_accuracy: 0.55
# -------------------------------------------------
# sensibilité : [0.53846154 0.42105263 0.36666667 0.66666667 0.42857143]
# moy_sensibilité: 0.48
# -------------------------------------------------
# spécificité : [0.55       0.59259259 0.75       0.48148148 0.83333333]
# moy_spécificité: 0.64
# -------------------------------------------------
# MCC : [0.0877058  0.01364522 0.11853345 0.14694367 0.28827833]
# MCC: 0.13
# -------------------------------------------------
# precision-po: [0.60869565 0.42105263 0.73333333 0.46153846 0.69230769]
# moy_precision-po: 0.58
# -------------------------------------------------
# precision-ne : [0.47826087 0.59259259 0.38709677 0.68421053 0.625     ]
# moy_precision-ne: 0.55
# -------------------------------------------------
# AUC : [0.49230769 0.56725146 0.63333333 0.57201646 0.69543651]
# moy_AUC: 0.59
# -------------------------------------------------
# VN : [11 16 12 13 20]
# VP : [14  8 11 12  9]
# FP : [ 9 11  4 14  4]
# FN : [12 11 19  6 12]
# -------------------------------------------------
# -------------------------------------------------
# Gaussian
# Accuracy: [0.73913043 0.54347826 0.69565217 0.53333333 0.57777778]
# moy_accuracy: 0.62
# -------------------------------------------------
# sensibilité : [0.80769231 0.57894737 0.7        0.66666667 0.61904762]
# moy_sensibilité: 0.67
# -------------------------------------------------
# spécificité : [0.65       0.51851852 0.6875     0.44444444 0.54166667]
# moy_spécificité: 0.57
# -------------------------------------------------
# MCC : [0.4649005  0.09607145 0.37229796 0.11111111 0.16071429]
# MCC: 0.24
# -------------------------------------------------
# precision-po: [0.75       0.45833333 0.80769231 0.44444444 0.54166667]
# moy_precision-po: 0.60
# -------------------------------------------------
# precision-ne : [0.72222222 0.63636364 0.55       0.66666667 0.61904762]
# moy_precision-ne: 0.64
# -------------------------------------------------
# AUC : [0.79615385 0.56920078 0.725      0.64609053 0.62103175]
# moy_AUC: 0.67
# -------------------------------------------------
# VN : [13 14 11 12 13]
# VP : [21 11 21 12 13]
# FP : [ 7 13  5 15 11]
# FN : [5 8 9 6 8]
# -------------------------------------------------
# -------------------------------------------------
# KNN
# Accuracy: [0.54347826 0.47826087 0.60869565 0.53333333 0.53333333]
# moy_accuracy: 0.54
# -------------------------------------------------
# sensibilité : [0.46153846 0.26315789 0.66666667 0.44444444 0.57142857]
# moy_sensibilité: 0.48
# -------------------------------------------------
# spécificité : [0.65       0.62962963 0.5        0.59259259 0.5       ]
# moy_spécificité: 0.57
# -------------------------------------------------
# MCC : [ 0.11229687 -0.11261015  0.16265001  0.03673592  0.07142857]
# MCC: 0.05
# -------------------------------------------------
# precision-po: [0.63157895 0.33333333 0.71428571 0.42105263 0.5       ]
# moy_precision-po: 0.52
# -------------------------------------------------
# precision-ne : [0.48148148 0.5483871  0.44444444 0.61538462 0.57142857]
# moy_precision-ne: 0.53
# -------------------------------------------------
# AUC : [0.56923077 0.40935673 0.54895833 0.58847737 0.52777778]
# moy_AUC: 0.53
# -------------------------------------------------
# VN : [13 17  8 16 12]
# VP : [12  5 20  8 12]
# FP : [ 7 10  8 11 12]
# FN : [14 14 10 10  9]
# -------------------------------------------------
# -------------------------------------------------
