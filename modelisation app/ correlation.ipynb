# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/mois1-mois2/blob/main/modelisation%20app/%20correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
def eta_squared(x,y):
    moyenne_y = np.mean(y)
    classes = []
    for classe in x.unique():
        yi_classe = y[x==classe]
        classes.append({'ni': len(yi_classe),
                        'moyenne_classe': np.mean(yi_classe)})
    SCT = np.sum([(yj-moyenne_y)**2 for yj in y])
    SCE = np.sum([c['ni']*(c['moyenne_classe']-moyenne_y)**2 for c in classes])
    return SCE/SCT

# %% [markdown]
# # cs_longia

# %%
Cl1 = '/content/apprentissage.xlsx' 
data1=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
del data1["Source"] 
del data1["CodeSite"] 
data1
# Out:
#         X_long      Y_lat  Cs_longia  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740          1  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950          1  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950          1  ...       4.3       3.7       3.8
# 3   -13.167180  27.157730          0  ...       4.2       3.6       3.8
# 4   -13.201560  27.165070          0  ...       4.6       3.8       3.9
# ..         ...        ...        ...  ...       ...       ...       ...
# 198  -5.366667  35.766667          1  ...       4.0       4.0       4.2
# 199  -5.816667  35.783333          1  ...       3.6       3.8       4.0
# 200  -5.366667  35.833333          1  ...       4.0       3.9       4.3
# 201  -5.558611  35.841944          1  ...       3.6       3.4       3.6
# 202  -5.483333  35.900000          1  ...       4.0       4.0       4.2
#
# [203 rows x 226 columns]

# %%
data1["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 198    1
# 199    1
# 200    1
# 201    1
# 202    1
# Name: Cs_longia, Length: 203, dtype: int64

# %%
A1 = data1.loc[:, data1.columns != 'Cs_longia']
x1 = data1.Cs_longia

# %%
T1=A1.columns

# %%
T1
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
lst1=[]

# %%
for variable in T1 :
  y=A1[variable]
  print("variable : ",variable,"/corrélation:",eta_squared(x1,y))
  lst1.append([variable,eta_squared(x1,y)])
# Out:
# variable :  X_long /corrélation: 0.014907543721239909
# variable :  Y_lat /corrélation: 0.02068798989320879
# variable :  Bovins /corrélation: 0.010665111172745101
# variable :  Volaille /corrélation: 0.002059064629224964
# variable :  Caprins /corrélation: 0.002395411809425821
# variable :  Ovins /corrélation: 0.04204309954175782
# variable :  Equides /corrélation: 0.018091886294064333
# variable :  Coniferes /corrélation: 0.011968742073335325
# variable :  ZoneAride /corrélation: 0.03050054399569615
# variable :  ZonePel /corrélation: 0.00036633449619265305
# variable :  Lesfeuillus /corrélation: 0.009433920401958094
# variable :  Caduc /corrélation: 0.0029761206919433343
# variable :  Autres /corrélation: 0.011099961815085527
# variable :  Arbrisseau /corrélation: 0.007557109485838745
# variable :  Pl_herb /corrélation: 0.018478786480108624
# variable :  VegCul /corrélation: 0.039576627200022654
# variable :  VegInond /corrélation: 0.0020188298246184527
# variable :  ZoneUrbaine /corrélation: 0.0004171651655154538
# variable :  Moy_IRM /corrélation: 0.03743052964886251
# variable :  Amp1_IRM /corrélation: 0.01587734968283396
# variable :  Amp2_IRM /corrélation: 0.007262591275823586
# variable :  Amp3_IRM /corrélation: 0.03142660100677615
# variable :  VarT_ann_IRM /corrélation: 0.006007776830812108
# variable :  VarT_bi_IRM /corrélation: 1.1933685247725788e-06
# variable :  VarT_tri_IRM /corrélation: 0.004880564744836453
# variable :  VarT_Cy_IRM /corrélation: 0.005486112288146263
# variable :  Min_IRM /corrélation: 0.04797182731866463
# variable :  Max_IRM /corrélation: 0.026548528613119224
# variable :  Ph1_IRM /corrélation: 0.039603028458924106
# variable :  Ph2_IRM /corrélation: 0.0032271674633766287
# variable :  Ph3_IRM /corrélation: 0.0158639360992941
# variable :  Var_IRM /corrélation: 0.01990193122772172
# variable :  Moy_TempJ /corrélation: 0.006018986922598286
# variable :  Amp1_TempJ /corrélation: 0.0006139492594806651
# variable :  Amp2_TempJ /corrélation: 0.014286869367858886
# variable :  Amp3_TempJ /corrélation: 0.10356228943658431
# variable :  VarT_ann_TempJ /corrélation: 0.0005845447343518414
# variable :  VarT_bi_TempJ /corrélation: 0.00647890332836792
# variable :  VarT_tri_TempJ /corrélation: 0.004876960833574715
# variable :  VarT_cy_TempJ /corrélation: 0.0019164630541541432
# variable :  Min_TempJ /corrélation: 0.00662961758619414
# variable :  Max_TempJ /corrélation: 0.005545015585406105
# variable :  Ph1_TempJ /corrélation: 0.00484480361506424
# variable :  Ph2_TempJ /corrélation: 0.0003035552250008039
# variable :  Ph3_TempJ /corrélation: 0.004743535907141725
# variable :  Var_TempJ /corrélation: 0.0019060909658719025
# variable :  Moy_TempN /corrélation: 0.006146831546416289
# variable :  Amp1_TempN /corrélation: 0.00012082575473083353
# variable :  Amp2_TempN /corrélation: 0.027647192547780895
# variable :  Amp3_TempN /corrélation: 0.0004310090281682975
# variable :  VarT_ann_TempN /corrélation: 3.5238004553850776e-05
# variable :  VarT_bi_TempN /corrélation: 0.01047654108422437
# variable :  VarT_tri_TempN /corrélation: 0.00012606587131395915
# variable :  VarT_cy_TempN /corrélation: 0.0004301460553803924
# variable :  Min_TempN /corrélation: 0.006427825397823434
# variable :  Max_TempN /corrélation: 0.005942398209396421
# variable :  Ph1_TempN /corrélation: 0.006905479123969625
# variable :  Ph2_TempN /corrélation: 4.88774797274175e-05
# variable :  Ph3_TempN /corrélation: 0.018405819548693175
# variable :  Var_TempN /corrélation: 0.0003252738404756975
# variable :  Moy_NDVI /corrélation: 0.026716522437302284
# variable :  Amp1_NDVI /corrélation: 0.04175305211226607
# variable :  Amp2_NDVI /corrélation: 0.028240546266286852
# variable :  Amp3_NDVI /corrélation: 0.02509801140287577
# variable :  VarT_ann_NDVI /corrélation: 0.010841397537050141
# variable :  VarT_bi_NDVI /corrélation: 0.0016622842730844554
# variable :  VarT_tri_NDVI /corrélation: 0.005720182388520715
# variable :  VarT_cy_NDVI /corrélation: 0.01343474020944027
# variable :  Min_NDVI /corrélation: 0.012963680155575268
# variable :  Max_NDVI /corrélation: 0.04208499695688243
# variable :  Ph1_NDVI /corrélation: 0.0005322685536080081
# variable :  Ph2_NDVI /corrélation: 0.00037035333839612717
# variable :  Ph3_NDVI /corrélation: 6.068740679473555e-06
# variable :  Var_NDVI /corrélation: 0.04762553180985702
# variable :  Moy_EVI /corrélation: 0.022262084144771148
# variable :  Amp1_EVI /corrélation: 0.03311057790876982
# variable :  Amp2_EVI /corrélation: 0.025005800021151072
# variable :  Amp3_EVI /corrélation: 0.042165864300414774
# variable :  VarT_ann_EVI /corrélation: 0.010047695313332973
# variable :  VarT_bi_EVI /corrélation: 0.0027173742639437313
# variable :  VarT_tri_EVI /corrélation: 0.009202038943418442
# variable :  VarT_cy_EVI /corrélation: 0.012149643511040767
# variable :  Min_EVI /corrélation: 0.008042128376333715
# variable :  Max_EVI /corrélation: 0.034296939572441135
# variable :  Ph1_EVI /corrélation: 0.00022402334681787935
# variable :  Ph2_EVI /corrélation: 1.5812751416545063e-06
# variable :  Ph3_EVI /corrélation: 0.006117844083269993
# variable :  Var_EVI /corrélation: 0.03413978678744323
# variable :  Ret_eau /corrélation: 0.011406058738050855
# variable :  Sol_teneur /corrélation: 0.006932744599287625
# variable :  Substratum /corrélation: 0.04223090184721784
# variable :  Prob_R /corrélation: 0.06283350437984474
# variable :  ProfAbs_Sub /corrélation: 0.014836359537072689
# variable :  CEC /corrélation: 0.008090085397247204
# variable :  Sol_Argile /corrélation: 0.00021329576411540597
# variable :  Sol_Carbone /corrélation: 0.004315432141072077
# variable :  Sol_Carbone_stock /corrélation: 0.00011811215053615652
# variable :  Sol_Carbone_terreFine /corrélation: 0.0006480813846004409
# variable :  Sol_pH_KCL /corrélation: 4.160686493813142e-05
# variable :  Sol_Limon /corrélation: 0.021521537586632652
# variable :  Sol_Sable /corrélation: 0.01916723947549685
# variable :  Elev_Max /corrélation: 0.01953635081901616
# variable :  Elev_Moyenne /corrélation: 0.017206476816811835
# variable :  Elev_Min /corrélation: 0.014246745636891597
# variable :  Elev_Moy /corrélation: 0.01686309463663451
# variable :  Elev_sd /corrélation: 0.019590864640288558
# variable :  Geom_maj /corrélation: 0.008738225079895834
# variable :  Geom_Shan /corrélation: 0.001215078561987139
# variable :  Geom_unif /corrélation: 0.004796022931297418
# variable :  Rugosite_Max /corrélation: 0.029134573570975916
# variable :  Rugosite_Moyenne /corrélation: 0.024104169518081885
# variable :  Rugosite_Min /corrélation: 0.030832713533705557
# variable :  Rugosite_Moy /corrélation: 0.02672798320722991
# variable :  Rugosite_sd /corrélation: 0.021706862797105594
# variable :  Pente_Max /corrélation: 0.02897989770002098
# variable :  Pente_Moyenne /corrélation: 0.02049599700950349
# variable :  Pente_Min /corrélation: 0.028966187336441795
# variable :  Pente_Moy /corrélation: 0.02656522850660958
# variable :  Pente_sd /corrélation: 0.020799616747254147
# variable :  IPT_Max /corrélation: 0.016485287920429425
# variable :  IPT_Med /corrélation: 0.008229078737351245
# variable :  IPT_Min /corrélation: 0.01984264219829475
# variable :  IPT_Moy /corrélation: 0.0015770233298015787
# variable :  IPT_sd /corrélation: 0.0196477703866066
# variable :  IR_Max /corrélation: 0.028188049841115972
# variable :  IR_Med /corrélation: 0.019841429082105837
# variable :  IR_Min /corrélation: 0.02629132041760515
# variable :  IR_Moy /corrélation: 0.02473778092641689
# variable :  IR_sd /corrélation: 0.016076904978180602
# variable :  RV_Max /corrélation: 0.01113875166668757
# variable :  RV_Med /corrélation: 0.0046159631374196155
# variable :  RV_Min /corrélation: 0.007211398249785495
# variable :  RV_Moy /corrélation: 0.0063266469885103335
# variable :  RV_sd /corrélation: 0.007840677585329726
# variable :  Bio_Ta_moy /corrélation: 0.005964464930026865
# variable :  Bio_Tj_Moy /corrélation: 0.007506867692093809
# variable :  Isoth /corrélation: 0.00012296192337950452
# variable :  Bio_Saison /corrélation: 0.0014515708593438087
# variable :  Bio_Tmax /corrélation: 0.017475044543318028
# variable :  Bio_Tmin /corrélation: 0.00018677339404385044
# variable :  Bio_Tint /corrélation: 0.00394800068309203
# variable :  Bio_Thum_Moy /corrélation: 0.0046891074046795395
# variable :  Bio_Tsec_Moy /corrélation: 0.016511573450619047
# variable :  Bio_Tch_Moy /corrélation: 0.01586074115697416
# variable :  Bio_Tfr_Moy /corrélation: 0.0018865817257930093
# variable :  Bio_Pre_Ann /corrélation: 0.0025167626105185165
# variable :  Bio_Pre_hum /corrélation: 0.004724345016943051
# variable :  Bio_Pre_sec /corrélation: 0.010943555120817901
# variable :  Bio_Pre_Saison /corrélation: 4.2962872663746325e-06
# variable :  Bio_Pre_Qhum /corrélation: 0.002523338316110114
# variable :  Bio_Pre_Qsec /corrélation: 0.0016098252797568527
# variable :  Bio_Pre_Qch /corrélation: 4.074908233257309e-08
# variable :  Bio_Pre_Qfr /corrélation: 0.002559823069707333
# variable :  Prec_Janv /corrélation: 0.0012016472197005602
# variable :  Prec_Fev /corrélation: 0.0010187938367171125
# variable :  Prec_Mars /corrélation: 0.00019380509690037313
# variable :  Prec_Avril /corrélation: 0.006277998346013833
# variable :  Prec_Mai /corrélation: 0.004132140273758485
# variable :  Prec_Juin /corrélation: 0.00016130145535935415
# variable :  Prec_Juill /corrélation: 0.03879049279275149
# variable :  Prec_Aout /corrélation: 0.0014309769759594802
# variable :  Prec_Sept /corrélation: 2.6430443403984048e-05
# variable :  Prec_Oct /corrélation: 0.00833361656458956
# variable :  Prec_Nov /corrélation: 0.0014549643307274712
# variable :  Prec_Dec /corrélation: 0.006002656458282385
# variable :  Rad_Janv /corrélation: 0.02069686767844632
# variable :  Rad_Fev /corrélation: 0.021964294481696515
# variable :  Rad_Mars /corrélation: 0.013398248711865082
# variable :  Rad_Avril /corrélation: 0.004459794131762252
# variable :  Rad_Mai /corrélation: 0.011936759427683505
# variable :  Rad_Juin /corrélation: 0.01478878013360453
# variable :  Rad_Juill /corrélation: 0.014438973893817035
# variable :  Rad_Aout /corrélation: 0.005373043859118563
# variable :  Rad_Sept /corrélation: 2.482889453652383e-05
# variable :  Rad_Oct /corrélation: 0.0199283102264555
# variable :  Rad_Nov /corrélation: 0.018653268786983566
# variable :  Rad_Dec /corrélation: 0.02029584502259751
# variable :  Tmax_Janv /corrélation: 0.004065108552970015
# variable :  Tmax_Fev /corrélation: 0.005421140257793364
# variable :  Tmax_Mars /corrélation: 0.002000222946067622
# variable :  Tmax_Avril /corrélation: 0.0018489915203327898
# variable :  Tmax_Mai /corrélation: 0.0045282621524062264
# variable :  Tmax_Juin /corrélation: 0.007630124730440435
# variable :  Tmax_Juill /corrélation: 0.016744415718108516
# variable :  Tmax_Aout /corrélation: 0.017922289739143418
# variable :  Tmax_Sept /corrélation: 0.021534366790178994
# variable :  Tmax_Oct /corrélation: 0.013191301008482318
# variable :  Tmax_Nov /corrélation: 0.008037016608546915
# variable :  Tmax_Dec /corrélation: 0.005100115035390856
# variable :  Tmin_Janv /corrélation: 0.0002556191970223884
# variable :  Tmin_Fev /corrélation: 0.0006859658515197985
# variable :  Tmin_Mars /corrélation: 6.205445888829534e-06
# variable :  Tmin_Avril /corrélation: 2.996057165051025e-05
# variable :  Tmin_Mai /corrélation: 0.0004554880514999371
# variable :  Tmin_Juin /corrélation: 0.0037851295561753466
# variable :  Tmin_Juill /corrélation: 0.006860946160029727
# variable :  Tmin_Aout /corrélation: 0.008750407161970324
# variable :  Tmin_Sept /corrélation: 0.008659599832064215
# variable :  Tmin_Oct /corrélation: 0.0032713509538123014
# variable :  Tmin_Nov /corrélation: 0.0007451801838526775
# variable :  Tmin_Dec /corrélation: 0.00010757288986094988
# variable :  Vap_Janv /corrélation: 0.005269037984104718
# variable :  Vap_Fev /corrélation: 0.005350496495790794
# variable :  Vap_Mars /corrélation: 0.004965138487550618
# variable :  Vap_Avril /corrélation: 0.0019969083477611436
# variable :  Vap_Mai /corrélation: 0.004834464410378689
# variable :  Vap_Juin /corrélation: 0.006485752956325832
# variable :  Vap_Juill /corrélation: 0.008906234792644574
# variable :  Vap_Aout /corrélation: 0.008962235110653803
# variable :  Vap_Sept /corrélation: 0.006727707968919889
# variable :  Vap_Oct /corrélation: 0.003162921878850793
# variable :  Vap_Nov /corrélation: 0.0030206361015486915
# variable :  Vap_Dec /corrélation: 0.0025061374351548985
# variable :  Vent_Janv /corrélation: 0.0393690720351093
# variable :  Vent_Fev /corrélation: 0.03510745385814654
# variable :  Vent_Mars /corrélation: 0.05601337047795949
# variable :  Vent_Avril /corrélation: 0.041182392013442044
# variable :  Vent_Mai /corrélation: 0.0545610601395118
# variable :  Vent_Juin /corrélation: 0.02573545878645966
# variable :  Vent_Juill /corrélation: 0.021602230807490002
# variable :  Vent_Aout /corrélation: 0.03325117483722408
# variable :  Vent_Sept /corrélation: 0.06370729353546721
# variable :  Vent_Oct /corrélation: 0.05924379290887623
# variable :  Vent_Nov /corrélation: 0.03467906678582198
# variable :  Vent_Dec /corrélation: 0.0616664703643713

# %%
lst1
# Out:
# [['X_long', 0.014907543721239909],
#  ['Y_lat', 0.02068798989320879],
#  ['Bovins', 0.010665111172745101],
#  ['Volaille', 0.002059064629224964],
#  ['Caprins', 0.002395411809425821],
#  ['Ovins', 0.04204309954175782],
#  ['Equides', 0.018091886294064333],
#  ['Coniferes', 0.011968742073335325],
#  ['ZoneAride', 0.03050054399569615],
#  ['ZonePel', 0.00036633449619265305],
#  ['Lesfeuillus', 0.009433920401958094],
#  ['Caduc', 0.0029761206919433343],
#  ['Autres', 0.011099961815085527],
#  ['Arbrisseau', 0.007557109485838745],
#  ['Pl_herb', 0.018478786480108624],
#  ['VegCul', 0.039576627200022654],
#  ['VegInond', 0.0020188298246184527],
#  ['ZoneUrbaine', 0.0004171651655154538],
#  ['Moy_IRM', 0.03743052964886251],
#  ['Amp1_IRM', 0.01587734968283396],
#  ['Amp2_IRM', 0.007262591275823586],
#  ['Amp3_IRM', 0.03142660100677615],
#  ['VarT_ann_IRM', 0.006007776830812108],
#  ['VarT_bi_IRM', 1.1933685247725788e-06],
#  ['VarT_tri_IRM', 0.004880564744836453],
#  ['VarT_Cy_IRM', 0.005486112288146263],
#  ['Min_IRM', 0.04797182731866463],
#  ['Max_IRM', 0.026548528613119224],
#  ['Ph1_IRM', 0.039603028458924106],
#  ['Ph2_IRM', 0.0032271674633766287],
#  ['Ph3_IRM', 0.0158639360992941],
#  ['Var_IRM', 0.01990193122772172],
#  ['Moy_TempJ', 0.006018986922598286],
#  ['Amp1_TempJ', 0.0006139492594806651],
#  ['Amp2_TempJ', 0.014286869367858886],
#  ['Amp3_TempJ', 0.10356228943658431],
#  ['VarT_ann_TempJ', 0.0005845447343518414],
#  ['VarT_bi_TempJ', 0.00647890332836792],
#  ['VarT_tri_TempJ', 0.004876960833574715],
#  ['VarT_cy_TempJ', 0.0019164630541541432],
#  ['Min_TempJ', 0.00662961758619414],
#  ['Max_TempJ', 0.005545015585406105],
#  ['Ph1_TempJ', 0.00484480361506424],
#  ['Ph2_TempJ', 0.0003035552250008039],
#  ['Ph3_TempJ', 0.004743535907141725],
#  ['Var_TempJ', 0.0019060909658719025],
#  ['Moy_TempN', 0.006146831546416289],
#  ['Amp1_TempN', 0.00012082575473083353],
#  ['Amp2_TempN', 0.027647192547780895],
#  ['Amp3_TempN', 0.0004310090281682975],
#  ['VarT_ann_TempN', 3.5238004553850776e-05],
#  ['VarT_bi_TempN', 0.01047654108422437],
#  ['VarT_tri_TempN', 0.00012606587131395915],
#  ['VarT_cy_TempN', 0.0004301460553803924],
#  ['Min_TempN', 0.006427825397823434],
#  ['Max_TempN', 0.005942398209396421],
#  ['Ph1_TempN', 0.006905479123969625],
#  ['Ph2_TempN', 4.88774797274175e-05],
#  ['Ph3_TempN', 0.018405819548693175],
#  ['Var_TempN', 0.0003252738404756975],
#  ['Moy_NDVI', 0.026716522437302284],
#  ['Amp1_NDVI', 0.04175305211226607],
#  ['Amp2_NDVI', 0.028240546266286852],
#  ['Amp3_NDVI', 0.02509801140287577],
#  ['VarT_ann_NDVI', 0.010841397537050141],
#  ['VarT_bi_NDVI', 0.0016622842730844554],
#  ['VarT_tri_NDVI', 0.005720182388520715],
#  ['VarT_cy_NDVI', 0.01343474020944027],
#  ['Min_NDVI', 0.012963680155575268],
#  ['Max_NDVI', 0.04208499695688243],
#  ['Ph1_NDVI', 0.0005322685536080081],
#  ['Ph2_NDVI', 0.00037035333839612717],
#  ['Ph3_NDVI', 6.068740679473555e-06],
#  ['Var_NDVI', 0.04762553180985702],
#  ['Moy_EVI', 0.022262084144771148],
#  ['Amp1_EVI', 0.03311057790876982],
#  ['Amp2_EVI', 0.025005800021151072],
#  ['Amp3_EVI', 0.042165864300414774],
#  ['VarT_ann_EVI', 0.010047695313332973],
#  ['VarT_bi_EVI', 0.0027173742639437313],
#  ['VarT_tri_EVI', 0.009202038943418442],
#  ['VarT_cy_EVI', 0.012149643511040767],
#  ['Min_EVI', 0.008042128376333715],
#  ['Max_EVI', 0.034296939572441135],
#  ['Ph1_EVI', 0.00022402334681787935],
#  ['Ph2_EVI', 1.5812751416545063e-06],
#  ['Ph3_EVI', 0.006117844083269993],
#  ['Var_EVI', 0.03413978678744323],
#  ['Ret_eau', 0.011406058738050855],
#  ['Sol_teneur', 0.006932744599287625],
#  ['Substratum', 0.04223090184721784],
#  ['Prob_R', 0.06283350437984474],
#  ['ProfAbs_Sub', 0.014836359537072689],
#  ['CEC', 0.008090085397247204],
#  ['Sol_Argile', 0.00021329576411540597],
#  ['Sol_Carbone', 0.004315432141072077],
#  ['Sol_Carbone_stock', 0.00011811215053615652],
#  ['Sol_Carbone_terreFine', 0.0006480813846004409],
#  ['Sol_pH_KCL', 4.160686493813142e-05],
#  ['Sol_Limon', 0.021521537586632652],
#  ['Sol_Sable', 0.01916723947549685],
#  ['Elev_Max', 0.01953635081901616],
#  ['Elev_Moyenne', 0.017206476816811835],
#  ['Elev_Min', 0.014246745636891597],
#  ['Elev_Moy', 0.01686309463663451],
#  ['Elev_sd', 0.019590864640288558],
#  ['Geom_maj', 0.008738225079895834],
#  ['Geom_Shan', 0.001215078561987139],
#  ['Geom_unif', 0.004796022931297418],
#  ['Rugosite_Max', 0.029134573570975916],
#  ['Rugosite_Moyenne', 0.024104169518081885],
#  ['Rugosite_Min', 0.030832713533705557],
#  ['Rugosite_Moy', 0.02672798320722991],
#  ['Rugosite_sd', 0.021706862797105594],
#  ['Pente_Max', 0.02897989770002098],
#  ['Pente_Moyenne', 0.02049599700950349],
#  ['Pente_Min', 0.028966187336441795],
#  ['Pente_Moy', 0.02656522850660958],
#  ['Pente_sd', 0.020799616747254147],
#  ['IPT_Max', 0.016485287920429425],
#  ['IPT_Med', 0.008229078737351245],
#  ['IPT_Min', 0.01984264219829475],
#  ['IPT_Moy', 0.0015770233298015787],
#  ['IPT_sd', 0.0196477703866066],
#  ['IR_Max', 0.028188049841115972],
#  ['IR_Med', 0.019841429082105837],
#  ['IR_Min', 0.02629132041760515],
#  ['IR_Moy', 0.02473778092641689],
#  ['IR_sd', 0.016076904978180602],
#  ['RV_Max', 0.01113875166668757],
#  ['RV_Med', 0.0046159631374196155],
#  ['RV_Min', 0.007211398249785495],
#  ['RV_Moy', 0.0063266469885103335],
#  ['RV_sd', 0.007840677585329726],
#  ['Bio_Ta_moy', 0.005964464930026865],
#  ['Bio_Tj_Moy', 0.007506867692093809],
#  ['Isoth', 0.00012296192337950452],
#  ['Bio_Saison', 0.0014515708593438087],
#  ['Bio_Tmax', 0.017475044543318028],
#  ['Bio_Tmin', 0.00018677339404385044],
#  ['Bio_Tint', 0.00394800068309203],
#  ['Bio_Thum_Moy', 0.0046891074046795395],
#  ['Bio_Tsec_Moy', 0.016511573450619047],
#  ['Bio_Tch_Moy', 0.01586074115697416],
#  ['Bio_Tfr_Moy', 0.0018865817257930093],
#  ['Bio_Pre_Ann', 0.0025167626105185165],
#  ['Bio_Pre_hum', 0.004724345016943051],
#  ['Bio_Pre_sec', 0.010943555120817901],
#  ['Bio_Pre_Saison', 4.2962872663746325e-06],
#  ['Bio_Pre_Qhum', 0.002523338316110114],
#  ['Bio_Pre_Qsec', 0.0016098252797568527],
#  ['Bio_Pre_Qch', 4.074908233257309e-08],
#  ['Bio_Pre_Qfr', 0.002559823069707333],
#  ['Prec_Janv', 0.0012016472197005602],
#  ['Prec_Fev', 0.0010187938367171125],
#  ['Prec_Mars', 0.00019380509690037313],
#  ['Prec_Avril', 0.006277998346013833],
#  ['Prec_Mai', 0.004132140273758485],
#  ['Prec_Juin', 0.00016130145535935415],
#  ['Prec_Juill', 0.03879049279275149],
#  ['Prec_Aout', 0.0014309769759594802],
#  ['Prec_Sept', 2.6430443403984048e-05],
#  ['Prec_Oct', 0.00833361656458956],
#  ['Prec_Nov', 0.0014549643307274712],
#  ['Prec_Dec', 0.006002656458282385],
#  ['Rad_Janv', 0.02069686767844632],
#  ['Rad_Fev', 0.021964294481696515],
#  ['Rad_Mars', 0.013398248711865082],
#  ['Rad_Avril', 0.004459794131762252],
#  ['Rad_Mai', 0.011936759427683505],
#  ['Rad_Juin', 0.01478878013360453],
#  ['Rad_Juill', 0.014438973893817035],
#  ['Rad_Aout', 0.005373043859118563],
#  ['Rad_Sept', 2.482889453652383e-05],
#  ['Rad_Oct', 0.0199283102264555],
#  ['Rad_Nov', 0.018653268786983566],
#  ['Rad_Dec', 0.02029584502259751],
#  ['Tmax_Janv', 0.004065108552970015],
#  ['Tmax_Fev', 0.005421140257793364],
#  ['Tmax_Mars', 0.002000222946067622],
#  ['Tmax_Avril', 0.0018489915203327898],
#  ['Tmax_Mai', 0.0045282621524062264],
#  ['Tmax_Juin', 0.007630124730440435],
#  ['Tmax_Juill', 0.016744415718108516],
#  ['Tmax_Aout', 0.017922289739143418],
#  ['Tmax_Sept', 0.021534366790178994],
#  ['Tmax_Oct', 0.013191301008482318],
#  ['Tmax_Nov', 0.008037016608546915],
#  ['Tmax_Dec', 0.005100115035390856],
#  ['Tmin_Janv', 0.0002556191970223884],
#  ['Tmin_Fev', 0.0006859658515197985],
#  ['Tmin_Mars', 6.205445888829534e-06],
#  ['Tmin_Avril', 2.996057165051025e-05],
#  ['Tmin_Mai', 0.0004554880514999371],
#  ['Tmin_Juin', 0.0037851295561753466],
#  ['Tmin_Juill', 0.006860946160029727],
#  ['Tmin_Aout', 0.008750407161970324],
#  ['Tmin_Sept', 0.008659599832064215],
#  ['Tmin_Oct', 0.0032713509538123014],
#  ['Tmin_Nov', 0.0007451801838526775],
#  ['Tmin_Dec', 0.00010757288986094988],
#  ['Vap_Janv', 0.005269037984104718],
#  ['Vap_Fev', 0.005350496495790794],
#  ['Vap_Mars', 0.004965138487550618],
#  ['Vap_Avril', 0.0019969083477611436],
#  ['Vap_Mai', 0.004834464410378689],
#  ['Vap_Juin', 0.006485752956325832],
#  ['Vap_Juill', 0.008906234792644574],
#  ['Vap_Aout', 0.008962235110653803],
#  ['Vap_Sept', 0.006727707968919889],
#  ['Vap_Oct', 0.003162921878850793],
#  ['Vap_Nov', 0.0030206361015486915],
#  ['Vap_Dec', 0.0025061374351548985],
#  ['Vent_Janv', 0.0393690720351093],
#  ['Vent_Fev', 0.03510745385814654],
#  ['Vent_Mars', 0.05601337047795949],
#  ['Vent_Avril', 0.041182392013442044],
#  ['Vent_Mai', 0.0545610601395118],
#  ['Vent_Juin', 0.02573545878645966],
#  ['Vent_Juill', 0.021602230807490002],
#  ['Vent_Aout', 0.03325117483722408],
#  ['Vent_Sept', 0.06370729353546721],
#  ['Vent_Oct', 0.05924379290887623],
#  ['Vent_Nov', 0.03467906678582198],
#  ['Vent_Dec', 0.0616664703643713]]

# %%
df1 = pd.DataFrame(lst1, columns = ['variable','corrélation'])
print(df1)
# Out:
#       variable  corrélation
# 0       X_long     0.014908
# 1        Y_lat     0.020688
# 2       Bovins     0.010665
# 3     Volaille     0.002059
# 4      Caprins     0.002395
# ..         ...          ...
# 220  Vent_Aout     0.033251
# 221  Vent_Sept     0.063707
# 222   Vent_Oct     0.059244
# 223   Vent_Nov     0.034679
# 224   Vent_Dec     0.061666
#
# [225 rows x 2 columns]

# %%
df1.to_excel("cs_longia_apprentissage_corrélation.xlsx")
